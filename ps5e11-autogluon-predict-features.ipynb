# %%
# %%capture cap
# !pip install -qq ipywidgets
# !pip install -qq autogluon scikit-learn==1.5.2 
# !apt-get install -qq -y graphviz graphviz-dev && pip install -q pydot
# !pip install -qq pygraphviz
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 85.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.9/454.9 kB 25.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.3/487.3 kB 25.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.7/189.7 kB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.8/285.8 kB 19.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.5/280.5 kB 15.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 52.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 35.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 22.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 MB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.4/354.4 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 79.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 67.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 70.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.5/963.5 kB 40.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 84.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 26.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 17.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 75.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 85.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 100.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 kB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 3.0 MB/s eta 0:00:00
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Building wheel for seqeval (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# Selecting previously unselected package libgtk2.0-common.
# (Reading database ... 128639 files and directories currently installed.)
# Preparing to unpack .../0-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../1-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../2-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../3-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libxdot4:amd64.
# Preparing to unpack .../4-libxdot4_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgvc6-plugins-gtk.
# Preparing to unpack .../5-libgvc6-plugins-gtk_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgraphviz-dev:amd64.
# Preparing to unpack .../6-libgraphviz-dev_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../7-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.0/106.0 kB 3.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for pygraphviz (pyproject.toml) ... done

# %%
import torch
import os
import pydot

import random
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
from time import time, sleep
from itertools import combinations

from IPython.display import display, Image
import matplotlib.pyplot as plt
import seaborn as sns

import warnings

warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')

## -- Set Global Seed --
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

pd.set_option('display.max_columns', 500)
plt.style.use("ggplot")

## -- Ansi color codes --
COLOR = '\033[32m'
RESET = '\033[0m'

print("Packages import succesful!")
# Out:
# Packages import succesful!

# %%
### Load Data ###
PATH = "/kaggle/input/playground-series-s5e11/"
submit = pd.read_csv(PATH+"sample_submission.csv")

list_of_targets = [
    'debt_to_income_ratio',
    'credit_score',
    'interest_rate',
    'employment_status',
    'annual_income',
    'loan_amount',
    'gender',
    'marital_status',
    'education_level',
    'loan_purpose',
    'grade_subgrade',
]

TARGET = list_of_targets[4]

train = pd.read_csv(PATH+"train.csv").drop(['id', "loan_paid_back"], axis=1)
test = pd.read_csv(PATH+"test.csv").drop(['id', TARGET], axis=1)

# ## -- Convert target to float for regression --
# train[TARGET] = train[TARGET].astype(np.float32)

NUMS = test.select_dtypes(include='number').columns.tolist()
CATS = test.select_dtypes(exclude='number').columns.tolist()
BASE = NUMS + CATS

for (name, df) in dict(Train=train, Test=test).items():
    print(f"{name} shape: {df.shape}")

print(f"\nTotal Numerical: {len(NUMS)}")
print(f"Total Categorical: {len(CATS)}")
print(f"Total base features: {len(BASE)}")
# Out:
# Train shape: (593994, 11)
# Test shape: (254569, 10)
#
# Total Numerical: 4
# Total Categorical: 6
# Total base features: 10

# %%
# !rm -r /kaggle/working/AG_loan_models

# %%
from autogluon.tabular import TabularPredictor

# %%
MODELS_PATH = "./AG_loan_models/"

predictor = TabularPredictor(
                label = TARGET,
         problem_type = "regression",
         #  eval_metric = "roc_auc",
                 path = MODELS_PATH,
    ).fit(
                   train_data = train,
                      presets = "best",
                num_bag_folds = 6,
             # dynamic_stacking = False,
             # num_stack_levels = 1,
                   time_limit = 3600*5,
                   # auto_stack = False,
                 # num_bag_sets = 2,
                  # ag_args_fit = {'num_cpus': os.cpu_count()},
)
# Out:
# Preset alias specified: 'best' maps to 'best_quality'.
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.11.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Sat Sep 27 10:16:09 UTC 2025
# CPU Count:          4
# Memory Avail:       29.95 GB / 31.35 GB (95.5%)
# Disk Space Avail:   19.50 GB / 19.52 GB (99.9%)
# ===================================================
# Presets specified: ['best']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=6, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 4500s of the 18000s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-11-29 10:34:35,763	INFO worker.py:1843 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho"
# (_dystack pid=413) Running DyStack sub-fit ...
# (_dystack pid=413) Beginning AutoGluon training ... Time limit = 4496s
# (_dystack pid=413) AutoGluon will save models to "/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho"
# (_dystack pid=413) Train Data Rows:    527994
# (_dystack pid=413) Train Data Columns: 10
# (_dystack pid=413) Label Column:       annual_income
# (_dystack pid=413) Problem Type:       regression
# (_dystack pid=413) Preprocessing data ...
# (_dystack pid=413) Using Feature Generators to preprocess the data ...
# (_dystack pid=413) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=413) 	Available Memory:                    30088.00 MB
# (_dystack pid=413) 	Train Data (Original)  Memory Usage: 210.58 MB (0.7% of available memory)
# (_dystack pid=413) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=413) 	Stage 1 Generators:
# (_dystack pid=413) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=413) 	Stage 2 Generators:
# (_dystack pid=413) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=413) 	Stage 3 Generators:
# (_dystack pid=413) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=413) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=413) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=413) 	Stage 4 Generators:
# (_dystack pid=413) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=413) 	Stage 5 Generators:
# (_dystack pid=413) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=413) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=413) 		('float', [])  : 3 | ['debt_to_income_ratio', 'loan_amount', 'interest_rate']
# (_dystack pid=413) 		('int', [])    : 1 | ['credit_score']
# (_dystack pid=413) 		('object', []) : 6 | ['gender', 'marital_status', 'education_level', 'employment_status', 'loan_purpose', ...]
# (_dystack pid=413) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=413) 		('category', []) : 6 | ['gender', 'marital_status', 'education_level', 'employment_status', 'loan_purpose', ...]
# (_dystack pid=413) 		('float', [])    : 3 | ['debt_to_income_ratio', 'loan_amount', 'interest_rate']
# (_dystack pid=413) 		('int', [])      : 1 | ['credit_score']
# (_dystack pid=413) 	2.2s = Fit runtime
# (_dystack pid=413) 	10 features in original data used to generate 10 features in processed data.
# (_dystack pid=413) 	Train Data (Processed) Memory Usage: 19.14 MB (0.1% of available memory)
# (_dystack pid=413) Data preprocessing and feature engineering runtime = 2.3s ...
# (_dystack pid=413) AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# (_dystack pid=413) 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# (_dystack pid=413) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=413) Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=413) User-specified model hyperparameters to be fit:
# (_dystack pid=413) {
# (_dystack pid=413) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=413) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=413) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=413) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=413) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=413) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=413) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=413) }
# (_dystack pid=413) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=413) Fitting 106 L1 models, fit_strategy="sequential" ...
# (_dystack pid=413) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2994.72s of the 4493.19s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.53%)
# (_dystack pid=413) 	-26680.5111	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=413) 	35.58s	 = Training   runtime
# (_dystack pid=413) 	9.36s	 = Validation runtime
# (_dystack pid=413) Fitting model: LightGBM_BAG_L1 ... Training model for up to 2951.59s of the 4450.06s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.54%)
# (_dystack pid=413) 	-26659.2253	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=413) 	33.36s	 = Training   runtime
# (_dystack pid=413) 	7.67s	 = Validation runtime
# (_dystack pid=413) Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 2913.28s of the 4411.76s of remaining time.
# (_dystack pid=413) 	-26799.839	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=413) 	521.61s	 = Training   runtime
# (_dystack pid=413) 	26.86s	 = Validation runtime
# (_dystack pid=413) Fitting model: CatBoost_BAG_L1 ... Training model for up to 2361.62s of the 3860.10s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.85%)
# (_ray_fit pid=1419) 	Ran out of time, early stopping on iteration 929.
# (_ray_fit pid=1771) 	Ran out of time, early stopping on iteration 1343. [repeated 4x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_dystack pid=413) 	-26650.9419	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=413) 	1902.29s	 = Training   runtime
# (_dystack pid=413) 	6.48s	 = Validation runtime
# (_dystack pid=413) Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 454.63s of the 1953.11s of remaining time.
# (_ray_fit pid=1772) 	Ran out of time, early stopping on iteration 1336.
# (_dystack pid=413) 	-26721.684	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=413) 	132.0s	 = Training   runtime
# (_dystack pid=413) 	20.66s	 = Validation runtime
# (_dystack pid=413) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 299.93s of the 1798.41s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.89%)
# (_dystack pid=413) 	-26690.5518	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=413) 	179.7s	 = Training   runtime
# (_dystack pid=413) 	7.63s	 = Validation runtime
# (_dystack pid=413) Fitting model: XGBoost_BAG_L1 ... Training model for up to 115.47s of the 1613.94s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.71%)
# (_dystack pid=413) 	-26678.3966	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=413) 	104.5s	 = Training   runtime
# (_dystack pid=413) 	2.59s	 = Validation runtime
# (_dystack pid=413) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 6.44s of the 1504.91s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.51%)
# (_dystack pid=413) 	Time limit exceeded... Skipping NeuralNetTorch_BAG_L1.
# (_dystack pid=413) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 1481.49s of remaining time.
# (_dystack pid=413) 	Ensemble Weights: {'CatBoost_BAG_L1': 0.72, 'LightGBM_BAG_L1': 0.2, 'RandomForestMSE_BAG_L1': 0.08}
# (_dystack pid=413) 	-26649.1707	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=413) 	1.03s	 = Training   runtime
# (_dystack pid=413) 	0.01s	 = Validation runtime
# (_dystack pid=413) Fitting 106 L2 models, fit_strategy="sequential" ...
# (_dystack pid=413) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1480.39s of the 1480.30s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.85%)
# (_dystack pid=413) 	-26650.8859	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=413) 	27.62s	 = Training   runtime
# (_dystack pid=413) 	4.31s	 = Validation runtime
# (_dystack pid=413) Fitting model: LightGBM_BAG_L2 ... Training model for up to 1448.12s of the 1448.03s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.85%)
# (_dystack pid=413) 	-26650.9563	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=413) 	23.4s	 = Training   runtime
# (_dystack pid=413) 	3.1s	 = Validation runtime
# (_dystack pid=413) Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 1420.05s of the 1419.96s of remaining time.
# (_dystack pid=413) 	Warning: Reducing model 'n_estimators' from 300 -> 178 due to low time. Expected time usage reduced from 2382.8s -> 1419.6s...
# (_dystack pid=413) 	-26818.2978	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=413) 	1259.24s	 = Training   runtime
# (_dystack pid=413) 	19.29s	 = Validation runtime
# (_dystack pid=413) Fitting model: CatBoost_BAG_L2 ... Training model for up to 140.32s of the 140.23s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.18%)
# (_ray_fit pid=3919) 	Ran out of time, early stopping on iteration 47.
# (_ray_fit pid=4075) 	Ran out of time, early stopping on iteration 79. [repeated 4x across cluster]
# (_dystack pid=413) 	-26649.4515	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=413) 	113.79s	 = Training   runtime
# (_dystack pid=413) 	0.54s	 = Validation runtime
# (_dystack pid=413) Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 21.97s of the 21.87s of remaining time.
# (_dystack pid=413) 	Warning: Model is expected to require 247.5s to train, which exceeds the maximum time limit of 21.6s, skipping model...
# (_dystack pid=413) 	Time limit exceeded... Skipping ExtraTreesMSE_BAG_L2.
# (_dystack pid=413) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=413) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=413) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=2809, ip=172.19.2.2)
# (_dystack pid=413)   File "/usr/local/lib/python3.11/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
# (_dystack pid=413)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=413)   File "/usr/local/lib/python3.11/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=413)     out = self._fit(**kwargs)
# (_dystack pid=413)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=413)   File "/usr/local/lib/python3.11/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 247, in _fit
# (_dystack pid=413)     raise TimeLimitExceeded
# (_dystack pid=413) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_ray_fit pid=4088) 	Ran out of time, early stopping on iteration 83.
# (_dystack pid=413) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 17.69s of the 17.60s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.42%)
# (_dystack pid=413) 	Time limit exceeded... Skipping NeuralNetFastAI_BAG_L2.
# (_dystack pid=413) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the 5.08s of remaining time.
# (_dystack pid=413) 	Ensemble Weights: {'CatBoost_BAG_L1': 0.36, 'CatBoost_BAG_L2': 0.24, 'LightGBMXT_BAG_L2': 0.16, 'LightGBM_BAG_L2': 0.12, 'LightGBM_BAG_L1': 0.04, 'RandomForestMSE_BAG_L1': 0.04, 'RandomForestMSE_BAG_L2': 0.04}
# (_dystack pid=413) 	-26647.9713	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=413) 	1.19s	 = Training   runtime
# (_dystack pid=413) 	0.01s	 = Validation runtime
# (_dystack pid=413) AutoGluon training complete, total runtime = 4491.73s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 1666.5 rows/s (87999 batch size)
# (_dystack pid=413) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho")
# (_dystack pid=413) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=413) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=413) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=413) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                      model  score_holdout     score_val              eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0          LightGBM_BAG_L2  -26803.905090 -26650.956310  root_mean_squared_error       26.864688      84.334446  2932.446493                 0.810660                3.098812          23.398670            2       True         10
# 1      WeightedEnsemble_L3  -26804.097731 -26647.971252  root_mean_squared_error       30.723633     108.483952  4334.297211                 0.006208                0.011681           1.190148            3       True         13
# 2        LightGBMXT_BAG_L2  -26805.523638 -26650.885902  root_mean_squared_error       27.289021      85.541471  2936.669499                 1.234993                4.305837          27.621676            2       True          9
# 3          CatBoost_BAG_L2  -26805.594682 -26649.451466  root_mean_squared_error       26.248980      81.779494  3022.842145                 0.194952                0.543860         113.794322            2       True         12
# 4      WeightedEnsemble_L2  -26805.658717 -26649.170747  root_mean_squared_error        9.051760      41.014370  2458.292033                 0.004786                0.012172           1.028348            2       True          8
# 5          CatBoost_BAG_L1  -26807.473143 -26650.941860  root_mean_squared_error        2.222293       6.475508  1902.289148                 2.222293                6.475508        1902.289148            1       True          4
# 6          LightGBM_BAG_L1  -26814.687653 -26659.225269  root_mean_squared_error        2.404155       7.666105    33.364760                 2.404155                7.666105          33.364760            1       True          2
# 7           XGBoost_BAG_L1  -26834.178515 -26678.396630  root_mean_squared_error        1.575765       2.586250   104.504598                 1.575765                2.586250         104.504598            1       True          7
# 8        LightGBMXT_BAG_L1  -26835.325330 -26680.511068  root_mean_squared_error        8.136647       9.356304    35.581819                 8.136647                9.356304          35.581819            1       True          1
# 9   NeuralNetFastAI_BAG_L1  -26842.020365 -26690.551762  root_mean_squared_error        4.468322       7.634312   179.702000                 4.468322                7.634312         179.702000            1       True          6
# 10    ExtraTreesMSE_BAG_L1  -26855.432670 -26721.684007  root_mean_squared_error        2.826320      20.656571   131.995721                 2.826320               20.656571         131.995721            1       True          5
# 11  RandomForestMSE_BAG_L2  -26882.063624 -26818.297754  root_mean_squared_error       28.476820     100.523762  4168.292395                 2.422792               19.288128        1259.244572            2       True         11
# 12  RandomForestMSE_BAG_L1  -26913.091047 -26799.839017  root_mean_squared_error        4.420527      26.860585   521.609777                 4.420527               26.860585         521.609777            1       True          3
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	4532s	 = DyStack   runtime |	13468s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 13468s
# AutoGluon will save models to "/kaggle/working/AG_loan_models"
# Train Data Rows:    593994
# Train Data Columns: 10
# Label Column:       annual_income
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    29513.76 MB
# 	Train Data (Original)  Memory Usage: 236.92 MB (0.8% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 3 | ['debt_to_income_ratio', 'loan_amount', 'interest_rate']
# 		('int', [])    : 1 | ['credit_score']
# 		('object', []) : 6 | ['gender', 'marital_status', 'education_level', 'employment_status', 'loan_purpose', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 6 | ['gender', 'marital_status', 'education_level', 'employment_status', 'loan_purpose', ...]
# 		('float', [])    : 3 | ['debt_to_income_ratio', 'loan_amount', 'interest_rate']
# 		('int', [])      : 1 | ['credit_score']
# 	2.6s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 21.53 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 3.08s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 8974.65s of the 13465.31s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.48%)
# 	-26696.5923	 = Validation score   (-root_mean_squared_error)
# 	38.39s	 = Training   runtime
# 	11.24s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 8930.40s of the 13421.07s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.48%)
# 	-26676.048	 = Validation score   (-root_mean_squared_error)
# 	33.92s	 = Training   runtime
# 	9.77s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 8891.18s of the 13381.84s of remaining time.
# 	-26799.2744	 = Validation score   (-root_mean_squared_error)
# 	636.63s	 = Training   runtime
# 	29.24s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 8221.77s of the 12712.44s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.78%)
# 	-26664.9532	 = Validation score   (-root_mean_squared_error)
# 	6610.69s	 = Training   runtime
# 	11.92s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 1605.46s of the 6096.13s of remaining time.
# 	-26735.3162	 = Validation score   (-root_mean_squared_error)
# 	174.31s	 = Training   runtime
# 	22.69s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1405.07s of the 5895.74s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.81%)
# 	-26707.5713	 = Validation score   (-root_mean_squared_error)
# 	897.18s	 = Training   runtime
# 	8.77s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 502.51s of the 4993.17s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.65%)
# 	-26683.2556	 = Validation score   (-root_mean_squared_error)
# 	419.47s	 = Training   runtime
# 	3.96s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 78.00s of the 4568.67s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.46%)
# 	Time limit exceeded... Skipping NeuralNetTorch_BAG_L1.
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 37.93s of the 4528.60s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.54%)
# 2025-11-29 14:19:09,536	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-11-29 14:19:10,537	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-11-29 14:19:10,538	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-26678.0912	 = Validation score   (-root_mean_squared_error)
# 	39.43s	 = Training   runtime
# 	11.83s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 897.46s of the 4483.34s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.68, 'LightGBM_BAG_L1': 0.12, 'LightGBMLarge_BAG_L1': 0.12, 'RandomForestMSE_BAG_L1': 0.08}
# 	-26662.4916	 = Validation score   (-root_mean_squared_error)
# 	0.94s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting 106 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 4482.33s of the 4482.22s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.87%)
# 	-26664.6131	 = Validation score   (-root_mean_squared_error)
# 	32.97s	 = Training   runtime
# 	4.71s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 4444.42s of the 4444.31s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.88%)
# 	-26665.1768	 = Validation score   (-root_mean_squared_error)
# 	26.91s	 = Training   runtime
# 	3.94s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 4412.74s of the 4412.64s of remaining time.
# 	-26787.2346	 = Validation score   (-root_mean_squared_error)
# 	3017.09s	 = Training   runtime
# 	36.34s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1355.14s of the 1355.04s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.19%)
# 	-26662.5973	 = Validation score   (-root_mean_squared_error)
# 	414.82s	 = Training   runtime
# 	0.93s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 935.52s of the 935.42s of remaining time.
# 	-26710.1385	 = Validation score   (-root_mean_squared_error)
# 	301.68s	 = Training   runtime
# 	25.52s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 606.56s of the 606.46s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.49%)
# 	-26664.0163	 = Validation score   (-root_mean_squared_error)
# 	293.63s	 = Training   runtime
# 	8.48s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 307.22s of the 307.11s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.17%)
# 	-26669.4503	 = Validation score   (-root_mean_squared_error)
# 	253.0s	 = Training   runtime
# 	4.49s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 49.05s of the 48.95s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.82%)
# 	Time limit exceeded... Skipping NeuralNetTorch_BAG_L2.
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 26.37s of the 26.26s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.95%)
# 2025-11-29 15:34:12,036	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-11-29 15:34:13,036	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-11-29 15:34:13,040	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-26669.5317	 = Validation score   (-root_mean_squared_error)
# 	29.59s	 = Training   runtime
# 	4.08s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 448.23s of the -8.85s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L2': 0.28, 'NeuralNetFastAI_BAG_L2': 0.28, 'CatBoost_BAG_L1': 0.24, 'LightGBMXT_BAG_L2': 0.12, 'LightGBMLarge_BAG_L1': 0.04, 'RandomForestMSE_BAG_L2': 0.04}
# 	-26661.4227	 = Validation score   (-root_mean_squared_error)
# 	1.39s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 13478.78s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 1146.7 rows/s (98999 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AG_loan_models")

# %%
## -- Get Summary -- 
print(f"-> Total models : {len(predictor.model_names())}")
print(f"-> Best model   : {predictor.model_best}") 

## -- Observe RUN 1 RESULTS -- 
leaderboard = predictor.leaderboard(silent=True)
leaderboard.style.background_gradient(subset=["score_val"], cmap="Spectral")
# Out:
# -> Total models : 18
# -> Best model   : WeightedEnsemble_L3
# <style type="text/css">
# #T_068d8_row0_col1 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_068d8_row1_col1 {
#   background-color: #5c51a3;
#   color: #f1f1f1;
# }
# #T_068d8_row2_col1 {
#   background-color: #5b53a4;
#   color: #f1f1f1;
# }
# #T_068d8_row3_col1 {
#   background-color: #5758a6;
#   color: #f1f1f1;
# }
# #T_068d8_row4_col1 {
#   background-color: #555aa7;
#   color: #f1f1f1;
# }
# #T_068d8_row5_col1, #T_068d8_row6_col1 {
#   background-color: #545ca8;
#   color: #f1f1f1;
# }
# #T_068d8_row7_col1 {
#   background-color: #466eb1;
#   color: #f1f1f1;
# }
# #T_068d8_row8_col1 {
#   background-color: #4471b2;
#   color: #f1f1f1;
# }
# #T_068d8_row9_col1 {
#   background-color: #358bbc;
#   color: #f1f1f1;
# }
# #T_068d8_row10_col1 {
#   background-color: #3b92b9;
#   color: #f1f1f1;
# }
# #T_068d8_row11_col1 {
#   background-color: #50a9af;
#   color: #f1f1f1;
# }
# #T_068d8_row12_col1 {
#   background-color: #8cd1a4;
#   color: #000000;
# }
# #T_068d8_row13_col1 {
#   background-color: #bfe5a0;
#   color: #000000;
# }
# #T_068d8_row14_col1 {
#   background-color: #caea9e;
#   color: #000000;
# }
# #T_068d8_row15_col1 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_068d8_row16_col1 {
#   background-color: #cd364d;
#   color: #f1f1f1;
# }
# #T_068d8_row17_col1 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_068d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_068d8_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_068d8_level0_col1" class="col_heading level0 col1" >score_val</th>
#       <th id="T_068d8_level0_col2" class="col_heading level0 col2" >eval_metric</th>
#       <th id="T_068d8_level0_col3" class="col_heading level0 col3" >pred_time_val</th>
#       <th id="T_068d8_level0_col4" class="col_heading level0 col4" >fit_time</th>
#       <th id="T_068d8_level0_col5" class="col_heading level0 col5" >pred_time_val_marginal</th>
#       <th id="T_068d8_level0_col6" class="col_heading level0 col6" >fit_time_marginal</th>
#       <th id="T_068d8_level0_col7" class="col_heading level0 col7" >stack_level</th>
#       <th id="T_068d8_level0_col8" class="col_heading level0 col8" >can_infer</th>
#       <th id="T_068d8_level0_col9" class="col_heading level0 col9" >fit_order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_068d8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_068d8_row0_col0" class="data row0 col0" >WeightedEnsemble_L3</td>
#       <td id="T_068d8_row0_col1" class="data row0 col1" >-26661.422705</td>
#       <td id="T_068d8_row0_col2" class="data row0 col2" >root_mean_squared_error</td>
#       <td id="T_068d8_row0_col3" class="data row0 col3" >159.898088</td>
#       <td id="T_068d8_row0_col4" class="data row0 col4" >12609.923035</td>
#       <td id="T_068d8_row0_col5" class="data row0 col5" >0.011014</td>
#       <td id="T_068d8_row0_col6" class="data row0 col6" >1.392445</td>
#       <td id="T_068d8_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_068d8_row0_col8" class="data row0 col8" >True</td>
#       <td id="T_068d8_row0_col9" class="data row0 col9" >18</td>
#     </tr>
#     <tr>
#       <th id="T_068d8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_068d8_row1_col0" class="data row1 col0" >WeightedEnsemble_L2</td>
#       <td id="T_068d8_row1_col1" class="data row1 col1" >-26662.491640</td>
#       <td id="T_068d8_row1_col2" class="data row1 col2" >root_mean_squared_error</td>
#       <td id="T_068d8_row1_col3" class="data row1 col3" >62.776675</td>
#       <td id="T_068d8_row1_col4" class="data row1 col4" >7321.607541</td>
#       <td id="T_068d8_row1_col5" class="data row1 col5" >0.014820</td>
#       <td id="T_068d8_row1_col6" class="data row1 col6" >0.940949</td>
#       <td id="T_068d8_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_068d8_row1_col8" class="data row1 col8" >True</td>
#       <td id="T_068d8_row1_col9" class="data row1 col9" >9</td>
#     </tr>
#     <tr>
#       <th id="T_068d8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_068d8_row2_col0" class="data row2 col0" >CatBoost_BAG_L2</td>
#       <td id="T_068d8_row2_col1" class="data row2 col1" >-26662.597294</td>
#       <td id="T_068d8_row2_col2" class="data row2 col2" >root_mean_squared_error</td>
#       <td id="T_068d8_row2_col3" class="data row2 col3" >110.360631</td>
#       <td id="T_068d8_row2_col4" class="data row2 col4" >9264.838419</td>
#       <td id="T_068d8_row2_col5" class="data row2 col5" >0.934069</td>
#       <td id="T_068d8_row2_col6" class="data row2 col6" >414.821995</td>
#       <td id="T_068d8_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_068d8_row2_col8" class="data row2 col8" >True</td>
#       <td id="T_068d8_row2_col9" class="data row2 col9" >13</td>
#     </tr>
#     <tr>
#       <th id="T_068d8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_068d8_row3_col0" class="data row3 col0" >NeuralNetFastAI_BAG_L2</td>
#       <td id="T_068d8_row3_col1" class="data row3 col1" >-26664.016339</td>
#       <td id="T_068d8_row3_col2" class="data row3 col2" >root_mean_squared_error</td>
#       <td id="T_068d8_row3_col3" class="data row3 col3" >117.909741</td>
#       <td id="T_068d8_row3_col4" class="data row3 col4" >9143.647476</td>
#       <td id="T_068d8_row3_col5" class="data row3 col5" >8.483179</td>
#       <td id="T_068d8_row3_col6" class="data row3 col6" >293.631052</td>
#       <td id="T_068d8_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_068d8_row3_col8" class="data row3 col8" >True</td>
#       <td id="T_068d8_row3_col9" class="data row3 col9" >15</td>
#     </tr>
#     <tr>
#       <th id="T_068d8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_068d8_row4_col0" class="data row4 col0" >LightGBMXT_BAG_L2</td>
#       <td id="T_068d8_row4_col1" class="data row4 col1" >-26664.613113</td>
#       <td id="T_068d8_row4_col2" class="data row4 col2" >root_mean_squared_error</td>
#       <td id="T_068d8_row4_col3" class="data row4 col3" >114.133661</td>
#       <td id="T_068d8_row4_col4" class="data row4 col4" >8882.984138</td>
#       <td id="T_068d8_row4_col5" class="data row4 col5" >4.707098</td>
#       <td id="T_068d8_row4_col6" class="data row4 col6" >32.967713</td>
#       <td id="T_068d8_row4_col7" class="data row4 col7" >2</td>
#       <td id="T_068d8_row4_col8" class="data row4 col8" >True</td>
#       <td id="T_068d8_row4_col9" class="data row4 col9" >10</td>
#     </tr>
#     <tr>
#       <th id="T_068d8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_068d8_row5_col0" class="data row5 col0" >CatBoost_BAG_L1</td>
#       <td id="T_068d8_row5_col1" class="data row5 col1" >-26664.953234</td>
#       <td id="T_068d8_row5_col2" class="data row5 col2" >root_mean_squared_error</td>
#       <td id="T_068d8_row5_col3" class="data row5 col3" >11.922126</td>
#       <td id="T_068d8_row5_col4" class="data row5 col4" >6610.692135</td>
#       <td id="T_068d8_row5_col5" class="data row5 col5" >11.922126</td>
#       <td id="T_068d8_row5_col6" class="data row5 col6" >6610.692135</td>
#       <td id="T_068d8_row5_col7" class="data row5 col7" >1</td>
#       <td id="T_068d8_row5_col8" class="data row5 col8" >True</td>
#       <td id="T_068d8_row5_col9" class="data row5 col9" >4</td>
#     </tr>
#     <tr>
#       <th id="T_068d8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_068d8_row6_col0" class="data row6 col0" >LightGBM_BAG_L2</td>
#       <td id="T_068d8_row6_col1" class="data row6 col1" >-26665.176759</td>
#       <td id="T_068d8_row6_col2" class="data row6 col2" >root_mean_squared_error</td>
#       <td id="T_068d8_row6_col3" class="data row6 col3" >113.369243</td>
#       <td id="T_068d8_row6_col4" class="data row6 col4" >8876.924917</td>
#       <td id="T_068d8_row6_col5" class="data row6 col5" >3.942680</td>
#       <td id="T_068d8_row6_col6" class="data row6 col6" >26.908493</td>
#       <td id="T_068d8_row6_col7" class="data row6 col7" >2</td>
#       <td id="T_068d8_row6_col8" class="data row6 col8" >True</td>
#       <td id="T_068d8_row6_col9" class="data row6 col9" >11</td>
#     </tr>
#     <tr>
#       <th id="

# %%
## -- RUN 2: Use original data as extra learning input --
# predictor.fit_pseudolabel(
#                 orig,
#                 use_ensemble = True,
#                 fit_ensemble = True,
#                 time_limit   = 3600*5,
#                 ag_args_fit  = {'num_cpus': os.cpu_count() - 1},
# )

# %%
## -- Get Summary -- 
# print(f"""
#     # {'█'*5}| Total models : {len(predictor.model_names())}
#     # {'█'*5}| Best model   : {predictor.model_best}
#         """)

# # -- Observe RUN 2 RESULTS --
# leaderboard = predictor.leaderboard(silent=True)
# display(leaderboard.style.background_gradient(subset=["score_val"], cmap="Spectral"))

# %%
## -- Create folder directory to save predictions --
SAVE_PATH = '/kaggle/working/AG_loan_predictions/'
# !mkdir {SAVE_PATH}

# %%
## -- Predictions for {SELECTED FEATURE} --
oof_ = predictor.predict_oof(train_data=train)
np.save(f"{SAVE_PATH}oof_AG_on_{TARGET}.npy", oof_)

preds_ = predictor.predict(test)
np.save(f"{SAVE_PATH}pred_AG_on_{TARGET}.npy", preds_)

oof_[:5], preds_[:5]
# Out:
# (0    46192.531250
#  1    46792.121094
#  2    48629.453125
#  3    47347.765625
#  4    50169.281250
#  Name: annual_income, dtype: float32,
#  0    48696.320312
#  1    47121.203125
#  2    44637.964844
#  3    50373.917969
#  4    46359.617188
#  Name: annual_income, dtype: float32)

# %%
predictor.plot_ensemble_model(filename='ensemble_model.png')
display(Image(f'{MODELS_PATH}ensemble_model.png'))

# %%
# !zip -r /kaggle/working/AG_accident_models /kaggle/working/AG_accident_models.zip
# !zip -r {FOLDER}{NAME_EXT}.zip /kaggle/working/{FOLDER}{NAME_EXT}

# %%
## -- Extract model scores --
result_ = dict(zip(leaderboard['model'], leaderboard['score_val']))
result_df = pd.DataFrame.from_dict(result_, orient='index').sort_values(0)

max_score = result_df.max().item()
min_score = result_df.min().item()

## -- PLOT MODELS & SCORES --
plt.figure(figsize=(18, 15))
plt.stem(
    result_df.index,
    result_df[0],
    orientation = 'horizontal',
    bottom = min_score - 0.0055,
    markerfmt = 'C3o'
)
plt.xlim(min_score - 0.006, max_score + 0.005)
plt.xlabel('Score')
plt.title('-- Scores of Models --', fontsize=15)

for i, value in enumerate(result_df[0]):
    plt.text(value+1e-3, i, f'{abs(value):.5f}', ha='left', va='center', fontdict=dict(size=12))

plt.grid(True, axis='x')
plt.tight_layout()
plt.show()

# %%
# predictor.model_names()

# %%
# ## -- Permutation Feature Importances --
# feat_imp = predictor.feature_importance(
#                         data = X_test,
#                         # time_limit = 3600,
#                         # model = 'LightGBM_BAG_L1',
#                         # features = None,
#                         # feature_stage = 'transformed',
#                         # subsample_size = 5000,
#                         # num_shuffle_sets = 10,
#                         # include_confidence_band = True,
#                         confidence_level = 0.95,
#                         # silent = False
# ) 

# feat_imp.style.background_gradient(subset=["importance"], cmap="Spectral")

# %%
# plt.figure(figsize=(18, 35))
# sns.barplot(data=feat_imp, y=feat_imp.index, x=feat_imp.importance)
# plt.tick_params(axis='y', which='major', labelcolor='r')
# plt.title("Top Features by Permutation")
# plt.tight_layout()
# plt.show()

# %%
## -- OPTIONAL: Remove stored files --
# !rm -r {MODELS_PATH}

# %%
print(f"""
{'-'*48}
{'█'*5} | - AUTOGLUON NOTEBOOK COMPLETE! - | {'█'*5}
{'-'*48}
""")
# Out:
# ------------------------------------------------
# █████ | - AUTOGLUON NOTEBOOK COMPLETE! - | █████
# ------------------------------------------------
