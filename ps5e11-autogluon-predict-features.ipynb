# %%
# %%capture cap
# !pip install -qq ipywidgets
# !pip install -qq autogluon scikit-learn==1.5.2 
# !apt-get install -qq -y graphviz graphviz-dev && pip install -q pydot
# !pip install -qq pygraphviz
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 76.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.9/454.9 kB 23.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.3/487.3 kB 23.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.7/189.7 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.8/285.8 kB 14.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.5/280.5 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 51.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 20.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 MB 25.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.4/354.4 kB 16.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 56.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 85.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 45.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 32.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 72.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.5/963.5 kB 41.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 98.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 21.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 74.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 79.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 98.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 2.3 MB/s eta 0:00:00
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Building wheel for seqeval (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# Selecting previously unselected package libgtk2.0-common.
# (Reading database ... 128639 files and directories currently installed.)
# Preparing to unpack .../0-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../1-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../2-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../3-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libxdot4:amd64.
# Preparing to unpack .../4-libxdot4_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgvc6-plugins-gtk.
# Preparing to unpack .../5-libgvc6-plugins-gtk_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgraphviz-dev:amd64.
# Preparing to unpack .../6-libgraphviz-dev_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../7-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.0/106.0 kB 4.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for pygraphviz (pyproject.toml) ... done

# %%
import torch
import os
import pydot

import random
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
from time import time, sleep
from itertools import combinations

from IPython.display import display, Image
import matplotlib.pyplot as plt
import seaborn as sns

import warnings

warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')

## -- Set Global Seed --
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

pd.set_option('display.max_columns', 500)
plt.style.use("ggplot")

## -- Ansi color codes --
COLOR = '\033[32m'
RESET = '\033[0m'

print("Packages import succesful!")
# Out:
# Packages import succesful!

# %%
### Load Data ###
PATH = "/kaggle/input/playground-series-s5e11/"
submit = pd.read_csv(PATH+"sample_submission.csv")

list_of_targets = ["debt_to_income_ratio", "credit_score", "interest_rate", "employment_status"]
TARGET = list_of_targets[2]

train = pd.read_csv(PATH+"train.csv").drop(['id', "loan_paid_back"], axis=1)
test = pd.read_csv(PATH+"test.csv").drop(['id', TARGET], axis=1)

# ## -- Convert target to float for regression --
# train[TARGET] = train[TARGET].astype(np.float32)

NUMS = test.select_dtypes(include='number').columns.tolist()
CATS = test.select_dtypes(exclude='number').columns.tolist()
BASE = NUMS + CATS

for (name, df) in dict(Train=train, Test=test).items():
    print(f"{name} shape: {df.shape}")

print(f"\nTotal Numerical: {len(NUMS)}")
print(f"Total Categorical: {len(CATS)}")
print(f"Total base features: {len(BASE)}")
# Out:
# Train shape: (593994, 11)
# Test shape: (254569, 10)
#
# Total Numerical: 4
# Total Categorical: 6
# Total base features: 10

# %%
# !rm -r /kaggle/working/AG_loan_models

# %%
from autogluon.tabular import TabularPredictor

# %%
MODELS_PATH = "./AG_loan_models/"

predictor = TabularPredictor(
                label = TARGET,
         problem_type = "regression",
         #  eval_metric = "roc_auc",
                 path = MODELS_PATH,
    ).fit(
                   train_data = train,
                      presets = "best",
                num_bag_folds = 6,
             # dynamic_stacking = False,
             # num_stack_levels = 1,
                   time_limit = 3600*5,
                   # auto_stack = False,
                 # num_bag_sets = 2,
                  # ag_args_fit = {'num_cpus': os.cpu_count()},
)
# Out:
# Preset alias specified: 'best' maps to 'best_quality'.
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.11.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Sat Sep 27 10:16:09 UTC 2025
# CPU Count:          4
# Memory Avail:       29.94 GB / 31.35 GB (95.5%)
# Disk Space Avail:   19.50 GB / 19.52 GB (99.9%)
# ===================================================
# Presets specified: ['best']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=6, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 4500s of the 18000s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-11-29 03:43:57,285	INFO worker.py:1843 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho"
# (_dystack pid=414) Running DyStack sub-fit ...
# (_dystack pid=414) Beginning AutoGluon training ... Time limit = 4495s
# (_dystack pid=414) AutoGluon will save models to "/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho"
# (_dystack pid=414) Train Data Rows:    527994
# (_dystack pid=414) Train Data Columns: 10
# (_dystack pid=414) Label Column:       interest_rate
# (_dystack pid=414) Problem Type:       regression
# (_dystack pid=414) Preprocessing data ...
# (_dystack pid=414) Using Feature Generators to preprocess the data ...
# (_dystack pid=414) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=414) 	Available Memory:                    30102.10 MB
# (_dystack pid=414) 	Train Data (Original)  Memory Usage: 210.58 MB (0.7% of available memory)
# (_dystack pid=414) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=414) 	Stage 1 Generators:
# (_dystack pid=414) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=414) 	Stage 2 Generators:
# (_dystack pid=414) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=414) 	Stage 3 Generators:
# (_dystack pid=414) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=414) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=414) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=414) 	Stage 4 Generators:
# (_dystack pid=414) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=414) 	Stage 5 Generators:
# (_dystack pid=414) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=414) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=414) 		('float', [])  : 3 | ['annual_income', 'debt_to_income_ratio', 'loan_amount']
# (_dystack pid=414) 		('int', [])    : 1 | ['credit_score']
# (_dystack pid=414) 		('object', []) : 6 | ['gender', 'marital_status', 'education_level', 'employment_status', 'loan_purpose', ...]
# (_dystack pid=414) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=414) 		('category', []) : 6 | ['gender', 'marital_status', 'education_level', 'employment_status', 'loan_purpose', ...]
# (_dystack pid=414) 		('float', [])    : 3 | ['annual_income', 'debt_to_income_ratio', 'loan_amount']
# (_dystack pid=414) 		('int', [])      : 1 | ['credit_score']
# (_dystack pid=414) 	2.2s = Fit runtime
# (_dystack pid=414) 	10 features in original data used to generate 10 features in processed data.
# (_dystack pid=414) 	Train Data (Processed) Memory Usage: 19.14 MB (0.1% of available memory)
# (_dystack pid=414) Data preprocessing and feature engineering runtime = 2.33s ...
# (_dystack pid=414) AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# (_dystack pid=414) 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# (_dystack pid=414) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=414) Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=414) User-specified model hyperparameters to be fit:
# (_dystack pid=414) {
# (_dystack pid=414) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=414) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=414) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=414) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=414) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=414) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=414) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=414) }
# (_dystack pid=414) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=414) Fitting 106 L1 models, fit_strategy="sequential" ...
# (_dystack pid=414) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2994.51s of the 4492.87s of remaining time.
# (_dystack pid=414) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.53%)
# (_dystack pid=414) 	-1.6907	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=414) 	69.89s	 = Training   runtime
# (_dystack pid=414) 	25.95s	 = Validation runtime
# (_dystack pid=414) Fitting model: LightGBM_BAG_L1 ... Training model for up to 2913.81s of the 4412.17s of remaining time.
# (_dystack pid=414) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.56%)
# (_dystack pid=414) 	-1.6867	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=414) 	43.08s	 = Training   runtime
# (_dystack pid=414) 	11.14s	 = Validation runtime
# (_dystack pid=414) Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 2863.97s of the 4362.33s of remaining time.
# (_dystack pid=414) 	-1.6949	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=414) 	535.83s	 = Training   runtime
# (_dystack pid=414) 	31.86s	 = Validation runtime
# (_dystack pid=414) Fitting model: CatBoost_BAG_L1 ... Training model for up to 2293.05s of the 3791.41s of remaining time.
# (_dystack pid=414) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.84%)
# (_ray_fit pid=1436) 	Ran out of time, early stopping on iteration 753.
# (_ray_fit pid=1767) 	Ran out of time, early stopping on iteration 1173. [repeated 4x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_dystack pid=414) 	-1.687	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=414) 	1841.98s	 = Training   runtime
# (_dystack pid=414) 	3.41s	 = Validation runtime
# (_dystack pid=414) Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 446.82s of the 1945.18s of remaining time.
# (_dystack pid=414) 	-1.6905	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=414) 	126.66s	 = Training   runtime
# (_dystack pid=414) 	23.13s	 = Validation runtime
# (_dystack pid=414) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 295.24s of the 1793.60s of remaining time.
# (_ray_fit pid=1803) 	Ran out of time, early stopping on iteration 1155.
# (_dystack pid=414) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.89%)
# (_dystack pid=414) 	-1.6918	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=414) 	204.97s	 = Training   runtime
# (_dystack pid=414) 	7.86s	 = Validation runtime
# (_dystack pid=414) Fitting model: XGBoost_BAG_L1 ... Training model for up to 85.44s of the 1583.81s of remaining time.
# (_dystack pid=414) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.71%)
# (_dystack pid=414) 	-1.8066	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=414) 	77.48s	 = Training   runtime
# (_dystack pid=414) 	2.37s	 = Validation runtime
# (_dystack pid=414) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 3.65s of the 1502.02s of remaining time.
# (_dystack pid=414) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.51%)
# (_dystack pid=414) 	Time limit exceeded... Skipping NeuralNetTorch_BAG_L1.
# (_dystack pid=414) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 1475.01s of remaining time.
# (_dystack pid=414) 	Ensemble Weights: {'LightGBM_BAG_L1': 0.5, 'CatBoost_BAG_L1': 0.35, 'RandomForestMSE_BAG_L1': 0.1, 'ExtraTreesMSE_BAG_L1': 0.05}
# (_dystack pid=414) 	-1.6864	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=414) 	1.73s	 = Training   runtime
# (_dystack pid=414) 	0.01s	 = Validation runtime
# (_dystack pid=414) Fitting 106 L2 models, fit_strategy="sequential" ...
# (_dystack pid=414) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1473.21s of the 1473.10s of remaining time.
# (_dystack pid=414) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.84%)
# (_dystack pid=414) 	-1.6875	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=414) 	47.73s	 = Training   runtime
# (_dystack pid=414) 	9.56s	 = Validation runtime
# (_dystack pid=414) Fitting model: LightGBM_BAG_L2 ... Training model for up to 1420.02s of the 1419.91s of remaining time.
# (_dystack pid=414) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.85%)
# (_dystack pid=414) 	-1.6865	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=414) 	35.2s	 = Training   runtime
# (_dystack pid=414) 	5.4s	 = Validation runtime
# (_dystack pid=414) Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 1380.12s of the 1380.01s of remaining time.
# (_dystack pid=414) 	Warning: Reducing model 'n_estimators' from 300 -> 210 due to low time. Expected time usage reduced from 1964.5s -> 1379.5s...
# (_dystack pid=414) 	-1.6916	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=414) 	1346.15s	 = Training   runtime
# (_dystack pid=414) 	23.36s	 = Validation runtime
# (_dystack pid=414) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the 8.20s of remaining time.
# (_dystack pid=414) 	Ensemble Weights: {'LightGBM_BAG_L1': 0.28, 'LightGBM_BAG_L2': 0.24, 'CatBoost_BAG_L1': 0.2, 'RandomForestMSE_BAG_L2': 0.2, 'RandomForestMSE_BAG_L1': 0.04, 'ExtraTreesMSE_BAG_L1': 0.04}
# (_dystack pid=414) 	-1.6859	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=414) 	0.72s	 = Training   runtime
# (_dystack pid=414) 	0.01s	 = Validation runtime
# (_dystack pid=414) AutoGluon training complete, total runtime = 4487.82s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 1271.7 rows/s (87999 batch size)
# (_dystack pid=414) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho")
# (_dystack pid=414) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=2809, ip=172.19.2.2)
# (_dystack pid=414)   File "/usr/local/lib/python3.11/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
# (_dystack pid=414)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=414)   File "/usr/local/lib/python3.11/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=414)     out = self._fit(**kwargs)
# (_dystack pid=414)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=414)   File "/usr/local/lib/python3.11/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 247, in _fit
# (_dystack pid=414)     raise TimeLimitExceeded
# (_dystack pid=414) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=414) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=2807, ip=172.19.2.2)
# (_dystack pid=414)   File "/usr/local/lib/python3.11/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
# (_dystack pid=414)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=414)   File "/usr/local/lib/python3.11/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=414)     out = self._fit(**kwargs)
# (_dystack pid=414)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=414)   File "/usr/local/lib/python3.11/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 247, in _fit
# (_dystack pid=414)     raise TimeLimitExceeded
# (_dystack pid=414) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=414) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=2806, ip=172.19.2.2)
# (_dystack pid=414)   File "/usr/local/lib/python3.11/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
# (_dystack pid=414)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=414)   File "/usr/local/lib/python3.11/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=414)     out = self._fit(**kwargs)
# (_dystack pid=414)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=414)   File "/usr/local/lib/python3.11/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 247, in _fit
# (_dystack pid=414)     raise TimeLimitExceeded
# (_dystack pid=414) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=414) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                      model  score_holdout  score_val              eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0          LightGBM_BAG_L2      -1.690966  -1.686467  root_mean_squared_error       34.268675     111.120348  2935.091867                 1.452729                5.402730          35.202284            2       True         10
# 1      WeightedEnsemble_L3      -1.691096  -1.685934  root_mean_squared_error       37.130397     134.492759  4281.958042                 0.006138                0.009210           0.719998            3       True         12
# 2      WeightedEnsemble_L2      -1.691215  -1.686380  root_mean_squared_error       14.820874      69.543996  2549.277962                 0.004361                0.013314           1.728576            2       True          8
# 3          LightGBM_BAG_L1      -1.691509  -1.686719  root_mean_squared_error        3.568759      11.137002    43.080295                 3.568759               11.137002          43.080295            1       True          2
# 4          CatBoost_BAG_L1      -1.691744  -1.686967  root_mean_squared_error        1.716344       3.410498  1841.975902                 1.716344                3.410498        1841.975902            1       True          4
# 5        LightGBMXT_BAG_L2      -1.691874  -1.687520  root_mean_squared_error       35.901678     115.277233  2947.615370                 3.085733                9.559615          47.725786            2       True          9
# 6     ExtraTreesMSE_BAG_L1      -1.693987  -1.690542  root_mean_squared_error        3.484308      23.125885   126.659129                 3.484308               23.125885         126.659129            1       True          5
# 7        LightGBMXT_BAG_L1      -1.695278  -1.690745  root_mean_squared_error       12.217243      25.951915    69.890049                12.217243               25.951915          69.890049            1       True          1
# 8   RandomForestMSE_BAG_L2      -1.695626  -1.691645  root_mean_squared_error       35.671530     129.080819  4246.035760                 2.855584               23.363201        1346.146177            2       True         11
# 9   NeuralNetFastAI_BAG_L1      -1.696143  -1.691785  root_mean_squared_error        4.528886       7.862884   204.969776                 4.528886                7.862884         204.969776            1       True          6
# 10  RandomForestMSE_BAG_L1      -1.697950  -1.694898  root_mean_squared_error        6.047102      31.857296   535.834060                 6.047102               31.857296         535.834060            1       True          3
# 11          XGBoost_BAG_L1      -1.809976  -1.806556  root_mean_squared_error        1.253302       2.372137    77.480372                 1.253302                2.372137          77.480372            1       True          7
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	4537s	 = DyStack   runtime |	13463s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 13463s
# AutoGluon will save models to "/kaggle/working/AG_loan_models"
# Train Data Rows:    593994
# Train Data Columns: 10
# Label Column:       interest_rate
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    29342.67 MB
# 	Train Data (Original)  Memory Usage: 236.92 MB (0.8% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 3 | ['annual_income', 'debt_to_income_ratio', 'loan_amount']
# 		('int', [])    : 1 | ['credit_score']
# 		('object', []) : 6 | ['gender', 'marital_status', 'education_level', 'employment_status', 'loan_purpose', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 6 | ['gender', 'marital_status', 'education_level', 'employment_status', 'loan_purpose', ...]
# 		('float', [])    : 3 | ['annual_income', 'debt_to_income_ratio', 'loan_amount']
# 		('int', [])      : 1 | ['credit_score']
# 	2.8s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 21.53 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 3.2s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 8970.78s of the 13459.52s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.48%)
# 	-1.6911	 = Validation score   (-root_mean_squared_error)
# 	77.88s	 = Training   runtime
# 	31.55s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 8884.52s of the 13373.26s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.48%)
# 	-1.687	 = Validation score   (-root_mean_squared_error)
# 	47.24s	 = Training   runtime
# 	13.22s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 8831.16s of the 13319.90s of remaining time.
# 	-1.6944	 = Validation score   (-root_mean_squared_error)
# 	642.15s	 = Training   runtime
# 	31.75s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 8155.95s of the 12644.69s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.79%)
# 	-1.6864	 = Validation score   (-root_mean_squared_error)
# 	6552.53s	 = Training   runtime
# 	13.04s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 1597.93s of the 6086.67s of remaining time.
# 	-1.6905	 = Validation score   (-root_mean_squared_error)
# 	152.82s	 = Training   runtime
# 	25.31s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1417.81s of the 5906.55s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.82%)
# 	-1.6919	 = Validation score   (-root_mean_squared_error)
# 	957.52s	 = Training   runtime
# 	9.43s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 454.86s of the 4943.60s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.65%)
# 	-1.6926	 = Validation score   (-root_mean_squared_error)
# 	377.72s	 = Training   runtime
# 	4.26s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 72.24s of the 4560.98s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.46%)
# 	Time limit exceeded... Skipping NeuralNetTorch_BAG_L1.
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 53.80s of the 4542.54s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.55%)
# 2025-11-29 07:28:17,039	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-11-29 07:28:17,041	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-11-29 07:28:17,042	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-1.6871	 = Validation score   (-root_mean_squared_error)
# 	52.25s	 = Training   runtime
# 	15.72s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 897.08s of the 4483.88s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.619, 'LightGBM_BAG_L1': 0.143, 'LightGBMLarge_BAG_L1': 0.143, 'RandomForestMSE_BAG_L1': 0.048, 'ExtraTreesMSE_BAG_L1': 0.048}
# 	-1.6862	 = Validation score   (-root_mean_squared_error)
# 	0.79s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting 106 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 4483.02s of the 4482.94s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.87%)
# 	-1.6873	 = Validation score   (-root_mean_squared_error)
# 	54.15s	 = Training   runtime
# 	10.88s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 4423.13s of the 4423.05s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.88%)
# 	-1.6864	 = Validation score   (-root_mean_squared_error)
# 	39.05s	 = Training   runtime
# 	4.79s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 4378.88s of the 4378.80s of remaining time.
# 	-1.6902	 = Validation score   (-root_mean_squared_error)
# 	2650.16s	 = Training   runtime
# 	38.76s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1686.72s of the 1686.64s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.20%)
# 	-1.6866	 = Validation score   (-root_mean_squared_error)
# 	1354.22s	 = Training   runtime
# 	2.95s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 326.74s of the 326.66s of remaining time.
# 	-1.6869	 = Validation score   (-root_mean_squared_error)
# 	280.01s	 = Training   runtime
# 	28.65s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 15.49s of the 15.40s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.50%)
# 	Time limit exceeded... Skipping NeuralNetFastAI_BAG_L2.
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 448.30s of the -2.08s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.357, 'ExtraTreesMSE_BAG_L2': 0.286, 'RandomForestMSE_BAG_L2': 0.143, 'LightGBM_BAG_L1': 0.071, 'LightGBMLarge_BAG_L1': 0.071, 'LightGBM_BAG_L2': 0.071}
# 	-1.6856	 = Validation score   (-root_mean_squared_error)
# 	1.29s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 13466.2s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 878.0 rows/s (98999 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AG_loan_models")

# %%
## -- Get Summary -- 
print(f"-> Total models : {len(predictor.model_names())}")
print(f"-> Best model   : {predictor.model_best}") 

## -- Observe RUN 1 RESULTS -- 
leaderboard = predictor.leaderboard(silent=True)
leaderboard.style.background_gradient(subset=["score_val"], cmap="Spectral")
# Out:
# -> Total models : 15
# -> Best model   : WeightedEnsemble_L3
# <style type="text/css">
# #T_24f10_row0_col1 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_24f10_row1_col1 {
#   background-color: #4471b2;
#   color: #f1f1f1;
# }
# #T_24f10_row2_col1, #T_24f10_row3_col1 {
#   background-color: #3a7eb8;
#   color: #f1f1f1;
# }
# #T_24f10_row4_col1 {
#   background-color: #378ebb;
#   color: #f1f1f1;
# }
# #T_24f10_row5_col1 {
#   background-color: #47a0b3;
#   color: #f1f1f1;
# }
# #T_24f10_row6_col1 {
#   background-color: #50a9af;
#   color: #f1f1f1;
# }
# #T_24f10_row7_col1 {
#   background-color: #52abae;
#   color: #f1f1f1;
# }
# #T_24f10_row8_col1 {
#   background-color: #60bba8;
#   color: #000000;
# }
# #T_24f10_row9_col1 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_24f10_row10_col1 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_24f10_row11_col1 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_24f10_row12_col1 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_24f10_row13_col1 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_24f10_row14_col1 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_24f10">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24f10_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_24f10_level0_col1" class="col_heading level0 col1" >score_val</th>
#       <th id="T_24f10_level0_col2" class="col_heading level0 col2" >eval_metric</th>
#       <th id="T_24f10_level0_col3" class="col_heading level0 col3" >pred_time_val</th>
#       <th id="T_24f10_level0_col4" class="col_heading level0 col4" >fit_time</th>
#       <th id="T_24f10_level0_col5" class="col_heading level0 col5" >pred_time_val_marginal</th>
#       <th id="T_24f10_level0_col6" class="col_heading level0 col6" >fit_time_marginal</th>
#       <th id="T_24f10_level0_col7" class="col_heading level0 col7" >stack_level</th>
#       <th id="T_24f10_level0_col8" class="col_heading level0 col8" >can_infer</th>
#       <th id="T_24f10_level0_col9" class="col_heading level0 col9" >fit_order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24f10_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_24f10_row0_col0" class="data row0 col0" >WeightedEnsemble_L3</td>
#       <td id="T_24f10_row0_col1" class="data row0 col1" >-1.685643</td>
#       <td id="T_24f10_row0_col2" class="data row0 col2" >root_mean_squared_error</td>
#       <td id="T_24f10_row0_col3" class="data row0 col3" >216.496399</td>
#       <td id="T_24f10_row0_col4" class="data row0 col4" >11830.625345</td>
#       <td id="T_24f10_row0_col5" class="data row0 col5" >0.010878</td>
#       <td id="T_24f10_row0_col6" class="data row0 col6" >1.291198</td>
#       <td id="T_24f10_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_24f10_row0_col8" class="data row0 col8" >True</td>
#       <td id="T_24f10_row0_col9" class="data row0 col9" >15</td>
#     </tr>
#     <tr>
#       <th id="T_24f10_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_24f10_row1_col0" class="data row1 col0" >WeightedEnsemble_L2</td>
#       <td id="T_24f10_row1_col1" class="data row1 col1" >-1.686168</td>
#       <td id="T_24f10_row1_col2" class="data row1 col2" >root_mean_squared_error</td>
#       <td id="T_24f10_row1_col3" class="data row1 col3" >99.055909</td>
#       <td id="T_24f10_row1_col4" class="data row1 col4" >7447.778822</td>
#       <td id="T_24f10_row1_col5" class="data row1 col5" >0.009505</td>
#       <td id="T_24f10_row1_col6" class="data row1 col6" >0.786445</td>
#       <td id="T_24f10_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_24f10_row1_col8" class="data row1 col8" >True</td>
#       <td id="T_24f10_row1_col9" class="data row1 col9" >9</td>
#     </tr>
#     <tr>
#       <th id="T_24f10_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_24f10_row2_col0" class="data row2 col0" >LightGBM_BAG_L2</td>
#       <td id="T_24f10_row2_col1" class="data row2 col1" >-1.686368</td>
#       <td id="T_24f10_row2_col2" class="data row2 col2" >root_mean_squared_error</td>
#       <td id="T_24f10_row2_col3" class="data row2 col3" >149.076640</td>
#       <td id="T_24f10_row2_col4" class="data row2 col4" >8899.162690</td>
#       <td id="T_24f10_row2_col5" class="data row2 col5" >4.794966</td>
#       <td id="T_24f10_row2_col6" class="data row2 col6" >39.048925</td>
#       <td id="T_24f10_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_24f10_row2_col8" class="data row2 col8" >True</td>
#       <td id="T_24f10_row2_col9" class="data row2 col9" >11</td>
#     </tr>
#     <tr>
#       <th id="T_24f10_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_24f10_row3_col0" class="data row3 col0" >CatBoost_BAG_L1</td>
#       <td id="T_24f10_row3_col1" class="data row3 col1" >-1.686389</td>
#       <td id="T_24f10_row3_col2" class="data row3 col2" >root_mean_squared_error</td>
#       <td id="T_24f10_row3_col3" class="data row3 col3" >13.038269</td>
#       <td id="T_24f10_row3_col4" class="data row3 col4" >6552.530873</td>
#       <td id="T_24f10_row3_col5" class="data row3 col5" >13.038269</td>
#       <td id="T_24f10_row3_col6" class="data row3 col6" >6552.530873</td>
#       <td id="T_24f10_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_24f10_row3_col8" class="data row3 col8" >True</td>
#       <td id="T_24f10_row3_col9" class="data row3 col9" >4</td>
#     </tr>
#     <tr>
#       <th id="T_24f10_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_24f10_row4_col0" class="data row4 col0" >CatBoost_BAG_L2</td>
#       <td id="T_24f10_row4_col1" class="data row4 col1" >-1.686624</td>
#       <td id="T_24f10_row4_col2" class="data row4 col2" >root_mean_squared_error</td>
#       <td id="T_24f10_row4_col3" class="data row4 col3" >147.231515</td>
#       <td id="T_24f10_row4_col4" class="data row4 col4" >10214.337138</td>
#       <td id="T_24f10_row4_col5" class="data row4 col5" >2.949840</td>
#       <td id="T_24f10_row4_col6" class="data row4 col6" >1354.223372</td>
#       <td id="T_24f10_row4_col7" class="data row4 col7" >2</td>
#       <td id="T_24f10_row4_col8" class="data row4 col8" >True</td>
#       <td id="T_24f10_row4_col9" class="data row4 col9" >13</td>
#     </tr>
#     <tr>
#       <th id="T_24f10_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_24f10_row5_col0" class="data row5 col0" >ExtraTreesMSE_BAG_L2</td>
#       <td id="T_24f10_row5_col1" class="data row5 col1" >-1.686883</td>
#       <td id="T_24f10_row5_col2" class="data row5 col2" >root_mean_squared_error</td>
#       <td id="T_24f10_row5_col3" class="data row5 col3" >172.928511</td>
#       <td id="T_24f10_row5_col4" class="data row5 col4" >9140.120746</td>
#       <td id="T_24f10_row5_col5" class="data row5 col5" >28.646837</td>
#       <td id="T_24f10_row5_col6" class="data row5 col6" >280.006981</td>
#       <td id="T_24f10_row5_col7" class="data row5 col7" >2</td>
#       <td id="T_24f10_row5_col8" class="data row5 col8" >True</td>
#       <td id="T_24f10_row5_col9" class="data row5 col9" >14</td>
#     </tr>
#     <tr>
#       <th id="T_24f10_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_24f10_row6_col0" class="data row6 col0" >LightGBM_BAG_L1</td>
#       <td id="T_24f10_row6_col1" class="data row6 col1" >-1.687040</td>
#       <td id="T_24f10_row6_col2" class="data row6 col2" >root_mean_squared_error</td>
#       <td id="T_24f10_row6_col3" class="data row6 col3" >13.223742</td>
#       <td id="T_24f10_row6_col4" class="data row6 col4" >47.240536</td>
#       <td id="T_24f10_row6_col5" class="data row6 col5" >13.223742</td>
#       <td id="T_24f10_row6_col6" class="data row6 col6" >47.240536</td>
#       <td id="T_24f10_row6_col7" class="data row6 col7" >1</td>
#       <td id="T_24f10_row6_col8" class="data row6 col8" >True</td>
#       <td id="T_24f10_row6_col9" class="data row6 col9" >2</td>
#     </tr>
#     <tr>
#       <th id="T_24f10_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_24f10_row7_col0" class="data row7 col0" >LightGBMLarge_BAG_L1</td>
#       <td id="T_24f10_row7_col1" class="data row7 col1" >-1.687078</td>
#       <td id="T_24f10_row7_co

# %%
## -- RUN 2: Use original data as extra learning input --
# predictor.fit_pseudolabel(
#                 orig,
#                 use_ensemble = True,
#                 fit_ensemble = True,
#                 time_limit   = 3600*5,
#                 ag_args_fit  = {'num_cpus': os.cpu_count() - 1},
# )

# %%
## -- Get Summary -- 
# print(f"""
#     # {'█'*5}| Total models : {len(predictor.model_names())}
#     # {'█'*5}| Best model   : {predictor.model_best}
#         """)

# # -- Observe RUN 2 RESULTS --
# leaderboard = predictor.leaderboard(silent=True)
# display(leaderboard.style.background_gradient(subset=["score_val"], cmap="Spectral"))

# %%
## -- Create folder directory to save predictions --
SAVE_PATH = '/kaggle/working/AG_loan_predictions/'
# !mkdir {SAVE_PATH}

# %%
## -- Predictions for {SELECTED FEATURE} --
oof_ = predictor.predict_oof(train_data=train)
np.save(f"{SAVE_PATH}oof_AG_on_{TARGET}.npy", oof_)

preds_ = predictor.predict(test)
np.save(f"{SAVE_PATH}pred_AG_on_{TARGET}.npy", preds_)

oof_[:5], preds_[:5]
# Out:
# 2025-11-29 08:44:01,052	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-11-29 08:44:01,058	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-11-29 08:44:02,052	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (0    11.357447
#  1    13.296731
#  2    12.253346
#  3    15.398060
#  4    12.711323
#  Name: interest_rate, dtype: float32,
#  0    13.513354
#  1    11.574545
#  2    13.733728
#  3    12.516803
#  4    12.167187
#  Name: interest_rate, dtype: float32)

# %%
predictor.plot_ensemble_model(filename='ensemble_model.png')
display(Image(f'{MODELS_PATH}ensemble_model.png'))

# %%
# !zip -r /kaggle/working/AG_accident_models /kaggle/working/AG_accident_models.zip
# !zip -r {FOLDER}{NAME_EXT}.zip /kaggle/working/{FOLDER}{NAME_EXT}

# %%
## -- Extract model scores --
result_ = dict(zip(leaderboard['model'], leaderboard['score_val']))
result_df = pd.DataFrame.from_dict(result_, orient='index').sort_values(0)

max_score = result_df.max().item()
min_score = result_df.min().item()

## -- PLOT MODELS & SCORES --
plt.figure(figsize=(18, 15))
plt.stem(
    result_df.index,
    result_df[0],
    orientation = 'horizontal',
    bottom = min_score - 0.0055,
    markerfmt = 'C3o'
)
plt.xlim(min_score - 0.006, max_score + 0.005)
plt.xlabel('Score')
plt.title('-- Scores of Models --', fontsize=15)

for i, value in enumerate(result_df[0]):
    plt.text(value+1e-3, i, f'{abs(value):.5f}', ha='left', va='center', fontdict=dict(size=12))

plt.grid(True, axis='x')
plt.tight_layout()
plt.show()

# %%
# predictor.model_names()

# %%
# ## -- Permutation Feature Importances --
# feat_imp = predictor.feature_importance(
#                         data = X_test,
#                         # time_limit = 3600,
#                         # model = 'LightGBM_BAG_L1',
#                         # features = None,
#                         # feature_stage = 'transformed',
#                         # subsample_size = 5000,
#                         # num_shuffle_sets = 10,
#                         # include_confidence_band = True,
#                         confidence_level = 0.95,
#                         # silent = False
# ) 

# feat_imp.style.background_gradient(subset=["importance"], cmap="Spectral")

# %%
# plt.figure(figsize=(18, 35))
# sns.barplot(data=feat_imp, y=feat_imp.index, x=feat_imp.importance)
# plt.tick_params(axis='y', which='major', labelcolor='r')
# plt.title("Top Features by Permutation")
# plt.tight_layout()
# plt.show()

# %%
## -- OPTIONAL: Remove stored files --
# !rm -r {MODELS_PATH}

# %%
print(f"""
{'-'*48}
{'█'*5} | - AUTOGLUON NOTEBOOK COMPLETE! - | {'█'*5}
{'-'*48}
""")
# Out:
# ------------------------------------------------
# █████ | - AUTOGLUON NOTEBOOK COMPLETE! - | █████
# ------------------------------------------------
