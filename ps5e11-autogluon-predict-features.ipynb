# %%
# %%capture cap
# !pip install -qq ipywidgets
# !pip install -qq autogluon scikit-learn==1.5.2 
# !apt-get install -qq -y graphviz graphviz-dev && pip install -q pydot
# !pip install -qq pygraphviz
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 98.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.9/454.9 kB 27.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.3/487.3 kB 28.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.7/189.7 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.8/285.8 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.5/280.5 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 56.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 44.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 24.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 MB 26.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.4/354.4 kB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 69.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 105.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 84.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 32.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.5/963.5 kB 53.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 115.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 30.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 19.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 78.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 92.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 90.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 27.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 3.3 MB/s eta 0:00:00
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Building wheel for seqeval (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# Selecting previously unselected package libgtk2.0-common.
# (Reading database ... 128639 files and directories currently installed.)
# Preparing to unpack .../0-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../1-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../2-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../3-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libxdot4:amd64.
# Preparing to unpack .../4-libxdot4_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgvc6-plugins-gtk.
# Preparing to unpack .../5-libgvc6-plugins-gtk_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgraphviz-dev:amd64.
# Preparing to unpack .../6-libgraphviz-dev_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../7-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.0/106.0 kB 2.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for pygraphviz (pyproject.toml) ... done

# %%
import torch
import os
import pydot

import random
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
from time import time, sleep
from itertools import combinations

from IPython.display import display, Image
import matplotlib.pyplot as plt
import seaborn as sns

import warnings

warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')

## -- Set Global Seed --
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

pd.set_option('display.max_columns', 500)
plt.style.use("ggplot")

## -- Ansi color codes --
COLOR = '\033[32m'
RESET = '\033[0m'

print("Packages import succesful!")
# Out:
# Packages import succesful!

# %%
### Load Data ###
PATH = "/kaggle/input/playground-series-s5e11/"
submit = pd.read_csv(PATH+"sample_submission.csv")

list_of_targets = [
    'debt_to_income_ratio',
    'credit_score',
    'interest_rate',
    'employment_status',
    'annual_income',
    'loan_amount',
    'education_level',
    'grade_subgrade',
    'loan_purpose',
    'marital_status',
    'gender',
]

TARGET = list_of_targets[6]

train = pd.read_csv(PATH+"train.csv").drop(['id', "loan_paid_back"], axis=1)
test = pd.read_csv(PATH+"test.csv").drop(['id', TARGET], axis=1)

# ## -- Convert target to float for regression --
# train[TARGET] = train[TARGET].astype(np.float32)

NUMS = test.select_dtypes(include='number').columns.tolist()
CATS = test.select_dtypes(exclude='number').columns.tolist()
BASE = NUMS + CATS

for (name, df) in dict(Train=train, Test=test).items():
    print(f"{name} shape: {df.shape}")

print(f"\nTotal Numerical: {len(NUMS)}")
print(f"Total Categorical: {len(CATS)}")
print(f"Total base features: {len(BASE)}")
# Out:
# Train shape: (593994, 11)
# Test shape: (254569, 10)
#
# Total Numerical: 5
# Total Categorical: 5
# Total base features: 10

# %%
# !rm -r /kaggle/working/AG_loan_models

# %%
from autogluon.tabular import TabularPredictor

# %%
MODELS_PATH = "./AG_loan_models/"

predictor = TabularPredictor(
                label = TARGET,
         # problem_type = "regression",
          eval_metric = "roc_auc_ovo_macro",
                 path = MODELS_PATH,
    ).fit(
                   train_data = train,
                      presets = "best",
                num_bag_folds = 6,
             # dynamic_stacking = False,
             # num_stack_levels = 1,
                   time_limit = 3600*5,
                   # auto_stack = False,
                 # num_bag_sets = 2,
                  # ag_args_fit = {'num_cpus': os.cpu_count()},
)
# Out:
# Preset alias specified: 'best' maps to 'best_quality'.
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.11.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Sat Sep 27 10:16:09 UTC 2025
# CPU Count:          4
# Memory Avail:       29.95 GB / 31.35 GB (95.5%)
# Disk Space Avail:   19.50 GB / 19.52 GB (99.9%)
# ===================================================
# Presets specified: ['best']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=6, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 4500s of the 18000s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-11-29 10:57:30,988	INFO worker.py:1843 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho"
# (_dystack pid=411) Running DyStack sub-fit ...
# (_dystack pid=411) Beginning AutoGluon training ... Time limit = 4496s
# (_dystack pid=411) AutoGluon will save models to "/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho"
# (_dystack pid=411) Train Data Rows:    527994
# (_dystack pid=411) Train Data Columns: 10
# (_dystack pid=411) Label Column:       education_level
# (_dystack pid=411) Problem Type:       multiclass
# (_dystack pid=411) Preprocessing data ...
# (_dystack pid=411) Train Data Class Count: 5
# (_dystack pid=411) Using Feature Generators to preprocess the data ...
# (_dystack pid=411) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=411) 	Available Memory:                    30104.49 MB
# (_dystack pid=411) 	Train Data (Original)  Memory Usage: 181.07 MB (0.6% of available memory)
# (_dystack pid=411) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=411) 	Stage 1 Generators:
# (_dystack pid=411) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=411) 	Stage 2 Generators:
# (_dystack pid=411) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=411) 	Stage 3 Generators:
# (_dystack pid=411) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=411) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=411) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=411) 	Stage 4 Generators:
# (_dystack pid=411) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=411) 	Stage 5 Generators:
# (_dystack pid=411) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=411) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=411) 		('float', [])  : 4 | ['annual_income', 'debt_to_income_ratio', 'loan_amount', 'interest_rate']
# (_dystack pid=411) 		('int', [])    : 1 | ['credit_score']
# (_dystack pid=411) 		('object', []) : 5 | ['gender', 'marital_status', 'employment_status', 'loan_purpose', 'grade_subgrade']
# (_dystack pid=411) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=411) 		('category', []) : 5 | ['gender', 'marital_status', 'employment_status', 'loan_purpose', 'grade_subgrade']
# (_dystack pid=411) 		('float', [])    : 4 | ['annual_income', 'debt_to_income_ratio', 'loan_amount', 'interest_rate']
# (_dystack pid=411) 		('int', [])      : 1 | ['credit_score']
# (_dystack pid=411) 	1.9s = Fit runtime
# (_dystack pid=411) 	10 features in original data used to generate 10 features in processed data.
# (_dystack pid=411) 	Train Data (Processed) Memory Usage: 22.66 MB (0.1% of available memory)
# (_dystack pid=411) Data preprocessing and feature engineering runtime = 2.61s ...
# (_dystack pid=411) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc_ovo'
# (_dystack pid=411) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=411) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=411) Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=411) User-specified model hyperparameters to be fit:
# (_dystack pid=411) {
# (_dystack pid=411) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=411) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=411) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=411) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=411) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=411) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=411) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=411) }
# (_dystack pid=411) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=411) Fitting 108 L1 models, fit_strategy="sequential" ...
# (_dystack pid=411) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2994.71s of the 4493.18s of remaining time.
# (_dystack pid=411) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.00%)
# (_ray_fit pid=705) Metric roc_auc_ovo is not supported by this model - using log_loss instead
# (_ray_fit pid=707) No improvement since epoch 7: early stopping
# (_ray_fit pid=708) Metric roc_auc_ovo is not supported by this model - using log_loss instead [repeated 3x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_ray_fit pid=967) Metric roc_auc_ovo is not supported by this model - using log_loss instead
# (_ray_fit pid=1018) Metric roc_auc_ovo is not supported by this model - using log_loss instead
# (_dystack pid=411) 	0.5165	 = Validation score   (roc_auc_ovo)
# (_dystack pid=411) 	860.98s	 = Training   runtime
# (_dystack pid=411) 	6.46s	 = Validation runtime
# (_dystack pid=411) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2126.08s of the 3624.55s of remaining time.
# (_dystack pid=411) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.72%)
# (_dystack pid=411) 	0.5211	 = Validation score   (roc_auc_ovo)
# (_dystack pid=411) 	212.84s	 = Training   runtime
# (_dystack pid=411) 	46.7s	 = Validation runtime
# (_dystack pid=411) Fitting model: LightGBM_BAG_L1 ... Training model for up to 1900.47s of the 3398.94s of remaining time.
# (_dystack pid=411) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.72%)
# (_dystack pid=411) 	0.5245	 = Validation score   (roc_auc_ovo)
# (_dystack pid=411) 	251.25s	 = Training   runtime
# (_dystack pid=411) 	40.3s	 = Validation runtime
# (_dystack pid=411) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 1636.12s of the 3134.59s of remaining time.
# (_dystack pid=411) 	0.5112	 = Validation score   (roc_auc_ovo)
# (_dystack pid=411) 	251.13s	 = Training   runtime
# (_dystack pid=411) 	25.36s	 = Validation runtime
# (_dystack pid=411) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 1352.74s of the 2851.21s of remaining time.
# (_dystack pid=411) 	0.5121	 = Validation score   (roc_auc_ovo)
# (_dystack pid=411) 	295.93s	 = Training   runtime
# (_dystack pid=411) 	26.21s	 = Validation runtime
# (_dystack pid=411) Fitting model: CatBoost_BAG_L1 ... Training model for up to 1024.22s of the 2522.69s of remaining time.
# (_dystack pid=411) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.02%)
# (_ray_fit pid=2098) 	Ran out of time, early stopping on iteration 88.
# (_ray_fit pid=2097) 	Ran out of time, early stopping on iteration 92. [repeated 3x across cluster]
# (_ray_fit pid=2328) 	Ran out of time, early stopping on iteration 121.
# (_ray_fit pid=2369) 	Ran out of time, early stopping on iteration 115.
# (_dystack pid=411) 	0.5155	 = Validation score   (roc_auc_ovo)
# (_dystack pid=411) 	810.89s	 = Training   runtime
# (_dystack pid=411) 	1.07s	 = Validation runtime
# (_dystack pid=411) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 208.40s of the 1706.86s of remaining time.
# (_dystack pid=411) 	0.5107	 = Validation score   (roc_auc_ovo)
# (_dystack pid=411) 	58.63s	 = Training   runtime
# (_dystack pid=411) 	19.94s	 = Validation runtime
# (_dystack pid=411) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 125.53s of the 1624.00s of remaining time.
# (_dystack pid=411) 	Not enough time to generate out-of-fold predictions for model. Estimated time required was 104.52s compared to 98.22s of available time.
# (_dystack pid=411) 	Time limit exceeded... Skipping ExtraTreesEntr_BAG_L1.
# (_dystack pid=411) Fitting model: XGBoost_BAG_L1 ... Training model for up to 60.28s of the 1558.75s of remaining time.
# (_dystack pid=411) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.95%)
# (_dystack pid=411) 	0.5093	 = Validation score   (roc_auc_ovo)
# (_dystack pid=411) 	60.18s	 = Training   runtime
# (_dystack pid=411) 	2.65s	 = Validation runtime
# (_dystack pid=411) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 1493.01s of remaining time.
# (_dystack pid=411) 	Ensemble Weights: {'LightGBM_BAG_L1': 0.56, 'CatBoost_BAG_L1': 0.2, 'NeuralNetFastAI_BAG_L1': 0.12, 'RandomForestGini_BAG_L1': 0.04, 'RandomForestEntr_BAG_L1': 0.04, 'ExtraTreesGini_BAG_L1': 0.04}
# (_dystack pid=411) 	0.5252	 = Validation score   (roc_auc_ovo)
# (_dystack pid=411) 	259.52s	 = Training   runtime
# (_dystack pid=411) 	1.53s	 = Validation runtime
# (_dystack pid=411) Fitting 108 L2 models, fit_strategy="sequential" ...
# (_dystack pid=411) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1231.55s of the 1230.69s of remaining time.
# (_dystack pid=411) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=10.04%)
# (_ray_fit pid=3048) Metric roc_auc_ovo is not supported by this model - using log_loss instead
# (_ray_fit pid=3291) Metric roc_auc_ovo is not supported by this model - using log_loss instead [repeated 4x across cluster]
# (_ray_fit pid=3340) Metric roc_auc_ovo is not supported by this model - using log_loss instead
# (_ray_fit pid=3340) No improvement since epoch 5: early stopping
# (_dystack pid=411) 	0.5179	 = Validation score   (roc_auc_ovo)
# (_dystack pid=411) 	775.16s	 = Training   runtime
# (_dystack pid=411) 	7.28s	 = Validation runtime
# (_dystack pid=411) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 444.90s of the 444.04s of remaining time.
# (_dystack pid=411) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.85%)
# (_dystack pid=411) 	0.5226	 = Validation score   (roc_auc_ovo)
# (_dystack pid=411) 	137.82s	 = Training   runtime
# (_dystack pid=411) 	6.98s	 = Validation runtime
# (_dystack pid=411) Fitting model: LightGBM_BAG_L2 ... Training model for up to 298.58s of the 297.72s of remaining time.
# (_dystack pid=411) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.85%)
# (_dystack pid=411) 	0.522	 = Validation score   (roc_auc_ovo)
# (_dystack pid=411) 	115.25s	 = Training   runtime
# (_dystack pid=411) 	4.72s	 = Validation runtime
# (_dystack pid=411) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 175.98s of the 175.13s of remaining time.
# (_dystack pid=411) 	Warning: Reducing model 'n_estimators' from 300 -> 44 due to low time. Expected time usage reduced from 1178.4s -> 174.4s...
# (_dystack pid=411) 	0.5055	 = Validation score   (roc_auc_ovo)
# (_dystack pid=411) 	178.51s	 = Training   runtime
# (_dystack pid=411) 	6.84s	 = Validation runtime
# (_dystack pid=411) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the -14.34s of remaining time.
# (_dystack pid=411) Warning: Ensemble Selection ran out of time, early stopping at iteration 22. This may mean that the time_limit specified is very small for this problem.
# (_dystack pid=411) 	Ensemble Weights: {'LightGBM_BAG_L1': 0.455, 'CatBoost_BAG_L1': 0.182, 'NeuralNetFastAI_BAG_L1': 0.091, 'LightGBMXT_BAG_L2': 0.091, 'RandomForestGini_BAG_L1': 0.045, 'RandomForestEntr_BAG_L1': 0.045, 'ExtraTreesGini_BAG_L1': 0.045, 'NeuralNetFastAI_BAG_L2': 0.045}
# (_dystack pid=411) 	0.5252	 = Validation score   (roc_auc_ovo)
# (_dystack pid=411) 	360.46s	 = Training   runtime
# (_dystack pid=411) 	1.26s	 = Validation runtime
# (_dystack pid=411) AutoGluon training complete, total runtime = 4872.2s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 1466.6 rows/s (87999 batch size)
# (_dystack pid=411) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho")
# (_dystack pid=411) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val  eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           LightGBM_BAG_L1       0.527886   0.524455  roc_auc_ovo       14.780686      40.299728   251.248591                14.780686               40.299728         251.248591            1       True          3
# 1       WeightedEnsemble_L2       0.527118   0.525189  roc_auc_ovo       38.722264     120.859437  2788.326010                 0.016217                1.530368         259.516080            2       True          9
# 2       WeightedEnsemble_L3       0.526854   0.525170  roc_auc_ovo       65.761511     184.196313  4075.259729                 0.027741                1.264241         360.455954            3       True         14
# 3           LightGBM_BAG_L2       0.526150   0.521993  roc_auc_ovo       60.901068     173.389933  2917.085124                 1.435492                4.715233         115.254733            2       True         12
# 4         LightGBMXT_BAG_L2       0.525218   0.522610  roc_auc_ovo       61.867990     175.650295  2939.648685                 2.402413                6.975595         137.818294            2       True         11
# 5    NeuralNetFastAI_BAG_L2       0.521644   0.517928  roc_auc_ovo       63.331357     175.956477  3576.985482                 3.865780                7.281777         775.155091            2       True         10
# 6         LightGBMXT_BAG_L1       0.521464   0.521074  roc_auc_ovo       19.237720      46.695771   212.844738                19.237720               46.695771         212.844738            1       True          2
# 7            XGBoost_BAG_L1       0.518343   0.509348  roc_auc_ovo        1.521810       2.649859    60.175724                 1.521810                2.649859          60.175724            1       True          8
# 8    NeuralNetFastAI_BAG_L1       0.517807   0.516546  roc_auc_ovo        4.937340       6.463729   860.984182                 4.937340                6.463729         860.984182            1       True          1
# 9           CatBoost_BAG_L1       0.514709   0.515510  roc_auc_ovo        0.688350       1.065247   810.888750                 0.688350                1.065247         810.888750            1       True          6
# 10  RandomForestEntr_BAG_L1       0.513374   0.512096  roc_auc_ovo        4.771723      26.207644   295.930537                 4.771723               26.207644         295.930537            1       True          5
# 11  RandomForestGini_BAG_L1       0.512274   0.511174  roc_auc_ovo       10.257152      25.355794   251.129618                10.257152               25.355794         251.129618            1       True          4
# 12    ExtraTreesGini_BAG_L1       0.511597   0.510735  roc_auc_ovo        3.270796      19.936927    58.628253                 3.270796               19.936927          58.628253            1       True          7
# 13  RandomForestGini_BAG_L2       0.507470   0.505517  roc_auc_ovo       60.017040     175.511514  2980.345213                 0.551463                6.836813         178.514822            2       True         13
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	4952s	 = DyStack   runtime |	13048s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 13048s
# AutoGluon will save models to "/kaggle/working/AG_loan_models"
# Train Data Rows:    593994
# Train Data Columns: 10
# Label Column:       education_level
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 5
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    29515.48 MB
# 	Train Data (Original)  Memory Usage: 203.70 MB (0.7% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 4 | ['annual_income', 'debt_to_income_ratio', 'loan_amount', 'interest_rate']
# 		('int', [])    : 1 | ['credit_score']
# 		('object', []) : 5 | ['gender', 'marital_status', 'employment_status', 'loan_purpose', 'grade_subgrade']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 5 | ['gender', 'marital_status', 'employment_status', 'loan_purpose', 'grade_subgrade']
# 		('float', [])    : 4 | ['annual_income', 'debt_to_income_ratio', 'loan_amount', 'interest_rate']
# 		('int', [])      : 1 | ['credit_score']
# 	2.7s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 25.49 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 3.61s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc_ovo'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 108 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 8694.14s of the 13044.46s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.94%)
# 	0.5162	 = Validation score   (roc_auc_ovo)
# 	1075.27s	 = Training   runtime
# 	7.51s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 7611.95s of the 11962.27s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.67%)
# 	0.5207	 = Validation score   (roc_auc_ovo)
# 	229.21s	 = Training   runtime
# 	43.93s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 7370.69s of the 11721.01s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.67%)
# 	0.5253	 = Validation score   (roc_auc_ovo)
# 	183.56s	 = Training   runtime
# 	29.79s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 7177.72s of the 11528.04s of remaining time.
# 	0.5126	 = Validation score   (roc_auc_ovo)
# 	278.23s	 = Training   runtime
# 	28.66s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 6865.72s of the 11216.04s of remaining time.
# 	0.5128	 = Validation score   (roc_auc_ovo)
# 	351.01s	 = Training   runtime
# 	29.69s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 6477.95s of the 10828.27s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.98%)
# 	0.524	 = Validation score   (roc_auc_ovo)
# 	5172.76s	 = Training   runtime
# 	3.79s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 1299.01s of the 5649.33s of remaining time.
# 	0.5107	 = Validation score   (roc_auc_ovo)
# 	76.57s	 = Training   runtime
# 	22.8s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 1194.64s of the 5544.96s of remaining time.
# 	0.5107	 = Validation score   (roc_auc_ovo)
# 	81.39s	 = Training   runtime
# 	23.82s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1083.64s of the 5433.96s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.88%)
# 	0.5185	 = Validation score   (roc_auc_ovo)
# 	886.42s	 = Training   runtime
# 	17.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 188.24s of the 4538.56s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.53%)
# 	0.5086	 = Validation score   (roc_auc_ovo)
# 	155.27s	 = Training   runtime
# 	6.79s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 26.88s of the 4377.20s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.87%)
# 	0.5202	 = Validation score   (roc_auc_ovo)
# 	31.63s	 = Training   runtime
# 	4.87s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 869.41s of the 4338.37s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L1': 0.48, 'CatBoost_BAG_L1': 0.4, 'RandomForestGini_BAG_L1': 0.04, 'RandomForestEntr_BAG_L1': 0.04, 'XGBoost_BAG_L1': 0.04}
# 	0.5267	 = Validation score   (roc_auc_ovo)
# 	400.01s	 = Training   runtime
# 	1.3s	 = Validation runtime
# Fitting 108 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 3936.81s of the 3935.87s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=5.71%)
# 	0.5184	 = Validation score   (roc_auc_ovo)
# 	1105.92s	 = Training   runtime
# 	9.72s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 2821.73s of the 2820.79s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=3.85%)
# 	0.5248	 = Validation score   (roc_auc_ovo)
# 	203.44s	 = Training   runtime
# 	12.11s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 2609.66s of the 2608.71s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=3.84%)
# 	0.5251	 = Validation score   (roc_auc_ovo)
# 	214.83s	 = Training   runtime
# 	9.87s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 2385.34s of the 2384.39s of remaining time.
# 	0.5119	 = Validation score   (roc_auc_ovo)
# 	1602.23s	 = Training   runtime
# 	53.23s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 720.78s of the 719.83s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 90 due to low time. Expected time usage reduced from 2373.6s -> 718.2s...
# 	0.5099	 = Validation score   (roc_auc_ovo)
# 	695.49s	 = Training   runtime
# 	15.75s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 393.68s of the 2.19s of remaining time.
# Warning: Ensemble Selection ran out of time, early stopping at iteration 17. This may mean that the time_limit specified is very small for this problem.
# 	Ensemble Weights: {'LightGBM_BAG_L1': 0.312, 'CatBoost_BAG_L1': 0.312, 'LightGBMXT_BAG_L2': 0.188, 'LightGBM_BAG_L2': 0.125, 'RandomForestGini_BAG_L1': 0.062}
# 	0.5268	 = Validation score   (roc_auc_ovo)
# 	401.92s	 = Training   runtime
# 	1.41s	 = Validation runtime
# AutoGluon training complete, total runtime = 13449.6s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 645.1 rows/s (98999 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AG_loan_models")

# %%
## -- Get Summary -- 
print(f"-> Total models : {len(predictor.model_names())}")
print(f"-> Best model   : {predictor.model_best}") 

## -- Observe RUN 1 RESULTS -- 
leaderboard = predictor.leaderboard(silent=True)
leaderboard.style.background_gradient(subset=["score_val"], cmap="Spectral")
# Out:
# -> Total models : 18
# -> Best model   : WeightedEnsemble_L3
# <style type="text/css">
# #T_49077_row0_col1 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_49077_row1_col1 {
#   background-color: #5c51a3;
#   color: #f1f1f1;
# }
# #T_49077_row2_col1 {
#   background-color: #3880b9;
#   color: #f1f1f1;
# }
# #T_49077_row3_col1 {
#   background-color: #3585bb;
#   color: #f1f1f1;
# }
# #T_49077_row4_col1 {
#   background-color: #358bbc;
#   color: #f1f1f1;
# }
# #T_49077_row5_col1 {
#   background-color: #50a9af;
#   color: #f1f1f1;
# }
# #T_49077_row6_col1 {
#   background-color: #c1e6a0;
#   color: #000000;
# }
# #T_49077_row7_col1 {
#   background-color: #d1ed9c;
#   color: #000000;
# }
# #T_49077_row8_col1 {
#   background-color: #f4faad;
#   color: #000000;
# }
# #T_49077_row9_col1 {
#   background-color: #f7fcb2;
#   color: #000000;
# }
# #T_49077_row10_col1 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_49077_row11_col1 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_49077_row12_col1 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_49077_row13_col1 {
#   background-color: #ed6246;
#   color: #f1f1f1;
# }
# #T_49077_row14_col1 {
#   background-color: #d9444d;
#   color: #f1f1f1;
# }
# #T_49077_row15_col1 {
#   background-color: #d8434e;
#   color: #f1f1f1;
# }
# #T_49077_row16_col1 {
#   background-color: #c32a4b;
#   color: #f1f1f1;
# }
# #T_49077_row17_col1 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_49077">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49077_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_49077_level0_col1" class="col_heading level0 col1" >score_val</th>
#       <th id="T_49077_level0_col2" class="col_heading level0 col2" >eval_metric</th>
#       <th id="T_49077_level0_col3" class="col_heading level0 col3" >pred_time_val</th>
#       <th id="T_49077_level0_col4" class="col_heading level0 col4" >fit_time</th>
#       <th id="T_49077_level0_col5" class="col_heading level0 col5" >pred_time_val_marginal</th>
#       <th id="T_49077_level0_col6" class="col_heading level0 col6" >fit_time_marginal</th>
#       <th id="T_49077_level0_col7" class="col_heading level0 col7" >stack_level</th>
#       <th id="T_49077_level0_col8" class="col_heading level0 col8" >can_infer</th>
#       <th id="T_49077_level0_col9" class="col_heading level0 col9" >fit_order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49077_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49077_row0_col0" class="data row0 col0" >WeightedEnsemble_L3</td>
#       <td id="T_49077_row0_col1" class="data row0 col1" >0.526824</td>
#       <td id="T_49077_row0_col2" class="data row0 col2" >roc_auc_ovo</td>
#       <td id="T_49077_row0_col3" class="data row0 col3" >242.120668</td>
#       <td id="T_49077_row0_col4" class="data row0 col4" >9341.525790</td>
#       <td id="T_49077_row0_col5" class="data row0 col5" >1.412984</td>
#       <td id="T_49077_row0_col6" class="data row0 col6" >401.924664</td>
#       <td id="T_49077_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_49077_row0_col8" class="data row0 col8" >True</td>
#       <td id="T_49077_row0_col9" class="data row0 col9" >18</td>
#     </tr>
#     <tr>
#       <th id="T_49077_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_49077_row1_col0" class="data row1 col0" >WeightedEnsemble_L2</td>
#       <td id="T_49077_row1_col1" class="data row1 col1" >0.526720</td>
#       <td id="T_49077_row1_col2" class="data row1 col2" >roc_auc_ovo</td>
#       <td id="T_49077_row1_col3" class="data row1 col3" >110.311966</td>
#       <td id="T_49077_row1_col4" class="data row1 col4" >7271.989128</td>
#       <td id="T_49077_row1_col5" class="data row1 col5" >1.302544</td>
#       <td id="T_49077_row1_col6" class="data row1 col6" >400.007829</td>
#       <td id="T_49077_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_49077_row1_col8" class="data row1 col8" >True</td>
#       <td id="T_49077_row1_col9" class="data row1 col9" >12</td>
#     </tr>
#     <tr>
#       <th id="T_49077_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_49077_row2_col0" class="data row2 col0" >LightGBM_BAG_L1</td>
#       <td id="T_49077_row2_col1" class="data row2 col1" >0.525255</td>
#       <td id="T_49077_row2_col2" class="data row2 col2" >roc_auc_ovo</td>
#       <td id="T_49077_row2_col3" class="data row2 col3" >29.785782</td>
#       <td id="T_49077_row2_col4" class="data row2 col4" >183.556946</td>
#       <td id="T_49077_row2_col5" class="data row2 col5" >29.785782</td>
#       <td id="T_49077_row2_col6" class="data row2 col6" >183.556946</td>
#       <td id="T_49077_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_49077_row2_col8" class="data row2 col8" >True</td>
#       <td id="T_49077_row2_col9" class="data row2 col9" >3</td>
#     </tr>
#     <tr>
#       <th id="T_49077_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_49077_row3_col0" class="data row3 col0" >LightGBM_BAG_L2</td>
#       <td id="T_49077_row3_col1" class="data row3 col1" >0.525105</td>
#       <td id="T_49077_row3_col2" class="data row3 col2" >roc_auc_ovo</td>
#       <td id="T_49077_row3_col3" class="data row3 col3" >228.598446</td>
#       <td id="T_49077_row3_col4" class="data row3 col4" >8736.164838</td>
#       <td id="T_49077_row3_col5" class="data row3 col5" >9.869469</td>
#       <td id="T_49077_row3_col6" class="data row3 col6" >214.832548</td>
#       <td id="T_49077_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_49077_row3_col8" class="data row3 col8" >True</td>
#       <td id="T_49077_row3_col9" class="data row3 col9" >15</td>
#     </tr>
#     <tr>
#       <th id="T_49077_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_49077_row4_col0" class="data row4 col0" >LightGBMXT_BAG_L2</td>
#       <td id="T_49077_row4_col1" class="data row4 col1" >0.524844</td>
#       <td id="T_49077_row4_col2" class="data row4 col2" >roc_auc_ovo</td>
#       <td id="T_49077_row4_col3" class="data row4 col3" >230.838215</td>
#       <td id="T_49077_row4_col4" class="data row4 col4" >8724.768578</td>
#       <td id="T_49077_row4_col5" class="data row4 col5" >12.109238</td>
#       <td id="T_49077_row4_col6" class="data row4 col6" >203.436288</td>
#       <td id="T_49077_row4_col7" class="data row4 col7" >2</td>
#       <td id="T_49077_row4_col8" class="data row4 col8" >True</td>
#       <td id="T_49077_row4_col9" class="data row4 col9" >14</td>
#     </tr>
#     <tr>
#       <th id="T_49077_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_49077_row5_col0" class="data row5 col0" >CatBoost_BAG_L1</td>
#       <td id="T_49077_row5_col1" class="data row5 col1" >0.523955</td>
#       <td id="T_49077_row5_col2" class="data row5 col2" >roc_auc_ovo</td>
#       <td id="T_49077_row5_col3" class="data row5 col3" >3.787039</td>
#       <td id="T_49077_row5_col4" class="data row5 col4" >5172.760161</td>
#       <td id="T_49077_row5_col5" class="data row5 col5" >3.787039</td>
#       <td id="T_49077_row5_col6" class="data row5 col6" >5172.760161</td>
#       <td id="T_49077_row5_col7" class="data row5 col7" >1</td>
#       <td id="T_49077_row5_col8" class="data row5 col8" >True</td>
#       <td id="T_49077_row5_col9" class="data row5 col9" >6</td>
#     </tr>
#     <tr>
#       <th id="T_49077_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_49077_row6_col0" class="data row6 col0" >LightGBMXT_BAG_L1</td>
#       <td id="T_49077_row6_col1" class="data row6 col1" >0.520669</td>
#       <td id="T_49077_row6_col2" class="data row6 col2" >roc_auc_ovo</td>
#       <td id="T_49077_row6_col3" class="data row6 col3" >43.927072</td>
#       <td id="T_49077_row6_col4" class="data row6 col4" >229.210852</td>
#       <td id="T_49077_row6_col5" class="data row6 col5" >43.927072</td>
#       <td id="T_49077_row6_col6" class="data row6 col6" >229.210852</td>
#       <td id="T_49077_row6_col7" class="data row6 col7" >1</td>
#       <td id="T_49077_row6_col8" class="data row6 col8" >True</td>
#       <td id="T_49077_row6_col9" class="data row6 col9" >2</td>
#     </tr>
#     <tr>
#       <th id="T_49077_level0_row7" class="row_heading level0 row7" >7</th>
#       <td i

# %%
## -- RUN 2: Use original data as extra learning input --
# predictor.fit_pseudolabel(
#                 orig,
#                 use_ensemble = True,
#                 fit_ensemble = True,
#                 time_limit   = 3600*5,
#                 ag_args_fit  = {'num_cpus': os.cpu_count() - 1},
# )

# %%
## -- Get Summary -- 
# print(f"""
#     # {'█'*5}| Total models : {len(predictor.model_names())}
#     # {'█'*5}| Best model   : {predictor.model_best}
#         """)

# # -- Observe RUN 2 RESULTS --
# leaderboard = predictor.leaderboard(silent=True)
# display(leaderboard.style.background_gradient(subset=["score_val"], cmap="Spectral"))

# %%
## -- Create folder directory to save predictions --
SAVE_PATH = '/kaggle/working/AG_loan_predictions/'
# !mkdir {SAVE_PATH}

# %%
## -- Predictions for {SELECTED FEATURE} --
oof_ = predictor.predict_proba_oof(train_data=train, as_multiclass=False)
np.save(f"{SAVE_PATH}oof_AG_on_{TARGET}.npy", oof_)

preds_ = predictor.predict_proba(data=test, as_multiclass=False)
np.save(f"{SAVE_PATH}pred_AG_on_{TARGET}.npy", preds_)

oof_[:5], preds_[:5]
# Out:
# (   Bachelor's  High School  Master's     Other       PhD
#  0    0.442239     0.337411  0.155428  0.046210  0.018713
#  1    0.463189     0.321780  0.154293  0.042219  0.018519
#  2    0.458749     0.310933  0.165442  0.046287  0.018590
#  3    0.455937     0.321714  0.156586  0.047718  0.018046
#  4    0.451938     0.333800  0.146919  0.046161  0.021182,
#     Bachelor's  High School  Master's     Other       PhD
#  0    0.472039     0.312534  0.147808  0.045819  0.021800
#  1    0.458801     0.321391  0.153598  0.047588  0.018621
#  2    0.452314     0.319548  0.155653  0.048922  0.023562
#  3    0.448663     0.332533  0.156962  0.042038  0.019804
#  4    0.481958     0.313136  0.144443  0.042386  0.018077)

# %%
predictor.plot_ensemble_model(filename='ensemble_model.png')
display(Image(f'{MODELS_PATH}ensemble_model.png'))

# %%
# !zip -r /kaggle/working/AG_accident_models /kaggle/working/AG_accident_models.zip
# !zip -r {FOLDER}{NAME_EXT}.zip /kaggle/working/{FOLDER}{NAME_EXT}

# %%
## -- Extract model scores --
result_ = dict(zip(leaderboard['model'], leaderboard['score_val']))
result_df = pd.DataFrame.from_dict(result_, orient='index').sort_values(0)

max_score = result_df.max().item()
min_score = result_df.min().item()

## -- PLOT MODELS & SCORES --
plt.figure(figsize=(18, 15))
plt.stem(
    result_df.index,
    result_df[0],
    orientation = 'horizontal',
    bottom = min_score - 0.0055,
    markerfmt = 'C3o'
)
plt.xlim(min_score - 0.006, max_score + 0.005)
plt.xlabel('Score')
plt.title('-- Scores of Models --', fontsize=15)

for i, value in enumerate(result_df[0]):
    plt.text(value+1e-3, i, f'{abs(value):.5f}', ha='left', va='center', fontdict=dict(size=12))

plt.grid(True, axis='x')
plt.tight_layout()
plt.show()

# %%
# predictor.model_names()

# %%
# ## -- Permutation Feature Importances --
# feat_imp = predictor.feature_importance(
#                         data = X_test,
#                         # time_limit = 3600,
#                         # model = 'LightGBM_BAG_L1',
#                         # features = None,
#                         # feature_stage = 'transformed',
#                         # subsample_size = 5000,
#                         # num_shuffle_sets = 10,
#                         # include_confidence_band = True,
#                         confidence_level = 0.95,
#                         # silent = False
# ) 

# feat_imp.style.background_gradient(subset=["importance"], cmap="Spectral")

# %%
# plt.figure(figsize=(18, 35))
# sns.barplot(data=feat_imp, y=feat_imp.index, x=feat_imp.importance)
# plt.tick_params(axis='y', which='major', labelcolor='r')
# plt.title("Top Features by Permutation")
# plt.tight_layout()
# plt.show()

# %%
## -- OPTIONAL: Remove stored files --
# !rm -r {MODELS_PATH}

# %%
print(f"""
{'-'*48}
{'█'*5} | - AUTOGLUON NOTEBOOK COMPLETE! - | {'█'*5}
{'-'*48}
""")
# Out:
# ------------------------------------------------
# █████ | - AUTOGLUON NOTEBOOK COMPLETE! - | █████
# ------------------------------------------------
