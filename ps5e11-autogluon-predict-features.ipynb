# %%
# %%capture cap
# !pip install -qq ipywidgets
# !pip install -qq autogluon scikit-learn==1.5.2 
# !apt-get install -qq -y graphviz graphviz-dev && pip install -q pydot
# !pip install -qq pygraphviz
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 79.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.9/454.9 kB 23.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.3/487.3 kB 26.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.7/189.7 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.8/285.8 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.5/280.5 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 60.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 36.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 22.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 MB 26.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.4/354.4 kB 21.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 62.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 35.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.5/963.5 kB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 34.4 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 25.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 17.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 76.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 95.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 102.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 28.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 4.0 MB/s eta 0:00:00
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Building wheel for seqeval (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# Selecting previously unselected package libgtk2.0-common.
# (Reading database ... 128639 files and directories currently installed.)
# Preparing to unpack .../0-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../1-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../2-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../3-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libxdot4:amd64.
# Preparing to unpack .../4-libxdot4_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgvc6-plugins-gtk.
# Preparing to unpack .../5-libgvc6-plugins-gtk_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgraphviz-dev:amd64.
# Preparing to unpack .../6-libgraphviz-dev_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../7-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.0/106.0 kB 4.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for pygraphviz (pyproject.toml) ... done

# %%
import torch
import os
import pydot

import random
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
from time import time, sleep
from itertools import combinations

from IPython.display import display, Image
import matplotlib.pyplot as plt
import seaborn as sns

import warnings

warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')

## -- Set Global Seed --
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

pd.set_option('display.max_columns', 500)
plt.style.use("ggplot")

## -- Ansi color codes --
COLOR = '\033[32m'
RESET = '\033[0m'

print("Packages import succesful!")
# Out:
# Packages import succesful!

# %%
### Load Data ###
PATH = "/kaggle/input/playground-series-s5e11/"
submit = pd.read_csv(PATH+"sample_submission.csv")

list_of_targets = [
    'debt_to_income_ratio',
    'credit_score',
    'interest_rate',
    'employment_status',
    'annual_income',
    'loan_amount',
    'education_level',
    'grade_subgrade',
    'loan_purpose',
    'marital_status',
    'gender',
]

TARGET = list_of_targets[6]

train = pd.read_csv(PATH+"train.csv").drop(['id', "loan_paid_back"], axis=1)
test = pd.read_csv(PATH+"test.csv").drop(['id', TARGET], axis=1)

# ## -- Convert target to float for regression --
# train[TARGET] = train[TARGET].astype(np.float32)

NUMS = test.select_dtypes(include='number').columns.tolist()
CATS = test.select_dtypes(exclude='number').columns.tolist()
BASE = NUMS + CATS

for (name, df) in dict(Train=train, Test=test).items():
    print(f"{name} shape: {df.shape}")

print(f"\nTotal Numerical: {len(NUMS)}")
print(f"Total Categorical: {len(CATS)}")
print(f"Total base features: {len(BASE)}")
# Out:
# Train shape: (593994, 11)
# Test shape: (254569, 10)
#
# Total Numerical: 5
# Total Categorical: 5
# Total base features: 10

# %%
# !rm -r /kaggle/working/AG_loan_models

# %%
from autogluon.tabular import TabularPredictor

# %%
MODELS_PATH = "./AG_loan_models/"

predictor = TabularPredictor(
                label = TARGET,
         # problem_type = "regression",
          eval_metric = "roc_auc_ovo_macro",
                 path = MODELS_PATH,
    ).fit(
                   train_data = train,
                      presets = "best",
                num_bag_folds = 6,
             # dynamic_stacking = False,
             # num_stack_levels = 1,
                   time_limit = 3600*5,
                   # auto_stack = False,
                 # num_bag_sets = 2,
                  # ag_args_fit = {'num_cpus': os.cpu_count()},
)
# Out:
# Preset alias specified: 'best' maps to 'best_quality'.
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.11.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Sat Sep 27 10:16:09 UTC 2025
# CPU Count:          4
# Memory Avail:       29.95 GB / 31.35 GB (95.5%)
# Disk Space Avail:   19.50 GB / 19.52 GB (99.9%)
# ===================================================
# Presets specified: ['best']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=6, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 4500s of the 18000s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-11-29 10:57:03,383	INFO worker.py:1843 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho"
# (_dystack pid=415) Running DyStack sub-fit ...
# (_dystack pid=415) Beginning AutoGluon training ... Time limit = 4496s
# (_dystack pid=415) AutoGluon will save models to "/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho"
# (_dystack pid=415) Train Data Rows:    527994
# (_dystack pid=415) Train Data Columns: 10
# (_dystack pid=415) Label Column:       education_level
# (_dystack pid=415) Problem Type:       multiclass
# (_dystack pid=415) Preprocessing data ...
# (_dystack pid=415) Train Data Class Count: 5
# (_dystack pid=415) Using Feature Generators to preprocess the data ...
# (_dystack pid=415) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=415) 	Available Memory:                    30102.19 MB
# (_dystack pid=415) 	Train Data (Original)  Memory Usage: 181.07 MB (0.6% of available memory)
# (_dystack pid=415) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=415) 	Stage 1 Generators:
# (_dystack pid=415) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=415) 	Stage 2 Generators:
# (_dystack pid=415) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=415) 	Stage 3 Generators:
# (_dystack pid=415) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=415) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=415) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=415) 	Stage 4 Generators:
# (_dystack pid=415) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=415) 	Stage 5 Generators:
# (_dystack pid=415) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=415) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=415) 		('float', [])  : 4 | ['annual_income', 'debt_to_income_ratio', 'loan_amount', 'interest_rate']
# (_dystack pid=415) 		('int', [])    : 1 | ['credit_score']
# (_dystack pid=415) 		('object', []) : 5 | ['gender', 'marital_status', 'employment_status', 'loan_purpose', 'grade_subgrade']
# (_dystack pid=415) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=415) 		('category', []) : 5 | ['gender', 'marital_status', 'employment_status', 'loan_purpose', 'grade_subgrade']
# (_dystack pid=415) 		('float', [])    : 4 | ['annual_income', 'debt_to_income_ratio', 'loan_amount', 'interest_rate']
# (_dystack pid=415) 		('int', [])      : 1 | ['credit_score']
# (_dystack pid=415) 	1.6s = Fit runtime
# (_dystack pid=415) 	10 features in original data used to generate 10 features in processed data.
# (_dystack pid=415) 	Train Data (Processed) Memory Usage: 22.66 MB (0.1% of available memory)
# (_dystack pid=415) Data preprocessing and feature engineering runtime = 2.25s ...
# (_dystack pid=415) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc_ovo'
# (_dystack pid=415) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=415) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=415) Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=415) User-specified model hyperparameters to be fit:
# (_dystack pid=415) {
# (_dystack pid=415) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=415) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=415) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=415) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=415) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=415) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=415) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=415) }
# (_dystack pid=415) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=415) Fitting 108 L1 models, fit_strategy="sequential" ...
# (_dystack pid=415) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2994.84s of the 4493.38s of remaining time.
# (_dystack pid=415) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.00%)
# (_ray_fit pid=703) Metric roc_auc_ovo is not supported by this model - using log_loss instead
# (_ray_fit pid=704) No improvement since epoch 7: early stopping
# (_ray_fit pid=704) Metric roc_auc_ovo is not supported by this model - using log_loss instead [repeated 3x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_ray_fit pid=988) Metric roc_auc_ovo is not supported by this model - using log_loss instead
# (_ray_fit pid=1042) Metric roc_auc_ovo is not supported by this model - using log_loss instead
# (_dystack pid=415) 	0.5165	 = Validation score   (roc_auc_ovo)
# (_dystack pid=415) 	1000.54s	 = Training   runtime
# (_dystack pid=415) 	7.74s	 = Validation runtime
# (_dystack pid=415) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1986.05s of the 3484.58s of remaining time.
# (_dystack pid=415) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.72%)
# (_dystack pid=415) 	0.5211	 = Validation score   (roc_auc_ovo)
# (_dystack pid=415) 	236.69s	 = Training   runtime
# (_dystack pid=415) 	41.47s	 = Validation runtime
# (_dystack pid=415) Fitting model: LightGBM_BAG_L1 ... Training model for up to 1736.94s of the 3235.48s of remaining time.
# (_dystack pid=415) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.72%)
# (_dystack pid=415) 	0.5245	 = Validation score   (roc_auc_ovo)
# (_dystack pid=415) 	277.53s	 = Training   runtime
# (_dystack pid=415) 	39.06s	 = Validation runtime
# (_dystack pid=415) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 1447.14s of the 2945.67s of remaining time.
# (_dystack pid=415) 	0.5112	 = Validation score   (roc_auc_ovo)
# (_dystack pid=415) 	247.47s	 = Training   runtime
# (_dystack pid=415) 	24.77s	 = Validation runtime
# (_dystack pid=415) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 1169.80s of the 2668.33s of remaining time.
# (_dystack pid=415) 	0.5121	 = Validation score   (roc_auc_ovo)
# (_dystack pid=415) 	331.83s	 = Training   runtime
# (_dystack pid=415) 	26.44s	 = Validation runtime
# (_dystack pid=415) Fitting model: CatBoost_BAG_L1 ... Training model for up to 806.14s of the 2304.67s of remaining time.
# (_dystack pid=415) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.04%)
# (_ray_fit pid=2140) 	Ran out of time, early stopping on iteration 53.
# (_ray_fit pid=2139) 	Ran out of time, early stopping on iteration 59. [repeated 3x across cluster]
# (_ray_fit pid=2404) 	Ran out of time, early stopping on iteration 93.
# (_ray_fit pid=2361) 	Ran out of time, early stopping on iteration 98.
# (_dystack pid=415) 	0.5072	 = Validation score   (roc_auc_ovo)
# (_dystack pid=415) 	633.75s	 = Training   runtime
# (_dystack pid=415) 	0.95s	 = Validation runtime
# (_dystack pid=415) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 166.55s of the 1665.08s of remaining time.
# (_dystack pid=415) 	0.5107	 = Validation score   (roc_auc_ovo)
# (_dystack pid=415) 	74.36s	 = Training   runtime
# (_dystack pid=415) 	19.78s	 = Validation runtime
# (_dystack pid=415) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 66.73s of the 1565.26s of remaining time.
# (_dystack pid=415) 	Warning: Reducing model 'n_estimators' from 300 -> 284 due to low time. Expected time usage reduced from 70.2s -> 66.6s...
# (_dystack pid=415) 	Not enough time to generate out-of-fold predictions for model. Estimated time required was 106.24s compared to 25.56s of available time.
# (_dystack pid=415) 	Time limit exceeded... Skipping ExtraTreesEntr_BAG_L1.
# (_dystack pid=415) Fitting model: XGBoost_BAG_L1 ... Training model for up to 5.27s of the 1503.81s of remaining time.
# (_dystack pid=415) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.94%)
# (_dystack pid=415) 	0.5144	 = Validation score   (roc_auc_ovo)
# (_dystack pid=415) 	23.98s	 = Training   runtime
# (_dystack pid=415) 	2.27s	 = Validation runtime
# (_dystack pid=415) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 1473.66s of remaining time.
# (_dystack pid=415) 	Ensemble Weights: {'XGBoost_BAG_L1': 0.44, 'LightGBM_BAG_L1': 0.36, 'NeuralNetFastAI_BAG_L1': 0.08, 'LightGBMXT_BAG_L1': 0.04, 'RandomForestGini_BAG_L1': 0.04, 'ExtraTreesGini_BAG_L1': 0.04}
# (_dystack pid=415) 	0.5251	 = Validation score   (roc_auc_ovo)
# (_dystack pid=415) 	249.95s	 = Training   runtime
# (_dystack pid=415) 	1.23s	 = Validation runtime
# (_dystack pid=415) Fitting 108 L2 models, fit_strategy="sequential" ...
# (_dystack pid=415) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1222.30s of the 1221.85s of remaining time.
# (_dystack pid=415) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=4.15%)
# (_ray_fit pid=3057) Metric roc_auc_ovo is not supported by this model - using log_loss instead
# (_ray_fit pid=3291) Metric roc_auc_ovo is not supported by this model - using log_loss instead [repeated 4x across cluster]
# (_dystack pid=415) 	0.5177	 = Validation score   (roc_auc_ovo)
# (_dystack pid=415) 	627.09s	 = Training   runtime
# (_dystack pid=415) 	9.04s	 = Validation runtime
# (_dystack pid=415) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 587.21s of the 586.75s of remaining time.
# (_ray_fit pid=3328) Metric roc_auc_ovo is not supported by this model - using log_loss instead
# (_dystack pid=415) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.83%)
# (_dystack pid=415) 	0.5234	 = Validation score   (roc_auc_ovo)
# (_dystack pid=415) 	160.16s	 = Training   runtime
# (_dystack pid=415) 	7.43s	 = Validation runtime
# (_dystack pid=415) Fitting model: LightGBM_BAG_L2 ... Training model for up to 418.23s of the 417.78s of remaining time.
# (_dystack pid=415) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.83%)
# (_dystack pid=415) 	0.5215	 = Validation score   (roc_auc_ovo)
# (_dystack pid=415) 	178.39s	 = Training   runtime
# (_dystack pid=415) 	6.12s	 = Validation runtime
# (_dystack pid=415) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 231.68s of the 231.23s of remaining time.
# (_dystack pid=415) 	Warning: Reducing model 'n_estimators' from 300 -> 48 due to low time. Expected time usage reduced from 1434.9s -> 230.0s...
# (_dystack pid=415) 	0.5046	 = Validation score   (roc_auc_ovo)
# (_dystack pid=415) 	222.37s	 = Training   runtime
# (_dystack pid=415) 	5.56s	 = Validation runtime
# (_dystack pid=415) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the -0.78s of remaining time.
# (_dystack pid=415) Warning: Ensemble Selection ran out of time, early stopping at iteration 24. This may mean that the time_limit specified is very small for this problem.
# (_dystack pid=415) 	Ensemble Weights: {'XGBoost_BAG_L1': 0.375, 'LightGBM_BAG_L1': 0.292, 'LightGBMXT_BAG_L2': 0.208, 'NeuralNetFastAI_BAG_L1': 0.083, 'RandomForestEntr_BAG_L1': 0.042}
# (_dystack pid=415) 	0.5253	 = Validation score   (roc_auc_ovo)
# (_dystack pid=415) 	370.69s	 = Training   runtime
# (_dystack pid=415) 	1.22s	 = Validation runtime
# (_dystack pid=415) AutoGluon training complete, total runtime = 4868.55s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 793.1 rows/s (87999 batch size)
# (_dystack pid=415) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho")
# (_dystack pid=415) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val  eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           LightGBM_BAG_L1       0.527886   0.524455  roc_auc_ovo       10.796476      39.056363   277.534913                10.796476               39.056363         277.534913            1       True          3
# 1       WeightedEnsemble_L2       0.527071   0.525130  roc_auc_ovo       48.463191     136.313565  2110.538757                 0.020114                1.226211         249.952150            2       True          9
# 2       WeightedEnsemble_L3       0.527058   0.525340  roc_auc_ovo       62.688473     171.140820  3357.013110                 0.013726                1.221900         370.689317            3       True         14
# 3    NeuralNetFastAI_BAG_L2       0.525881   0.517696  roc_auc_ovo       70.181600     171.522269  3453.258028                10.268924                9.038089         627.091754            2       True         10
# 4           LightGBM_BAG_L2       0.525845   0.521549  roc_auc_ovo       61.856375     168.599656  3004.553790                 1.943698                6.115475         178.387516            2       True         12
# 5         LightGBMXT_BAG_L2       0.525328   0.523401  roc_auc_ovo       62.674747     169.918920  2986.323793                 2.762071                7.434739         160.157520            2       True         11
# 6         LightGBMXT_BAG_L1       0.521464   0.521074  roc_auc_ovo       15.117792      41.470471   236.694558                15.117792               41.470471         236.694558            1       True          2
# 7    NeuralNetFastAI_BAG_L1       0.517807   0.516546  roc_auc_ovo        5.055259       7.736464  1000.543232                 5.055259                7.736464        1000.543232            1       True          1
# 8            XGBoost_BAG_L1       0.516503   0.514373  roc_auc_ovo        3.700228       2.273262    23.980356                 3.700228                2.273262          23.980356            1       True          8
# 9   RandomForestEntr_BAG_L1       0.513374   0.512096  roc_auc_ovo        9.139805      26.443838   331.833354                 9.139805               26.443838         331.833354            1       True          5
# 10          CatBoost_BAG_L1       0.513159   0.507151  roc_auc_ovo        2.329795       0.952989   633.746313                 2.329795                0.952989         633.746313            1       True          6
# 11  RandomForestGini_BAG_L1       0.512274   0.511174  roc_auc_ovo        7.943142      24.771774   247.472172                 7.943142               24.771774         247.472172            1       True          4
# 12    ExtraTreesGini_BAG_L1       0.511597   0.510735  roc_auc_ovo        5.830181      19.779021    74.361376                 5.830181               19.779021          74.361376            1       True          7
# 13  RandomForestGini_BAG_L2       0.508500   0.504633  roc_auc_ovo       60.586783     168.045237  3048.532789                 0.674107                5.561056         222.366515            2       True         13
# 	0	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: True)
# 	4955s	 = DyStack   runtime |	13045s	 = Remaining runtime
# Starting main fit with num_stack_levels=0.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=0)`
# Beginning AutoGluon training ... Time limit = 13045s
# AutoGluon will save models to "/kaggle/working/AG_loan_models"
# Train Data Rows:    593994
# Train Data Columns: 10
# Label Column:       education_level
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 5
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    30254.52 MB
# 	Train Data (Original)  Memory Usage: 203.70 MB (0.7% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 4 | ['annual_income', 'debt_to_income_ratio', 'loan_amount', 'interest_rate']
# 		('int', [])    : 1 | ['credit_score']
# 		('object', []) : 5 | ['gender', 'marital_status', 'employment_status', 'loan_purpose', 'grade_subgrade']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 5 | ['gender', 'marital_status', 'employment_status', 'loan_purpose', 'grade_subgrade']
# 		('float', [])    : 4 | ['annual_income', 'debt_to_income_ratio', 'loan_amount', 'interest_rate']
# 		('int', [])      : 1 | ['credit_score']
# 	2.3s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 25.49 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 3.17s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc_ovo'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# Fitting 108 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 13041.37s of the 13041.35s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.93%)
# 	0.5162	 = Validation score   (roc_auc_ovo)
# 	1168.79s	 = Training   runtime
# 	9.5s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 11864.97s of the 11864.96s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.67%)
# 	0.5207	 = Validation score   (roc_auc_ovo)
# 	248.66s	 = Training   runtime
# 	45.2s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 11604.18s of the 11604.17s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.67%)
# 	0.5253	 = Validation score   (roc_auc_ovo)
# 	209.57s	 = Training   runtime
# 	30.39s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 11384.96s of the 11384.94s of remaining time.
# 	0.5126	 = Validation score   (roc_auc_ovo)
# 	290.18s	 = Training   runtime
# 	27.98s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 11061.86s of the 11061.85s of remaining time.
# 	0.5128	 = Validation score   (roc_auc_ovo)
# 	377.34s	 = Training   runtime
# 	29.85s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 10649.58s of the 10649.57s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.99%)
# 	0.5244	 = Validation score   (roc_auc_ovo)
# 	8506.93s	 = Training   runtime
# 	5.06s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 2135.81s of the 2135.80s of remaining time.
# 	0.5107	 = Validation score   (roc_auc_ovo)
# 	71.82s	 = Training   runtime
# 	22.61s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 2036.39s of the 2036.38s of remaining time.
# 	0.5107	 = Validation score   (roc_auc_ovo)
# 	79.99s	 = Training   runtime
# 	23.97s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1925.22s of the 1925.21s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.89%)
# 	0.5259	 = Validation score   (roc_auc_ovo)
# 	1559.12s	 = Training   runtime
# 	40.16s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 354.80s of the 354.79s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.53%)
# 	0.5132	 = Validation score   (roc_auc_ovo)
# 	294.16s	 = Training   runtime
# 	8.69s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 52.87s of the 52.86s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.88%)
# 	0.5213	 = Validation score   (roc_auc_ovo)
# 	53.96s	 = Training   runtime
# 	11.21s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 1304.14s of the -10.75s of remaining time.
# 	Ensemble Weights: {'XGBoost_BAG_L1': 0.35, 'CatBoost_BAG_L1': 0.3, 'LightGBM_BAG_L1': 0.25, 'RandomForestGini_BAG_L1': 0.05, 'NeuralNetTorch_BAG_L1': 0.05}
# 	0.5277	 = Validation score   (roc_auc_ovo)
# 	412.66s	 = Training   runtime
# 	1.74s	 = Validation runtime
# AutoGluon training complete, total runtime = 13469.94s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 1109.2 rows/s (98999 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AG_loan_models")

# %%
## -- Get Summary -- 
print(f"-> Total models : {len(predictor.model_names())}")
print(f"-> Best model   : {predictor.model_best}") 

## -- Observe RUN 1 RESULTS -- 
leaderboard = predictor.leaderboard(silent=True)
leaderboard.style.background_gradient(subset=["score_val"], cmap="Spectral")
# Out:
# -> Total models : 12
# -> Best model   : WeightedEnsemble_L2
# <style type="text/css">
# #T_32c83_row0_col1 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_32c83_row1_col1 {
#   background-color: #3389bd;
#   color: #f1f1f1;
# }
# #T_32c83_row2_col1 {
#   background-color: #47a0b3;
#   color: #f1f1f1;
# }
# #T_32c83_row3_col1 {
#   background-color: #62bda7;
#   color: #000000;
# }
# #T_32c83_row4_col1 {
#   background-color: #d8ef9b;
#   color: #000000;
# }
# #T_32c83_row5_col1 {
#   background-color: #e9f69d;
#   color: #000000;
# }
# #T_32c83_row6_col1 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_32c83_row7_col1 {
#   background-color: #e45549;
#   color: #f1f1f1;
# }
# #T_32c83_row8_col1 {
#   background-color: #dc484c;
#   color: #f1f1f1;
# }
# #T_32c83_row9_col1 {
#   background-color: #d8434e;
#   color: #f1f1f1;
# }
# #T_32c83_row10_col1, #T_32c83_row11_col1 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_32c83">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32c83_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_32c83_level0_col1" class="col_heading level0 col1" >score_val</th>
#       <th id="T_32c83_level0_col2" class="col_heading level0 col2" >eval_metric</th>
#       <th id="T_32c83_level0_col3" class="col_heading level0 col3" >pred_time_val</th>
#       <th id="T_32c83_level0_col4" class="col_heading level0 col4" >fit_time</th>
#       <th id="T_32c83_level0_col5" class="col_heading level0 col5" >pred_time_val_marginal</th>
#       <th id="T_32c83_level0_col6" class="col_heading level0 col6" >fit_time_marginal</th>
#       <th id="T_32c83_level0_col7" class="col_heading level0 col7" >stack_level</th>
#       <th id="T_32c83_level0_col8" class="col_heading level0 col8" >can_infer</th>
#       <th id="T_32c83_level0_col9" class="col_heading level0 col9" >fit_order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32c83_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_32c83_row0_col0" class="data row0 col0" >WeightedEnsemble_L2</td>
#       <td id="T_32c83_row0_col1" class="data row0 col1" >0.527691</td>
#       <td id="T_32c83_row0_col2" class="data row0 col2" >roc_auc_ovo</td>
#       <td id="T_32c83_row0_col3" class="data row0 col3" >114.021107</td>
#       <td id="T_32c83_row0_col4" class="data row0 col4" >11272.619891</td>
#       <td id="T_32c83_row0_col5" class="data row0 col5" >1.740353</td>
#       <td id="T_32c83_row0_col6" class="data row0 col6" >412.655738</td>
#       <td id="T_32c83_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_32c83_row0_col8" class="data row0 col8" >True</td>
#       <td id="T_32c83_row0_col9" class="data row0 col9" >12</td>
#     </tr>
#     <tr>
#       <th id="T_32c83_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_32c83_row1_col0" class="data row1 col0" >XGBoost_BAG_L1</td>
#       <td id="T_32c83_row1_col1" class="data row1 col1" >0.525937</td>
#       <td id="T_32c83_row1_col2" class="data row1 col2" >roc_auc_ovo</td>
#       <td id="T_32c83_row1_col3" class="data row1 col3" >40.160119</td>
#       <td id="T_32c83_row1_col4" class="data row1 col4" >1559.115385</td>
#       <td id="T_32c83_row1_col5" class="data row1 col5" >40.160119</td>
#       <td id="T_32c83_row1_col6" class="data row1 col6" >1559.115385</td>
#       <td id="T_32c83_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_32c83_row1_col8" class="data row1 col8" >True</td>
#       <td id="T_32c83_row1_col9" class="data row1 col9" >9</td>
#     </tr>
#     <tr>
#       <th id="T_32c83_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_32c83_row2_col0" class="data row2 col0" >LightGBM_BAG_L1</td>
#       <td id="T_32c83_row2_col1" class="data row2 col1" >0.525255</td>
#       <td id="T_32c83_row2_col2" class="data row2 col2" >roc_auc_ovo</td>
#       <td id="T_32c83_row2_col3" class="data row2 col3" >30.386070</td>
#       <td id="T_32c83_row2_col4" class="data row2 col4" >209.574468</td>
#       <td id="T_32c83_row2_col5" class="data row2 col5" >30.386070</td>
#       <td id="T_32c83_row2_col6" class="data row2 col6" >209.574468</td>
#       <td id="T_32c83_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_32c83_row2_col8" class="data row2 col8" >True</td>
#       <td id="T_32c83_row2_col9" class="data row2 col9" >3</td>
#     </tr>
#     <tr>
#       <th id="T_32c83_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_32c83_row3_col0" class="data row3 col0" >CatBoost_BAG_L1</td>
#       <td id="T_32c83_row3_col1" class="data row3 col1" >0.524424</td>
#       <td id="T_32c83_row3_col2" class="data row3 col2" >roc_auc_ovo</td>
#       <td id="T_32c83_row3_col3" class="data row3 col3" >5.056829</td>
#       <td id="T_32c83_row3_col4" class="data row3 col4" >8506.933722</td>
#       <td id="T_32c83_row3_col5" class="data row3 col5" >5.056829</td>
#       <td id="T_32c83_row3_col6" class="data row3 col6" >8506.933722</td>
#       <td id="T_32c83_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_32c83_row3_col8" class="data row3 col8" >True</td>
#       <td id="T_32c83_row3_col9" class="data row3 col9" >6</td>
#     </tr>
#     <tr>
#       <th id="T_32c83_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_32c83_row4_col0" class="data row4 col0" >LightGBMLarge_BAG_L1</td>
#       <td id="T_32c83_row4_col1" class="data row4 col1" >0.521285</td>
#       <td id="T_32c83_row4_col2" class="data row4 col2" >roc_auc_ovo</td>
#       <td id="T_32c83_row4_col3" class="data row4 col3" >11.209559</td>
#       <td id="T_32c83_row4_col4" class="data row4 col4" >53.959567</td>
#       <td id="T_32c83_row4_col5" class="data row4 col5" >11.209559</td>
#       <td id="T_32c83_row4_col6" class="data row4 col6" >53.959567</td>
#       <td id="T_32c83_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_32c83_row4_col8" class="data row4 col8" >True</td>
#       <td id="T_32c83_row4_col9" class="data row4 col9" >11</td>
#     </tr>
#     <tr>
#       <th id="T_32c83_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_32c83_row5_col0" class="data row5 col0" >LightGBMXT_BAG_L1</td>
#       <td id="T_32c83_row5_col1" class="data row5 col1" >0.520669</td>
#       <td id="T_32c83_row5_col2" class="data row5 col2" >roc_auc_ovo</td>
#       <td id="T_32c83_row5_col3" class="data row5 col3" >45.204755</td>
#       <td id="T_32c83_row5_col4" class="data row5 col4" >248.658557</td>
#       <td id="T_32c83_row5_col5" class="data row5 col5" >45.204755</td>
#       <td id="T_32c83_row5_col6" class="data row5 col6" >248.658557</td>
#       <td id="T_32c83_row5_col7" class="data row5 col7" >1</td>
#       <td id="T_32c83_row5_col8" class="data row5 col8" >True</td>
#       <td id="T_32c83_row5_col9" class="data row5 col9" >2</td>
#     </tr>
#     <tr>
#       <th id="T_32c83_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_32c83_row6_col0" class="data row6 col0" >NeuralNetFastAI_BAG_L1</td>
#       <td id="T_32c83_row6_col1" class="data row6 col1" >0.516213</td>
#       <td id="T_32c83_row6_col2" class="data row6 col2" >roc_auc_ovo</td>
#       <td id="T_32c83_row6_col3" class="data row6 col3" >9.495952</td>
#       <td id="T_32c83_row6_col4" class="data row6 col4" >1168.788518</td>
#       <td id="T_32c83_row6_col5" class="data row6 col5" >9.495952</td>
#       <td id="T_32c83_row6_col6" class="data row6 col6" >1168.788518</td>
#       <td id="T_32c83_row6_col7" class="data row6 col7" >1</td>
#       <td id="T_32c83_row6_col8" class="data row6 col8" >True</td>
#       <td id="T_32c83_row6_col9" class="data row6 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_32c83_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_32c83_row7_col0" class="data row7 col0" >NeuralNetTorch_BAG_L1</td>
#       <td id="T_32c83_row7_col1" class="data row7 col1" >0.513237</td>
#       <td id="T_32c83_row7_col2" class="data row7 col2" >roc_auc_ovo</td>
#       <td id="T_32c83_row7_col3" class="data row7 col3" >8.694397</td>
#       <td id="T_32c83_row7_col4" class="data row7 col4" >294.159653</td>
#       <td id="T_32c83_row7_col5" class="data row7 col5" >8.694397</td>
#       <td id="T_32c83_row7_col6" class="dat

# %%
## -- RUN 2: Use original data as extra learning input --
# predictor.fit_pseudolabel(
#                 orig,
#                 use_ensemble = True,
#                 fit_ensemble = True,
#                 time_limit   = 3600*5,
#                 ag_args_fit  = {'num_cpus': os.cpu_count() - 1},
# )

# %%
## -- Get Summary -- 
# print(f"""
#     # {'█'*5}| Total models : {len(predictor.model_names())}
#     # {'█'*5}| Best model   : {predictor.model_best}
#         """)

# # -- Observe RUN 2 RESULTS --
# leaderboard = predictor.leaderboard(silent=True)
# display(leaderboard.style.background_gradient(subset=["score_val"], cmap="Spectral"))

# %%
## -- Create folder directory to save predictions --
SAVE_PATH = '/kaggle/working/AG_loan_predictions/'
# !mkdir {SAVE_PATH}

# %%
## -- Predictions for {SELECTED FEATURE} --
oof_ = predictor.predict_proba_oof(train_data=train, as_multiclass=False)
np.save(f"{SAVE_PATH}oof_AG_on_{TARGET}.npy", oof_)

preds_ = predictor.predict_proba(data=test, as_multiclass=False)
np.save(f"{SAVE_PATH}pred_AG_on_{TARGET}.npy", preds_)

oof_[:5], preds_[:5]
# Out:
# (   Bachelor's  High School  Master's     Other       PhD
#  0    0.439692     0.336152  0.157344  0.046828  0.019984
#  1    0.462428     0.320806  0.154991  0.042132  0.019643
#  2    0.461727     0.311078  0.162332  0.046198  0.018665
#  3    0.456245     0.319959  0.155154  0.049490  0.019152
#  4    0.452769     0.329958  0.148124  0.047076  0.022073,
#     Bachelor's  High School  Master's     Other       PhD
#  0    0.474693     0.306458  0.148679  0.047790  0.022380
#  1    0.458652     0.320618  0.152716  0.048348  0.019666
#  2    0.449236     0.318842  0.153428  0.053057  0.025437
#  3    0.445192     0.333417  0.158554  0.042136  0.020702
#  4    0.476085     0.317736  0.145168  0.041874  0.019137)

# %%
predictor.plot_ensemble_model(filename='ensemble_model.png')
display(Image(f'{MODELS_PATH}ensemble_model.png'))

# %%
# !zip -r /kaggle/working/AG_accident_models /kaggle/working/AG_accident_models.zip
# !zip -r {FOLDER}{NAME_EXT}.zip /kaggle/working/{FOLDER}{NAME_EXT}

# %%
## -- Extract model scores --
result_ = dict(zip(leaderboard['model'], leaderboard['score_val']))
result_df = pd.DataFrame.from_dict(result_, orient='index').sort_values(0)

max_score = result_df.max().item()
min_score = result_df.min().item()

## -- PLOT MODELS & SCORES --
plt.figure(figsize=(18, 15))
plt.stem(
    result_df.index,
    result_df[0],
    orientation = 'horizontal',
    bottom = min_score - 0.0055,
    markerfmt = 'C3o'
)
plt.xlim(min_score - 0.006, max_score + 0.005)
plt.xlabel('Score')
plt.title('-- Scores of Models --', fontsize=15)

for i, value in enumerate(result_df[0]):
    plt.text(value+1e-3, i, f'{abs(value):.5f}', ha='left', va='center', fontdict=dict(size=12))

plt.grid(True, axis='x')
plt.tight_layout()
plt.show()

# %%
# predictor.model_names()

# %%
# ## -- Permutation Feature Importances --
# feat_imp = predictor.feature_importance(
#                         data = X_test,
#                         # time_limit = 3600,
#                         # model = 'LightGBM_BAG_L1',
#                         # features = None,
#                         # feature_stage = 'transformed',
#                         # subsample_size = 5000,
#                         # num_shuffle_sets = 10,
#                         # include_confidence_band = True,
#                         confidence_level = 0.95,
#                         # silent = False
# ) 

# feat_imp.style.background_gradient(subset=["importance"], cmap="Spectral")

# %%
# plt.figure(figsize=(18, 35))
# sns.barplot(data=feat_imp, y=feat_imp.index, x=feat_imp.importance)
# plt.tick_params(axis='y', which='major', labelcolor='r')
# plt.title("Top Features by Permutation")
# plt.tight_layout()
# plt.show()

# %%
## -- OPTIONAL: Remove stored files --
# !rm -r {MODELS_PATH}

# %%
print(f"""
{'-'*48}
{'█'*5} | - AUTOGLUON NOTEBOOK COMPLETE! - | {'█'*5}
{'-'*48}
""")
# Out:
# ------------------------------------------------
# █████ | - AUTOGLUON NOTEBOOK COMPLETE! - | █████
# ------------------------------------------------
