# %%
# %%capture cap
# !pip install -qq ipywidgets
# !pip install -qq autogluon scikit-learn==1.5.2 
# !apt-get install -qq -y graphviz graphviz-dev && pip install -q pydot
# !pip install -qq pygraphviz
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 88.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.9/454.9 kB 21.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.3/487.3 kB 23.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.7/189.7 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.8/285.8 kB 16.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.5/280.5 kB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 52.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 39.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 MB 20.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.4/354.4 kB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 62.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 65.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 70.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.5/963.5 kB 41.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 93.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 25.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 16.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 76.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 85.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 100.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 kB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 26.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 3.2 MB/s eta 0:00:00
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Building wheel for seqeval (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# Selecting previously unselected package libgtk2.0-common.
# (Reading database ... 128639 files and directories currently installed.)
# Preparing to unpack .../0-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../1-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../2-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../3-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libxdot4:amd64.
# Preparing to unpack .../4-libxdot4_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgvc6-plugins-gtk.
# Preparing to unpack .../5-libgvc6-plugins-gtk_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgraphviz-dev:amd64.
# Preparing to unpack .../6-libgraphviz-dev_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../7-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.0/106.0 kB 3.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for pygraphviz (pyproject.toml) ... done

# %%
import torch
import os
import pydot

import random
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
from time import time, sleep
from itertools import combinations

from IPython.display import display, Image
import matplotlib.pyplot as plt
import seaborn as sns

import warnings

warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')

## -- Set Global Seed --
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

pd.set_option('display.max_columns', 500)
plt.style.use("ggplot")

## -- Ansi color codes --
COLOR = '\033[32m'
RESET = '\033[0m'

print("Packages import succesful!")
# Out:
# Packages import succesful!

# %%
### Load Data ###
PATH = "/kaggle/input/playground-series-s5e11/"
submit = pd.read_csv(PATH+"sample_submission.csv")

list_of_targets = ["debt_to_income_ratio", "credit_score", "interest_rate", "employment_status"]
TARGET = list_of_targets[3]

train = pd.read_csv(PATH+"train.csv").drop(['id', "loan_paid_back"], axis=1)
test = pd.read_csv(PATH+"test.csv").drop(['id', TARGET], axis=1)

# ## -- Convert target to float for regression --
# train[TARGET] = train[TARGET].astype(np.float32)

NUMS = test.select_dtypes(include='number').columns.tolist()
CATS = test.select_dtypes(exclude='number').columns.tolist()
BASE = NUMS + CATS

for (name, df) in dict(Train=train, Test=test).items():
    print(f"{name} shape: {df.shape}")

print(f"\nTotal Numerical: {len(NUMS)}")
print(f"Total Categorical: {len(CATS)}")
print(f"Total base features: {len(BASE)}")
# Out:
# Train shape: (593994, 11)
# Test shape: (254569, 10)
#
# Total Numerical: 5
# Total Categorical: 5
# Total base features: 10

# %%
# !rm -r /kaggle/working/AG_loan_models

# %%
from autogluon.tabular import TabularPredictor

# %%
MODELS_PATH = "./AG_loan_models/"

predictor = TabularPredictor(
                label = TARGET,
         # problem_type = "regression",
         #  eval_metric = "roc_auc",
                 path = MODELS_PATH,
    ).fit(
                   train_data = train,
                      presets = "best",
                num_bag_folds = 6,
             # dynamic_stacking = False,
             # num_stack_levels = 1,
                   time_limit = 3600*5,
                   # auto_stack = False,
                 # num_bag_sets = 2,
                  # ag_args_fit = {'num_cpus': os.cpu_count()},
)
# Out:
# Preset alias specified: 'best' maps to 'best_quality'.
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.11.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Sat Sep 27 10:16:09 UTC 2025
# CPU Count:          4
# Memory Avail:       29.93 GB / 31.35 GB (95.5%)
# Disk Space Avail:   19.50 GB / 19.52 GB (99.9%)
# ===================================================
# Presets specified: ['best']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=6, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 4500s of the 18000s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-11-29 03:45:57,051	INFO worker.py:1843 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho"
# (_dystack pid=413) Running DyStack sub-fit ...
# (_dystack pid=413) Beginning AutoGluon training ... Time limit = 4495s
# (_dystack pid=413) AutoGluon will save models to "/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho"
# (_dystack pid=413) Train Data Rows:    527994
# (_dystack pid=413) Train Data Columns: 10
# (_dystack pid=413) Label Column:       employment_status
# (_dystack pid=413) Problem Type:       multiclass
# (_dystack pid=413) Preprocessing data ...
# (_dystack pid=413) Train Data Class Count: 5
# (_dystack pid=413) Using Feature Generators to preprocess the data ...
# (_dystack pid=413) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=413) 	Available Memory:                    30095.25 MB
# (_dystack pid=413) 	Train Data (Original)  Memory Usage: 181.56 MB (0.6% of available memory)
# (_dystack pid=413) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=413) 	Stage 1 Generators:
# (_dystack pid=413) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=413) 	Stage 2 Generators:
# (_dystack pid=413) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=413) 	Stage 3 Generators:
# (_dystack pid=413) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=413) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=413) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=413) 	Stage 4 Generators:
# (_dystack pid=413) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=413) 	Stage 5 Generators:
# (_dystack pid=413) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=413) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=413) 		('float', [])  : 4 | ['annual_income', 'debt_to_income_ratio', 'loan_amount', 'interest_rate']
# (_dystack pid=413) 		('int', [])    : 1 | ['credit_score']
# (_dystack pid=413) 		('object', []) : 5 | ['gender', 'marital_status', 'education_level', 'loan_purpose', 'grade_subgrade']
# (_dystack pid=413) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=413) 		('category', []) : 5 | ['gender', 'marital_status', 'education_level', 'loan_purpose', 'grade_subgrade']
# (_dystack pid=413) 		('float', [])    : 4 | ['annual_income', 'debt_to_income_ratio', 'loan_amount', 'interest_rate']
# (_dystack pid=413) 		('int', [])      : 1 | ['credit_score']
# (_dystack pid=413) 	2.0s = Fit runtime
# (_dystack pid=413) 	10 features in original data used to generate 10 features in processed data.
# (_dystack pid=413) 	Train Data (Processed) Memory Usage: 22.66 MB (0.1% of available memory)
# (_dystack pid=413) Data preprocessing and feature engineering runtime = 2.72s ...
# (_dystack pid=413) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=413) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=413) Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=413) User-specified model hyperparameters to be fit:
# (_dystack pid=413) {
# (_dystack pid=413) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=413) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=413) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=413) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=413) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=413) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=413) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=413) }
# (_dystack pid=413) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=413) Fitting 108 L1 models, fit_strategy="sequential" ...
# (_dystack pid=413) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2994.23s of the 4492.46s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.00%)
# (_ray_fit pid=706) No improvement since epoch 0: early stopping
# (_ray_fit pid=708) No improvement since epoch 1: early stopping [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_ray_fit pid=705) No improvement since epoch 1: early stopping
# (_ray_fit pid=956) No improvement since epoch 0: early stopping
# (_ray_fit pid=992) No improvement since epoch 0: early stopping
# (_dystack pid=413) 	0.7587	 = Validation score   (accuracy)
# (_dystack pid=413) 	730.06s	 = Training   runtime
# (_dystack pid=413) 	7.61s	 = Validation runtime
# (_dystack pid=413) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2256.89s of the 3755.11s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.74%)
# (_dystack pid=413) 	0.7587	 = Validation score   (accuracy)
# (_dystack pid=413) 	33.54s	 = Training   runtime
# (_dystack pid=413) 	0.46s	 = Validation runtime
# (_dystack pid=413) Fitting model: LightGBM_BAG_L1 ... Training model for up to 2218.81s of the 3717.04s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.74%)
# (_dystack pid=413) 	0.7587	 = Validation score   (accuracy)
# (_dystack pid=413) 	27.87s	 = Training   runtime
# (_dystack pid=413) 	0.48s	 = Validation runtime
# (_dystack pid=413) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 2186.52s of the 3684.74s of remaining time.
# (_dystack pid=413) 	0.7587	 = Validation score   (accuracy)
# (_dystack pid=413) 	203.22s	 = Training   runtime
# (_dystack pid=413) 	28.15s	 = Validation runtime
# (_dystack pid=413) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 1950.86s of the 3449.09s of remaining time.
# (_dystack pid=413) 	0.7587	 = Validation score   (accuracy)
# (_dystack pid=413) 	285.97s	 = Training   runtime
# (_dystack pid=413) 	32.2s	 = Validation runtime
# (_dystack pid=413) Fitting model: CatBoost_BAG_L1 ... Training model for up to 1628.59s of the 3126.82s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.04%)
# (_dystack pid=413) 	0.7587	 = Validation score   (accuracy)
# (_dystack pid=413) 	348.06s	 = Training   runtime
# (_dystack pid=413) 	0.28s	 = Validation runtime
# (_dystack pid=413) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 1276.17s of the 2774.40s of remaining time.
# (_dystack pid=413) 	0.7587	 = Validation score   (accuracy)
# (_dystack pid=413) 	56.11s	 = Training   runtime
# (_dystack pid=413) 	25.04s	 = Validation runtime
# (_dystack pid=413) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 1193.15s of the 2691.38s of remaining time.
# (_dystack pid=413) 	0.7587	 = Validation score   (accuracy)
# (_dystack pid=413) 	63.67s	 = Training   runtime
# (_dystack pid=413) 	28.3s	 = Validation runtime
# (_dystack pid=413) Fitting model: XGBoost_BAG_L1 ... Training model for up to 1098.95s of the 2597.17s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.93%)
# (_dystack pid=413) 	0.7587	 = Validation score   (accuracy)
# (_dystack pid=413) 	294.8s	 = Training   runtime
# (_dystack pid=413) 	3.47s	 = Validation runtime
# (_dystack pid=413) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 799.83s of the 2298.06s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.58%)
# (_ray_fit pid=2839) 	Ran out of time, stopping training early. (Stopping on epoch 13)
# (_ray_fit pid=2838) 	Ran out of time, stopping training early. (Stopping on epoch 13)
# (_ray_fit pid=3044) 	Ran out of time, stopping training early. (Stopping on epoch 17)
# (_ray_fit pid=3084) 	Ran out of time, stopping training early. (Stopping on epoch 17)
# (_dystack pid=413) 	0.7587	 = Validation score   (accuracy)
# (_dystack pid=413) 	650.06s	 = Training   runtime
# (_dystack pid=413) 	8.17s	 = Validation runtime
# (_dystack pid=413) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 144.57s of the 1642.79s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.94%)
# (_dystack pid=413) 	0.7587	 = Validation score   (accuracy)
# (_dystack pid=413) 	32.7s	 = Training   runtime
# (_dystack pid=413) 	0.57s	 = Validation runtime
# (_dystack pid=413) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 107.42s of the 1605.64s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.08%)
# (_ray_fit pid=3593) 	Ran out of time, early stopping on iteration 11.
# (_dystack pid=413) 	0.7587	 = Validation score   (accuracy)
# (_dystack pid=413) 	79.31s	 = Training   runtime
# (_dystack pid=413) 	0.33s	 = Validation runtime
# (_dystack pid=413) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 23.32s of the 1521.54s of remaining time.
# (_ray_fit pid=3594) 	Ran out of time, early stopping on iteration 11. [repeated 3x across cluster]
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.60%)
# (_dystack pid=413) 	Time limit exceeded... Skipping NeuralNetTorch_r79_BAG_L1.
# (_dystack pid=413) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 6.00s of the 1504.22s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.80%)
# (_ray_fit pid=4162) 	Ran out of time, early stopping on iteration 2. Best iteration is:
# (_ray_fit pid=4162) 	[1]	valid_set's multi_error: 0.241332
# (_ray_fit pid=4339) 	Ran out of time, early stopping on iteration 4. Best iteration is: [repeated 4x across cluster]
# (_ray_fit pid=4339) 	[1]	valid_set's multi_error: 0.241332 [repeated 4x across cluster]
# (_dystack pid=413) 	0.7587	 = Validation score   (accuracy)
# (_dystack pid=413) 	14.22s	 = Training   runtime
# (_dystack pid=413) 	0.56s	 = Validation runtime
# (_dystack pid=413) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 1484.43s of remaining time.
# (_dystack pid=413) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 1.0}
# (_dystack pid=413) 	0.7587	 = Validation score   (accuracy)
# (_dystack pid=413) 	20.34s	 = Training   runtime
# (_dystack pid=413) 	0.07s	 = Validation runtime
# (_dystack pid=413) Fitting 108 L2 models, fit_strategy="sequential" ...
# (_ray_fit pid=4346) 	Ran out of time, early stopping on iteration 4. Best iteration is:
# (_ray_fit pid=4346) 	[1]	valid_set's multi_error: 0.241332
# (_dystack pid=413) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1463.89s of the 1463.08s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=6.01%)
# (_dystack pid=413) 	0.7587	 = Validation score   (accuracy)
# (_dystack pid=413) 	831.15s	 = Training   runtime
# (_dystack pid=413) 	9.93s	 = Validation runtime
# (_dystack pid=413) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 625.30s of the 624.48s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=4.08%)
# (_dystack pid=413) 	0.7587	 = Validation score   (accuracy)
# (_dystack pid=413) 	103.03s	 = Training   runtime
# (_dystack pid=413) 	0.99s	 = Validation runtime
# (_dystack pid=413) Fitting model: LightGBM_BAG_L2 ... Training model for up to 515.89s of the 515.07s of remaining time.
# (_dystack pid=413) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=4.08%)
# (_dystack pid=413) 	0.7587	 = Validation score   (accuracy)
# (_dystack pid=413) 	103.29s	 = Training   runtime
# (_dystack pid=413) 	1.33s	 = Validation runtime
# (_dystack pid=413) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 405.90s of the 405.09s of remaining time.
# (_dystack pid=413) 	Warning: Reducing model 'n_estimators' from 300 -> 92 due to low time. Expected time usage reduced from 1311.5s -> 403.3s...
# (_dystack pid=413) 	0.7583	 = Validation score   (accuracy)
# (_dystack pid=413) 	396.44s	 = Training   runtime
# (_dystack pid=413) 	15.11s	 = Validation runtime
# (_dystack pid=413) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the -9.34s of remaining time.
# (_dystack pid=413) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L2': 0.909, 'RandomForestGini_BAG_L2': 0.091}
# (_dystack pid=413) 	0.7587	 = Validation score   (accuracy)
# (_dystack pid=413) 	25.94s	 = Training   runtime
# (_dystack pid=413) 	0.08s	 = Validation runtime
# (_dystack pid=413) AutoGluon training complete, total runtime = 4530.75s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 1649.8 rows/s (87999 batch size)
# (_dystack pid=413) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho")
# (_dystack pid=413) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=413) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=413) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=413) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   RandomForestGini_BAG_L2       0.758697   0.758259    accuracy       64.848397     150.715154  3216.022798                 3.334840               15.107184         396.444407            2       True         18
# 1           LightGBM_BAG_L1       0.758667   0.758670    accuracy        0.127414       0.481467    27.865061                 0.127414                0.481467          27.865061            1       True          3
# 2      LightGBM_r131_BAG_L1       0.758667   0.758670    accuracy        0.151535       0.557863    14.215445                 0.151535                0.557863          14.215445            1       True         13
# 3      LightGBMLarge_BAG_L1       0.758667   0.758670    accuracy        0.169019       0.571199    32.696913                 0.169019                0.571199          32.696913            1       True         11
# 4      CatBoost_r177_BAG_L1       0.758667   0.758670    accuracy        0.304330       0.329326    79.310388                 0.304330                0.329326          79.310388            1       True         12
# 5           CatBoost_BAG_L1       0.758667   0.758670    accuracy        1.896531       0.284140   348.056483                 1.896531                0.284140         348.056483            1       True          6
# 6     NeuralNetTorch_BAG_L1       0.758667   0.758670    accuracy        3.055865       8.172129   650.062007                 3.055865                8.172129         650.062007            1       True         10
# 7         LightGBMXT_BAG_L1       0.758667   0.758670    accuracy        4.680910       0.457757    33.535171                 4.680910                0.457757          33.535171            1       True          2
# 8    NeuralNetFastAI_BAG_L1       0.758667   0.758679    accuracy        5.553163       7.607547   730.056849                 5.553163                7.607547         730.056849            1       True          1
# 9       WeightedEnsemble_L2       0.758667   0.758679    accuracy        5.557381       7.680444   750.393518                 0.004217                0.072897          20.336668            2       True         14
# 10  RandomForestGini_BAG_L1       0.758667   0.758668    accuracy        7.386415      28.148552   203.223339                 7.386415               28.148552         203.223339            1       True          4
# 11  RandomForestEntr_BAG_L1       0.758667   0.758670    accuracy       10.935618      32.195793   285.971803                10.935618               32.195793         285.971803            1       True          5
# 12    ExtraTreesEntr_BAG_L1       0.758667   0.758670    accuracy       12.205901      28.300228    63.673135                12.205901               28.300228          63.673135            1       True          8
# 13    ExtraTreesGini_BAG_L1       0.758667   0.758673    accuracy       13.420465      25.035196    56.114840                13.420465               25.035196          56.114840            1       True          7
# 14          LightGBM_BAG_L2       0.758667   0.758670    accuracy       61.864412     136.935961  2922.867857                 0.350854                1.327991         103.289466            2       True         17
# 15        LightGBMXT_BAG_L2       0.758667   0.758670    accuracy       61.873485     136.597564  2922.603737                 0.359927                0.989594         103.025346            2       True         16
# 16   NeuralNetFastAI_BAG_L2       0.758652   0.758723    accuracy       66.903332     145.539706  3650.728968                 5.389775                9.931736         831.150577            2       True         15
# 17      WeightedEnsemble_L3       0.758652   0.758734    accuracy       70.245777     160.726202  4073.112823                 0.007605                0.079311          25.939448            3       True         19
# 18           XGBoost_BAG_L1       0.758636   0.758675    accuracy        1.626391       3.466773   294.796957                 1.626391                3.466773         294.796957            1       True          9
# 	0	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: True)
# 	4613s	 = DyStack   runtime |	13387s	 = Remaining runtime
# Starting main fit with num_stack_levels=0.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=0)`
# Beginning AutoGluon training ... Time limit = 13387s
# AutoGluon will save models to "/kaggle/working/AG_loan_models"
# Train Data Rows:    593994
# Train Data Columns: 10
# Label Column:       employment_status
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 5
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    30169.70 MB
# 	Train Data (Original)  Memory Usage: 204.29 MB (0.7% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 4 | ['annual_income', 'debt_to_income_ratio', 'loan_amount', 'interest_rate']
# 		('int', [])    : 1 | ['credit_score']
# 		('object', []) : 5 | ['gender', 'marital_status', 'education_level', 'loan_purpose', 'grade_subgrade']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 5 | ['gender', 'marital_status', 'education_level', 'loan_purpose', 'grade_subgrade']
# 		('float', [])    : 4 | ['annual_income', 'debt_to_income_ratio', 'loan_amount', 'interest_rate']
# 		('int', [])      : 1 | ['credit_score']
# 	2.6s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 25.49 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 3.65s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# Fitting 108 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 13382.95s of the 13382.94s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.94%)
# 	0.7587	 = Validation score   (accuracy)
# 	908.8s	 = Training   runtime
# 	10.82s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 12467.62s of the 12467.60s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.69%)
# 	0.7587	 = Validation score   (accuracy)
# 	32.46s	 = Training   runtime
# 	0.72s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 12430.08s of the 12430.06s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.69%)
# 	0.7587	 = Validation score   (accuracy)
# 	31.71s	 = Training   runtime
# 	0.59s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 12393.57s of the 12393.56s of remaining time.
# 	0.7587	 = Validation score   (accuracy)
# 	245.24s	 = Training   runtime
# 	30.74s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 12114.07s of the 12114.05s of remaining time.
# 	0.7587	 = Validation score   (accuracy)
# 	339.74s	 = Training   runtime
# 	35.92s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 11733.96s of the 11733.94s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.97%)
# 	0.7587	 = Validation score   (accuracy)
# 	314.22s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 11415.30s of the 11415.29s of remaining time.
# 	0.7587	 = Validation score   (accuracy)
# 	73.41s	 = Training   runtime
# 	27.35s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 11312.53s of the 11312.52s of remaining time.
# 	0.7587	 = Validation score   (accuracy)
# 	88.3s	 = Training   runtime
# 	31.01s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 11191.14s of the 11191.12s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.89%)
# 	0.7587	 = Validation score   (accuracy)
# 	613.43s	 = Training   runtime
# 	5.57s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 10571.99s of the 10571.97s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	0.7587	 = Validation score   (accuracy)
# 	1333.58s	 = Training   runtime
# 	7.94s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 9232.85s of the 9232.84s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.90%)
# 	0.7587	 = Validation score   (accuracy)
# 	36.48s	 = Training   runtime
# 	0.71s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 9191.64s of the 9191.63s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.02%)
# 	0.7587	 = Validation score   (accuracy)
# 	121.71s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 9065.32s of the 9065.30s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.56%)
# 	0.7587	 = Validation score   (accuracy)
# 	993.23s	 = Training   runtime
# 	10.78s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 8066.47s of the 8066.46s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.76%)
# 	0.7587	 = Validation score   (accuracy)
# 	32.78s	 = Training   runtime
# 	0.7s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 8029.07s of the 8029.05s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.00%)
# 	0.7587	 = Validation score   (accuracy)
# 	4239.36s	 = Training   runtime
# 	28.33s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 3780.84s of the 3780.82s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.15%)
# 	0.7587	 = Validation score   (accuracy)
# 	349.29s	 = Training   runtime
# 	0.68s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 3426.24s of the 3426.23s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.69%)
# 	0.7587	 = Validation score   (accuracy)
# 	30.22s	 = Training   runtime
# 	0.61s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 3391.68s of the 3391.67s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.7587	 = Validation score   (accuracy)
# 	1441.91s	 = Training   runtime
# 	13.87s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 1943.44s of the 1943.42s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.03%)
# 	0.7587	 = Validation score   (accuracy)
# 	418.5s	 = Training   runtime
# 	5.15s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 1519.55s of the 1519.54s of remaining time.
# 	0.7587	 = Validation score   (accuracy)
# 	127.0s	 = Training   runtime
# 	29.41s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 1359.10s of the 1359.08s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.95%)
# 	0.7587	 = Validation score   (accuracy)
# 	234.35s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 1120.34s of the 1120.32s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.08%)
# 	0.7587	 = Validation score   (accuracy)
# 	442.27s	 = Training   runtime
# 	4.73s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 672.71s of the 672.69s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.05%)
# 	0.7587	 = Validation score   (accuracy)
# 	205.14s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 462.82s of the 462.81s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 194 due to low time. Expected time usage reduced from 714.8s -> 462.6s...
# 	0.7582	 = Validation score   (accuracy)
# 	437.88s	 = Training   runtime
# 	30.57s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 1338.29s of the -12.16s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_r191_BAG_L1': 1.0}
# 	0.7587	 = Validation score   (accuracy)
# 	44.15s	 = Training   runtime
# 	0.06s	 = Validation runtime
# AutoGluon training complete, total runtime = 13443.29s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 3493.7 rows/s (98999 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AG_loan_models")

# %%
## -- Get Summary -- 
print(f"-> Total models : {len(predictor.model_names())}")
print(f"-> Best model   : {predictor.model_best}") 

## -- Observe RUN 1 RESULTS -- 
leaderboard = predictor.leaderboard(silent=True)
leaderboard.style.background_gradient(subset=["score_val"], cmap="Spectral")
# Out:
# -> Total models : 25
# -> Best model   : WeightedEnsemble_L2
# <style type="text/css">
# #T_8c62e_row0_col1, #T_8c62e_row1_col1, #T_8c62e_row2_col1 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_8c62e_row3_col1 {
#   background-color: #5b53a4;
#   color: #f1f1f1;
# }
# #T_8c62e_row4_col1, #T_8c62e_row5_col1 {
#   background-color: #5956a5;
#   color: #f1f1f1;
# }
# #T_8c62e_row6_col1 {
#   background-color: #5758a6;
#   color: #f1f1f1;
# }
# #T_8c62e_row7_col1, #T_8c62e_row8_col1, #T_8c62e_row9_col1, #T_8c62e_row10_col1, #T_8c62e_row11_col1, #T_8c62e_row12_col1, #T_8c62e_row13_col1, #T_8c62e_row14_col1, #T_8c62e_row15_col1, #T_8c62e_row16_col1, #T_8c62e_row17_col1, #T_8c62e_row18_col1, #T_8c62e_row19_col1, #T_8c62e_row20_col1, #T_8c62e_row21_col1 {
#   background-color: #555aa7;
#   color: #f1f1f1;
# }
# #T_8c62e_row22_col1 {
#   background-color: #545ca8;
#   color: #f1f1f1;
# }
# #T_8c62e_row23_col1 {
#   background-color: #5061aa;
#   color: #f1f1f1;
# }
# #T_8c62e_row24_col1 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8c62e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c62e_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_8c62e_level0_col1" class="col_heading level0 col1" >score_val</th>
#       <th id="T_8c62e_level0_col2" class="col_heading level0 col2" >eval_metric</th>
#       <th id="T_8c62e_level0_col3" class="col_heading level0 col3" >pred_time_val</th>
#       <th id="T_8c62e_level0_col4" class="col_heading level0 col4" >fit_time</th>
#       <th id="T_8c62e_level0_col5" class="col_heading level0 col5" >pred_time_val_marginal</th>
#       <th id="T_8c62e_level0_col6" class="col_heading level0 col6" >fit_time_marginal</th>
#       <th id="T_8c62e_level0_col7" class="col_heading level0 col7" >stack_level</th>
#       <th id="T_8c62e_level0_col8" class="col_heading level0 col8" >can_infer</th>
#       <th id="T_8c62e_level0_col9" class="col_heading level0 col9" >fit_order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c62e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8c62e_row0_col0" class="data row0 col0" >NeuralNetFastAI_r191_BAG_L1</td>
#       <td id="T_8c62e_row0_col1" class="data row0 col1" >0.758679</td>
#       <td id="T_8c62e_row0_col2" class="data row0 col2" >accuracy</td>
#       <td id="T_8c62e_row0_col3" class="data row0 col3" >28.326045</td>
#       <td id="T_8c62e_row0_col4" class="data row0 col4" >4239.363661</td>
#       <td id="T_8c62e_row0_col5" class="data row0 col5" >28.326045</td>
#       <td id="T_8c62e_row0_col6" class="data row0 col6" >4239.363661</td>
#       <td id="T_8c62e_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_8c62e_row0_col8" class="data row0 col8" >True</td>
#       <td id="T_8c62e_row0_col9" class="data row0 col9" >15</td>
#     </tr>
#     <tr>
#       <th id="T_8c62e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8c62e_row1_col0" class="data row1 col0" >WeightedEnsemble_L2</td>
#       <td id="T_8c62e_row1_col1" class="data row1 col1" >0.758679</td>
#       <td id="T_8c62e_row1_col2" class="data row1 col2" >accuracy</td>
#       <td id="T_8c62e_row1_col3" class="data row1 col3" >28.389107</td>
#       <td id="T_8c62e_row1_col4" class="data row1 col4" >4283.518383</td>
#       <td id="T_8c62e_row1_col5" class="data row1 col5" >0.063062</td>
#       <td id="T_8c62e_row1_col6" class="data row1 col6" >44.154722</td>
#       <td id="T_8c62e_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_8c62e_row1_col8" class="data row1 col8" >True</td>
#       <td id="T_8c62e_row1_col9" class="data row1 col9" >25</td>
#     </tr>
#     <tr>
#       <th id="T_8c62e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8c62e_row2_col0" class="data row2 col0" >NeuralNetFastAI_r102_BAG_L1</td>
#       <td id="T_8c62e_row2_col1" class="data row2 col1" >0.758678</td>
#       <td id="T_8c62e_row2_col2" class="data row2 col2" >accuracy</td>
#       <td id="T_8c62e_row2_col3" class="data row2 col3" >4.734182</td>
#       <td id="T_8c62e_row2_col4" class="data row2 col4" >442.271491</td>
#       <td id="T_8c62e_row2_col5" class="data row2 col5" >4.734182</td>
#       <td id="T_8c62e_row2_col6" class="data row2 col6" >442.271491</td>
#       <td id="T_8c62e_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_8c62e_row2_col8" class="data row2 col8" >True</td>
#       <td id="T_8c62e_row2_col9" class="data row2 col9" >22</td>
#     </tr>
#     <tr>
#       <th id="T_8c62e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8c62e_row3_col0" class="data row3 col0" >XGBoost_r33_BAG_L1</td>
#       <td id="T_8c62e_row3_col1" class="data row3 col1" >0.758674</td>
#       <td id="T_8c62e_row3_col2" class="data row3 col2" >accuracy</td>
#       <td id="T_8c62e_row3_col3" class="data row3 col3" >5.145726</td>
#       <td id="T_8c62e_row3_col4" class="data row3 col4" >418.504266</td>
#       <td id="T_8c62e_row3_col5" class="data row3 col5" >5.145726</td>
#       <td id="T_8c62e_row3_col6" class="data row3 col6" >418.504266</td>
#       <td id="T_8c62e_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_8c62e_row3_col8" class="data row3 col8" >True</td>
#       <td id="T_8c62e_row3_col9" class="data row3 col9" >19</td>
#     </tr>
#     <tr>
#       <th id="T_8c62e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8c62e_row4_col0" class="data row4 col0" >NeuralNetFastAI_BAG_L1</td>
#       <td id="T_8c62e_row4_col1" class="data row4 col1" >0.758673</td>
#       <td id="T_8c62e_row4_col2" class="data row4 col2" >accuracy</td>
#       <td id="T_8c62e_row4_col3" class="data row4 col3" >10.818612</td>
#       <td id="T_8c62e_row4_col4" class="data row4 col4" >908.804459</td>
#       <td id="T_8c62e_row4_col5" class="data row4 col5" >10.818612</td>
#       <td id="T_8c62e_row4_col6" class="data row4 col6" >908.804459</td>
#       <td id="T_8c62e_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_8c62e_row4_col8" class="data row4 col8" >True</td>
#       <td id="T_8c62e_row4_col9" class="data row4 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8c62e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8c62e_row5_col0" class="data row5 col0" >ExtraTrees_r42_BAG_L1</td>
#       <td id="T_8c62e_row5_col1" class="data row5 col1" >0.758673</td>
#       <td id="T_8c62e_row5_col2" class="data row5 col2" >accuracy</td>
#       <td id="T_8c62e_row5_col3" class="data row5 col3" >29.406352</td>
#       <td id="T_8c62e_row5_col4" class="data row5 col4" >126.995640</td>
#       <td id="T_8c62e_row5_col5" class="data row5 col5" >29.406352</td>
#       <td id="T_8c62e_row5_col6" class="data row5 col6" >126.995640</td>
#       <td id="T_8c62e_row5_col7" class="data row5 col7" >1</td>
#       <td id="T_8c62e_row5_col8" class="data row5 col8" >True</td>
#       <td id="T_8c62e_row5_col9" class="data row5 col9" >20</td>
#     </tr>
#     <tr>
#       <th id="T_8c62e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8c62e_row6_col0" class="data row6 col0" >NeuralNetTorch_r22_BAG_L1</td>
#       <td id="T_8c62e_row6_col1" class="data row6 col1" >0.758671</td>
#       <td id="T_8c62e_row6_col2" class="data row6 col2" >accuracy</td>
#       <td id="T_8c62e_row6_col3" class="data row6 col3" >13.870969</td>
#       <td id="T_8c62e_row6_col4" class="data row6 col4" >1441.914574</td>
#       <td id="T_8c62e_row6_col5" class="data row6 col5" >13.870969</td>
#       <td id="T_8c62e_row6_col6" class="data row6 col6" >1441.914574</td>
#       <td id="T_8c62e_row6_col7" class="data row6 col7" >1</td>
#       <td id="T_8c62e_row6_col8" class="data row6 col8" >True</td>
#       <td id="T_8c62e_row6_col9" class="data row6 col9" >18</td>
#     </tr>
#     <tr>
#       <th id="T_8c62e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8c62e_row7_col0" class="data row7 col0" >CatBoost_BAG_L1</td>
#       <td id="T_8c62e_row7_col1" class="data row7 col1" >0.758669</td>
#       <td id="T_8c62e_row7_col2" class="data row7 col2" >accuracy</td>
#       <td id="T_8c62e_row7_col3" class="data row7 col3" >0.270374</td>
#       <td id="T_8c62e_row7_col4" class="data row7 col4"

# %%
## -- RUN 2: Use original data as extra learning input --
# predictor.fit_pseudolabel(
#                 orig,
#                 use_ensemble = True,
#                 fit_ensemble = True,
#                 time_limit   = 3600*5,
#                 ag_args_fit  = {'num_cpus': os.cpu_count() - 1},
# )

# %%
## -- Get Summary -- 
# print(f"""
#     # {'█'*5}| Total models : {len(predictor.model_names())}
#     # {'█'*5}| Best model   : {predictor.model_best}
#         """)

# # -- Observe RUN 2 RESULTS --
# leaderboard = predictor.leaderboard(silent=True)
# display(leaderboard.style.background_gradient(subset=["score_val"], cmap="Spectral"))

# %%
## -- Create folder directory to save predictions --
SAVE_PATH = '/kaggle/working/AG_loan_predictions/'
# !mkdir {SAVE_PATH}

# %%
## -- Predictions for {SELECTED FEATURE} --
oof_ = predictor.predict_oof(train_data=train)
np.save(f"{SAVE_PATH}oof_AG_on_{TARGET}.npy", oof_)

preds_ = predictor.predict(test)
np.save(f"{SAVE_PATH}pred_AG_on_{TARGET}.npy", preds_)

oof_[:5], preds_[:5]
# Out:
# (0    Employed
#  1    Employed
#  2    Employed
#  3    Employed
#  4    Employed
#  dtype: object,
#  0    Employed
#  1    Employed
#  2    Employed
#  3    Employed
#  4    Employed
#  Name: employment_status, dtype: object)

# %%
predictor.plot_ensemble_model(filename='ensemble_model.png')
display(Image(f'{MODELS_PATH}ensemble_model.png'))

# %%
# !zip -r /kaggle/working/AG_accident_models /kaggle/working/AG_accident_models.zip
# !zip -r {FOLDER}{NAME_EXT}.zip /kaggle/working/{FOLDER}{NAME_EXT}

# %%
## -- Extract model scores --
result_ = dict(zip(leaderboard['model'], leaderboard['score_val']))
result_df = pd.DataFrame.from_dict(result_, orient='index').sort_values(0)

max_score = result_df.max().item()
min_score = result_df.min().item()

## -- PLOT MODELS & SCORES --
plt.figure(figsize=(18, 15))
plt.stem(
    result_df.index,
    result_df[0],
    orientation = 'horizontal',
    bottom = min_score - 0.0055,
    markerfmt = 'C3o'
)
plt.xlim(min_score - 0.006, max_score + 0.005)
plt.xlabel('Score')
plt.title('-- Scores of Models --', fontsize=15)

for i, value in enumerate(result_df[0]):
    plt.text(value+1e-3, i, f'{abs(value):.5f}', ha='left', va='center', fontdict=dict(size=12))

plt.grid(True, axis='x')
plt.tight_layout()
plt.show()

# %%
# predictor.model_names()

# %%
# ## -- Permutation Feature Importances --
# feat_imp = predictor.feature_importance(
#                         data = X_test,
#                         # time_limit = 3600,
#                         # model = 'LightGBM_BAG_L1',
#                         # features = None,
#                         # feature_stage = 'transformed',
#                         # subsample_size = 5000,
#                         # num_shuffle_sets = 10,
#                         # include_confidence_band = True,
#                         confidence_level = 0.95,
#                         # silent = False
# ) 

# feat_imp.style.background_gradient(subset=["importance"], cmap="Spectral")

# %%
# plt.figure(figsize=(18, 35))
# sns.barplot(data=feat_imp, y=feat_imp.index, x=feat_imp.importance)
# plt.tick_params(axis='y', which='major', labelcolor='r')
# plt.title("Top Features by Permutation")
# plt.tight_layout()
# plt.show()

# %%
## -- OPTIONAL: Remove stored files --
# !rm -r {MODELS_PATH}

# %%
print(f"""
{'-'*48}
{'█'*5} | - AUTOGLUON NOTEBOOK COMPLETE! - | {'█'*5}
{'-'*48}
""")
# Out:
# ------------------------------------------------
# █████ | - AUTOGLUON NOTEBOOK COMPLETE! - | █████
# ------------------------------------------------
