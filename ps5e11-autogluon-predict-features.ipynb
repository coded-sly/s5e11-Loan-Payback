# %%
# %%capture cap
# !pip install -qq ipywidgets
# !pip install -qq autogluon scikit-learn==1.5.2 
# !apt-get install -qq -y graphviz graphviz-dev && pip install -q pydot
# !pip install -qq pygraphviz
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 9.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 90.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.9/454.9 kB 22.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.3/487.3 kB 23.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.7/189.7 kB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.8/285.8 kB 14.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.5/280.5 kB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 53.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 38.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 19.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 MB 25.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.4/354.4 kB 18.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 71.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 88.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 35.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 19.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.5/963.5 kB 33.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 102.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 23.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 76.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 85.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 99.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 25.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 3.2 MB/s eta 0:00:00
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Building wheel for seqeval (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# Selecting previously unselected package libgtk2.0-common.
# (Reading database ... 128639 files and directories currently installed.)
# Preparing to unpack .../0-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../1-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../2-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../3-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libxdot4:amd64.
# Preparing to unpack .../4-libxdot4_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgvc6-plugins-gtk.
# Preparing to unpack .../5-libgvc6-plugins-gtk_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgraphviz-dev:amd64.
# Preparing to unpack .../6-libgraphviz-dev_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../7-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.0/106.0 kB 2.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for pygraphviz (pyproject.toml) ... done

# %%
import torch
import os
import pydot

import random
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
from time import time, sleep
from itertools import combinations

from IPython.display import display, Image
import matplotlib.pyplot as plt
import seaborn as sns

import warnings

warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')

## -- Set Global Seed --
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

pd.set_option('display.max_columns', 500)
plt.style.use("ggplot")

## -- Ansi color codes --
COLOR = '\033[32m'
RESET = '\033[0m'

print("Packages import succesful!")
# Out:
# Packages import succesful!

# %%
### Load Data ###
PATH = "/kaggle/input/playground-series-s5e11/"
submit = pd.read_csv(PATH+"sample_submission.csv")

list_of_targets = [
    'debt_to_income_ratio',
    'credit_score',
    'interest_rate',
    'employment_status',
    'annual_income',
    'loan_amount',
    'gender',
    'marital_status',
    'education_level',
    'loan_purpose',
    'grade_subgrade',
]

TARGET = list_of_targets[5]

train = pd.read_csv(PATH+"train.csv").drop(['id', "loan_paid_back"], axis=1)
test = pd.read_csv(PATH+"test.csv").drop(['id', TARGET], axis=1)

# ## -- Convert target to float for regression --
# train[TARGET] = train[TARGET].astype(np.float32)

NUMS = test.select_dtypes(include='number').columns.tolist()
CATS = test.select_dtypes(exclude='number').columns.tolist()
BASE = NUMS + CATS

for (name, df) in dict(Train=train, Test=test).items():
    print(f"{name} shape: {df.shape}")

print(f"\nTotal Numerical: {len(NUMS)}")
print(f"Total Categorical: {len(CATS)}")
print(f"Total base features: {len(BASE)}")
# Out:
# Train shape: (593994, 11)
# Test shape: (254569, 10)
#
# Total Numerical: 4
# Total Categorical: 6
# Total base features: 10

# %%
# !rm -r /kaggle/working/AG_loan_models

# %%
from autogluon.tabular import TabularPredictor

# %%
MODELS_PATH = "./AG_loan_models/"

predictor = TabularPredictor(
                label = TARGET,
         problem_type = "regression",
         #  eval_metric = "roc_auc",
                 path = MODELS_PATH,
    ).fit(
                   train_data = train,
                      presets = "best",
                num_bag_folds = 6,
             # dynamic_stacking = False,
             # num_stack_levels = 1,
                   time_limit = 3600*5,
                   # auto_stack = False,
                 # num_bag_sets = 2,
                  # ag_args_fit = {'num_cpus': os.cpu_count()},
)
# Out:
# Preset alias specified: 'best' maps to 'best_quality'.
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.11.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Sat Sep 27 10:16:09 UTC 2025
# CPU Count:          4
# Memory Avail:       29.95 GB / 31.35 GB (95.5%)
# Disk Space Avail:   19.50 GB / 19.52 GB (99.9%)
# ===================================================
# Presets specified: ['best']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=6, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 4500s of the 18000s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-11-29 10:36:17,756	INFO worker.py:1843 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho"
# (_dystack pid=415) Running DyStack sub-fit ...
# (_dystack pid=415) Beginning AutoGluon training ... Time limit = 4495s
# (_dystack pid=415) AutoGluon will save models to "/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho"
# (_dystack pid=415) Train Data Rows:    527994
# (_dystack pid=415) Train Data Columns: 10
# (_dystack pid=415) Label Column:       loan_amount
# (_dystack pid=415) Problem Type:       regression
# (_dystack pid=415) Preprocessing data ...
# (_dystack pid=415) Using Feature Generators to preprocess the data ...
# (_dystack pid=415) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=415) 	Available Memory:                    30104.11 MB
# (_dystack pid=415) 	Train Data (Original)  Memory Usage: 210.58 MB (0.7% of available memory)
# (_dystack pid=415) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=415) 	Stage 1 Generators:
# (_dystack pid=415) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=415) 	Stage 2 Generators:
# (_dystack pid=415) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=415) 	Stage 3 Generators:
# (_dystack pid=415) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=415) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=415) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=415) 	Stage 4 Generators:
# (_dystack pid=415) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=415) 	Stage 5 Generators:
# (_dystack pid=415) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=415) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=415) 		('float', [])  : 3 | ['annual_income', 'debt_to_income_ratio', 'interest_rate']
# (_dystack pid=415) 		('int', [])    : 1 | ['credit_score']
# (_dystack pid=415) 		('object', []) : 6 | ['gender', 'marital_status', 'education_level', 'employment_status', 'loan_purpose', ...]
# (_dystack pid=415) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=415) 		('category', []) : 6 | ['gender', 'marital_status', 'education_level', 'employment_status', 'loan_purpose', ...]
# (_dystack pid=415) 		('float', [])    : 3 | ['annual_income', 'debt_to_income_ratio', 'interest_rate']
# (_dystack pid=415) 		('int', [])      : 1 | ['credit_score']
# (_dystack pid=415) 	2.1s = Fit runtime
# (_dystack pid=415) 	10 features in original data used to generate 10 features in processed data.
# (_dystack pid=415) 	Train Data (Processed) Memory Usage: 19.14 MB (0.1% of available memory)
# (_dystack pid=415) Data preprocessing and feature engineering runtime = 2.23s ...
# (_dystack pid=415) AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# (_dystack pid=415) 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# (_dystack pid=415) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=415) Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=415) User-specified model hyperparameters to be fit:
# (_dystack pid=415) {
# (_dystack pid=415) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=415) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=415) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=415) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=415) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=415) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=415) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=415) }
# (_dystack pid=415) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=415) Fitting 106 L1 models, fit_strategy="sequential" ...
# (_dystack pid=415) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2994.68s of the 4493.14s of remaining time.
# (_dystack pid=415) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.53%)
# (_dystack pid=415) 	-6923.9153	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=415) 	34.05s	 = Training   runtime
# (_dystack pid=415) 	8.12s	 = Validation runtime
# (_dystack pid=415) Fitting model: LightGBM_BAG_L1 ... Training model for up to 2953.74s of the 4452.19s of remaining time.
# (_dystack pid=415) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.54%)
# (_dystack pid=415) 	-6918.9445	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=415) 	26.2s	 = Training   runtime
# (_dystack pid=415) 	6.88s	 = Validation runtime
# (_dystack pid=415) Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 2922.81s of the 4421.27s of remaining time.
# (_dystack pid=415) 	-6940.8162	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=415) 	512.42s	 = Training   runtime
# (_dystack pid=415) 	27.27s	 = Validation runtime
# (_dystack pid=415) Fitting model: CatBoost_BAG_L1 ... Training model for up to 2378.88s of the 3877.34s of remaining time.
# (_dystack pid=415) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.83%)
# (_ray_fit pid=1420) 	Ran out of time, early stopping on iteration 953.
# (_ray_fit pid=1774) 	Ran out of time, early stopping on iteration 1362. [repeated 4x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_dystack pid=415) 	-6916.7882	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=415) 	1914.72s	 = Training   runtime
# (_dystack pid=415) 	6.05s	 = Validation runtime
# (_dystack pid=415) Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 459.59s of the 1958.04s of remaining time.
# (_ray_fit pid=1781) 	Ran out of time, early stopping on iteration 1369.
# (_dystack pid=415) 	-6931.2132	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=415) 	131.97s	 = Training   runtime
# (_dystack pid=415) 	20.4s	 = Validation runtime
# (_dystack pid=415) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 305.19s of the 1803.65s of remaining time.
# (_dystack pid=415) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.89%)
# (_dystack pid=415) 	-6925.7954	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=415) 	179.51s	 = Training   runtime
# (_dystack pid=415) 	8.37s	 = Validation runtime
# (_dystack pid=415) Fitting model: XGBoost_BAG_L1 ... Training model for up to 120.96s of the 1619.41s of remaining time.
# (_dystack pid=415) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.71%)
# (_dystack pid=415) 	-6922.4905	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=415) 	104.09s	 = Training   runtime
# (_dystack pid=415) 	3.37s	 = Validation runtime
# (_dystack pid=415) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 12.41s of the 1510.86s of remaining time.
# (_dystack pid=415) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.50%)
# (_dystack pid=415) 	Time limit exceeded... Skipping NeuralNetTorch_BAG_L1.
# (_dystack pid=415) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 1485.88s of remaining time.
# (_dystack pid=415) 	Ensemble Weights: {'CatBoost_BAG_L1': 0.667, 'RandomForestMSE_BAG_L1': 0.19, 'LightGBM_BAG_L1': 0.143}
# (_dystack pid=415) 	-6915.3007	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=415) 	2.31s	 = Training   runtime
# (_dystack pid=415) 	0.11s	 = Validation runtime
# (_dystack pid=415) Fitting 106 L2 models, fit_strategy="sequential" ...
# (_dystack pid=415) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1483.30s of the 1483.22s of remaining time.
# (_dystack pid=415) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.84%)
# (_dystack pid=415) 	-6915.4671	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=415) 	29.51s	 = Training   runtime
# (_dystack pid=415) 	4.54s	 = Validation runtime
# (_dystack pid=415) Fitting model: LightGBM_BAG_L2 ... Training model for up to 1449.25s of the 1449.17s of remaining time.
# (_dystack pid=415) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.84%)
# (_dystack pid=415) 	-6915.663	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=415) 	26.34s	 = Training   runtime
# (_dystack pid=415) 	3.64s	 = Validation runtime
# (_dystack pid=415) Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 1418.26s of the 1418.18s of remaining time.
# (_dystack pid=415) 	Warning: Reducing model 'n_estimators' from 300 -> 189 due to low time. Expected time usage reduced from 2247.0s -> 1417.8s...
# (_dystack pid=415) 	-6938.3485	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=415) 	1403.51s	 = Training   runtime
# (_dystack pid=415) 	21.04s	 = Validation runtime
# (_dystack pid=415) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the -7.90s of remaining time.
# (_dystack pid=415) 	Ensemble Weights: {'CatBoost_BAG_L1': 0.333, 'LightGBMXT_BAG_L2': 0.333, 'LightGBM_BAG_L2': 0.143, 'RandomForestMSE_BAG_L1': 0.095, 'RandomForestMSE_BAG_L2': 0.095}
# (_dystack pid=415) 	-6914.6849	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=415) 	0.89s	 = Training   runtime
# (_dystack pid=415) 	0.01s	 = Validation runtime
# (_dystack pid=415) AutoGluon training complete, total runtime = 4504.26s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 1678.5 rows/s (87999 batch size)
# (_dystack pid=415) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho")
# (_dystack pid=415) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=2812, ip=172.19.2.2)
# (_dystack pid=415)   File "/usr/local/lib/python3.11/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
# (_dystack pid=415)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=415)   File "/usr/local/lib/python3.11/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=415)     out = self._fit(**kwargs)
# (_dystack pid=415)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=415)   File "/usr/local/lib/python3.11/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 247, in _fit
# (_dystack pid=415)     raise TimeLimitExceeded
# (_dystack pid=415) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=415) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=2810, ip=172.19.2.2)
# (_dystack pid=415)   File "/usr/local/lib/python3.11/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
# (_dystack pid=415)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=415)   File "/usr/local/lib/python3.11/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=415)     out = self._fit(**kwargs)
# (_dystack pid=415)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=415)   File "/usr/local/lib/python3.11/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 247, in _fit
# (_dystack pid=415)     raise TimeLimitExceeded
# (_dystack pid=415) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=415) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=2811, ip=172.19.2.2)
# (_dystack pid=415)   File "/usr/local/lib/python3.11/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
# (_dystack pid=415)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=415)   File "/usr/local/lib/python3.11/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=415)     out = self._fit(**kwargs)
# (_dystack pid=415)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=415)   File "/usr/local/lib/python3.11/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 247, in _fit
# (_dystack pid=415)     raise TimeLimitExceeded
# (_dystack pid=415) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=415) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                      model  score_holdout    score_val              eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L3   -6903.073845 -6914.684923  root_mean_squared_error       31.694644     109.702980  4363.189192                 0.005852                0.010331           0.885796            3       True         12
# 1          LightGBM_BAG_L2   -6903.078456 -6915.663050  root_mean_squared_error       27.622139      84.108351  2929.290315                 1.081611                3.643096          26.337114            2       True         10
# 2        LightGBMXT_BAG_L2   -6903.497685 -6915.467058  root_mean_squared_error       27.976709      85.006411  2932.460661                 1.436181                4.541157          29.507459            2       True          9
# 3      WeightedEnsemble_L2   -6903.613828 -6915.300698  root_mean_squared_error        9.866992      40.310947  2455.648345                 0.003964                0.108953           2.308906            2       True          8
# 4          CatBoost_BAG_L1   -6905.058028 -6916.788218  root_mean_squared_error        2.070949       6.047177  1914.720513                 2.070949                6.047177        1914.720513            1       True          4
# 5          LightGBM_BAG_L1   -6907.073258 -6918.944511  root_mean_squared_error        2.236158       6.880373    26.203054                 2.236158                6.880373          26.203054            1       True          2
# 6           XGBoost_BAG_L1   -6909.722568 -6922.490493  root_mean_squared_error        1.286976       3.366428   104.085442                 1.286976                3.366428         104.085442            1       True          7
# 7        LightGBMXT_BAG_L1   -6912.746712 -6923.915294  root_mean_squared_error        7.764778       8.121590    34.048386                 7.764778                8.121590          34.048386            1       True          1
# 8   NeuralNetFastAI_BAG_L1   -6915.607679 -6925.795420  root_mean_squared_error        4.426647       8.371429   179.514065                 4.426647                8.371429         179.514065            1       True          6
# 9   RandomForestMSE_BAG_L2   -6916.563214 -6938.348479  root_mean_squared_error       29.171000     101.508396  4306.458823                 2.630472               21.043142        1403.505621            2       True         11
# 10    ExtraTreesMSE_BAG_L1   -6916.882646 -6931.213230  root_mean_squared_error        3.199099      20.403813   131.965870                 3.199099               20.403813         131.965870            1       True          5
# 11  RandomForestMSE_BAG_L1   -6923.740210 -6940.816198  root_mean_squared_error        5.555920      27.274444   512.415873                 5.555920               27.274444         512.415873            1       True          3
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	4545s	 = DyStack   runtime |	13455s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 13455s
# AutoGluon will save models to "/kaggle/working/AG_loan_models"
# Train Data Rows:    593994
# Train Data Columns: 10
# Label Column:       loan_amount
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    29406.39 MB
# 	Train Data (Original)  Memory Usage: 236.92 MB (0.8% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 3 | ['annual_income', 'debt_to_income_ratio', 'interest_rate']
# 		('int', [])    : 1 | ['credit_score']
# 		('object', []) : 6 | ['gender', 'marital_status', 'education_level', 'employment_status', 'loan_purpose', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 6 | ['gender', 'marital_status', 'education_level', 'employment_status', 'loan_purpose', ...]
# 		('float', [])    : 3 | ['annual_income', 'debt_to_income_ratio', 'interest_rate']
# 		('int', [])      : 1 | ['credit_score']
# 	2.7s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 21.53 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 3.18s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 8965.60s of the 13451.75s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.48%)
# 	-6922.3155	 = Validation score   (-root_mean_squared_error)
# 	36.75s	 = Training   runtime
# 	9.23s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 8922.97s of the 13409.12s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.48%)
# 	-6917.0258	 = Validation score   (-root_mean_squared_error)
# 	32.92s	 = Training   runtime
# 	9.2s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 8884.26s of the 13370.40s of remaining time.
# 	-6935.1396	 = Validation score   (-root_mean_squared_error)
# 	635.99s	 = Training   runtime
# 	31.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 8212.66s of the 12698.81s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.77%)
# 	-6914.2499	 = Validation score   (-root_mean_squared_error)
# 	5819.43s	 = Training   runtime
# 	7.02s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 2387.81s of the 6873.95s of remaining time.
# 	-6928.2442	 = Validation score   (-root_mean_squared_error)
# 	163.37s	 = Training   runtime
# 	22.72s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2198.13s of the 6684.28s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.81%)
# 	-6924.775	 = Validation score   (-root_mean_squared_error)
# 	1047.61s	 = Training   runtime
# 	8.64s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1145.15s of the 5631.30s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.65%)
# 	-6916.9081	 = Validation score   (-root_mean_squared_error)
# 	930.48s	 = Training   runtime
# 	5.65s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 209.40s of the 4695.55s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.45%)
# 	-6928.2461	 = Validation score   (-root_mean_squared_error)
# 	162.28s	 = Training   runtime
# 	7.37s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 42.04s of the 4528.19s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	-6917.7107	 = Validation score   (-root_mean_squared_error)
# 	38.95s	 = Training   runtime
# 	11.41s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 896.56s of the 4483.01s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.64, 'RandomForestMSE_BAG_L1': 0.2, 'LightGBM_BAG_L1': 0.12, 'XGBoost_BAG_L1': 0.04}
# 	-6912.7262	 = Validation score   (-root_mean_squared_error)
# 	1.17s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting 106 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 4481.76s of the 4481.65s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.92%)
# 	-6912.7133	 = Validation score   (-root_mean_squared_error)
# 	36.6s	 = Training   runtime
# 	5.08s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 4439.56s of the 4439.45s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.93%)
# 	-6912.6123	 = Validation score   (-root_mean_squared_error)
# 	30.38s	 = Training   runtime
# 	3.72s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 4403.72s of the 4403.61s of remaining time.
# 	-6928.8086	 = Validation score   (-root_mean_squared_error)
# 	3282.75s	 = Training   runtime
# 	38.17s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1077.66s of the 1077.55s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.24%)
# 	-6912.5828	 = Validation score   (-root_mean_squared_error)
# 	466.22s	 = Training   runtime
# 	1.28s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 606.04s of the 605.92s of remaining time.
# 	-6917.968	 = Validation score   (-root_mean_squared_error)
# 	331.6s	 = Training   runtime
# 	26.84s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 245.93s of the 245.82s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.58%)
# 	-6912.8343	 = Validation score   (-root_mean_squared_error)
# 	121.92s	 = Training   runtime
# 	9.14s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 118.21s of the 118.10s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.25%)
# 	-6917.5926	 = Validation score   (-root_mean_squared_error)
# 	108.16s	 = Training   runtime
# 	3.16s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 448.18s of the 4.01s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L2': 0.3, 'NeuralNetFastAI_BAG_L2': 0.2, 'LightGBMXT_BAG_L2': 0.15, 'CatBoost_BAG_L1': 0.1, 'ExtraTreesMSE_BAG_L2': 0.1, 'RandomForestMSE_BAG_L1': 0.05, 'RandomForestMSE_BAG_L2': 0.05, 'CatBoost_BAG_L2': 0.05}
# 	-6911.9066	 = Validation score   (-root_mean_squared_error)
# 	1.59s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 13452.66s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 1015.0 rows/s (98999 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AG_loan_models")

# %%
## -- Get Summary -- 
print(f"-> Total models : {len(predictor.model_names())}")
print(f"-> Best model   : {predictor.model_best}") 

## -- Observe RUN 1 RESULTS -- 
leaderboard = predictor.leaderboard(silent=True)
leaderboard.style.background_gradient(subset=["score_val"], cmap="Spectral")
# Out:
# -> Total models : 18
# -> Best model   : WeightedEnsemble_L3
# <style type="text/css">
# #T_a0082_row0_col1 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_a0082_row1_col1, #T_a0082_row2_col1 {
#   background-color: #525fa9;
#   color: #f1f1f1;
# }
# #T_a0082_row3_col1 {
#   background-color: #5061aa;
#   color: #f1f1f1;
# }
# #T_a0082_row4_col1 {
#   background-color: #4e63ac;
#   color: #f1f1f1;
# }
# #T_a0082_row5_col1 {
#   background-color: #4d65ad;
#   color: #f1f1f1;
# }
# #T_a0082_row6_col1 {
#   background-color: #3387bc;
#   color: #f1f1f1;
# }
# #T_a0082_row7_col1 {
#   background-color: #71c6a5;
#   color: #000000;
# }
# #T_a0082_row8_col1 {
#   background-color: #74c7a5;
#   color: #000000;
# }
# #T_a0082_row9_col1 {
#   background-color: #84cea5;
#   color: #000000;
# }
# #T_a0082_row10_col1 {
#   background-color: #86cfa5;
#   color: #000000;
# }
# #T_a0082_row11_col1 {
#   background-color: #8fd2a4;
#   color: #000000;
# }
# #T_a0082_row12_col1 {
#   background-color: #f2faaa;
#   color: #000000;
# }
# #T_a0082_row13_col1 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_a0082_row14_col1, #T_a0082_row15_col1 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_a0082_row16_col1 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_a0082_row17_col1 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a0082">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0082_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_a0082_level0_col1" class="col_heading level0 col1" >score_val</th>
#       <th id="T_a0082_level0_col2" class="col_heading level0 col2" >eval_metric</th>
#       <th id="T_a0082_level0_col3" class="col_heading level0 col3" >pred_time_val</th>
#       <th id="T_a0082_level0_col4" class="col_heading level0 col4" >fit_time</th>
#       <th id="T_a0082_level0_col5" class="col_heading level0 col5" >pred_time_val_marginal</th>
#       <th id="T_a0082_level0_col6" class="col_heading level0 col6" >fit_time_marginal</th>
#       <th id="T_a0082_level0_col7" class="col_heading level0 col7" >stack_level</th>
#       <th id="T_a0082_level0_col8" class="col_heading level0 col8" >can_infer</th>
#       <th id="T_a0082_level0_col9" class="col_heading level0 col9" >fit_order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0082_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0082_row0_col0" class="data row0 col0" >WeightedEnsemble_L3</td>
#       <td id="T_a0082_row0_col1" class="data row0 col1" >-6911.906615</td>
#       <td id="T_a0082_row0_col2" class="data row0 col2" >root_mean_squared_error</td>
#       <td id="T_a0082_row0_col3" class="data row0 col3" >196.569559</td>
#       <td id="T_a0082_row0_col4" class="data row0 col4" >13138.840079</td>
#       <td id="T_a0082_row0_col5" class="data row0 col5" >0.011366</td>
#       <td id="T_a0082_row0_col6" class="data row0 col6" >1.585405</td>
#       <td id="T_a0082_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_a0082_row0_col8" class="data row0 col8" >True</td>
#       <td id="T_a0082_row0_col9" class="data row0 col9" >18</td>
#     </tr>
#     <tr>
#       <th id="T_a0082_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a0082_row1_col0" class="data row1 col0" >CatBoost_BAG_L2</td>
#       <td id="T_a0082_row1_col1" class="data row1 col1" >-6912.582781</td>
#       <td id="T_a0082_row1_col2" class="data row1 col2" >root_mean_squared_error</td>
#       <td id="T_a0082_row1_col3" class="data row1 col3" >113.608926</td>
#       <td id="T_a0082_row1_col4" class="data row1 col4" >9333.997892</td>
#       <td id="T_a0082_row1_col5" class="data row1 col5" >1.277436</td>
#       <td id="T_a0082_row1_col6" class="data row1 col6" >466.223655</td>
#       <td id="T_a0082_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_a0082_row1_col8" class="data row1 col8" >True</td>
#       <td id="T_a0082_row1_col9" class="data row1 col9" >14</td>
#     </tr>
#     <tr>
#       <th id="T_a0082_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a0082_row2_col0" class="data row2 col0" >LightGBM_BAG_L2</td>
#       <td id="T_a0082_row2_col1" class="data row2 col1" >-6912.612306</td>
#       <td id="T_a0082_row2_col2" class="data row2 col2" >root_mean_squared_error</td>
#       <td id="T_a0082_row2_col3" class="data row2 col3" >116.050942</td>
#       <td id="T_a0082_row2_col4" class="data row2 col4" >8898.158407</td>
#       <td id="T_a0082_row2_col5" class="data row2 col5" >3.719452</td>
#       <td id="T_a0082_row2_col6" class="data row2 col6" >30.384171</td>
#       <td id="T_a0082_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_a0082_row2_col8" class="data row2 col8" >True</td>
#       <td id="T_a0082_row2_col9" class="data row2 col9" >12</td>
#     </tr>
#     <tr>
#       <th id="T_a0082_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a0082_row3_col0" class="data row3 col0" >LightGBMXT_BAG_L2</td>
#       <td id="T_a0082_row3_col1" class="data row3 col1" >-6912.713338</td>
#       <td id="T_a0082_row3_col2" class="data row3 col2" >root_mean_squared_error</td>
#       <td id="T_a0082_row3_col3" class="data row3 col3" >117.408514</td>
#       <td id="T_a0082_row3_col4" class="data row3 col4" >8904.370817</td>
#       <td id="T_a0082_row3_col5" class="data row3 col5" >5.077023</td>
#       <td id="T_a0082_row3_col6" class="data row3 col6" >36.596580</td>
#       <td id="T_a0082_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_a0082_row3_col8" class="data row3 col8" >True</td>
#       <td id="T_a0082_row3_col9" class="data row3 col9" >11</td>
#     </tr>
#     <tr>
#       <th id="T_a0082_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a0082_row4_col0" class="data row4 col0" >WeightedEnsemble_L2</td>
#       <td id="T_a0082_row4_col1" class="data row4 col1" >-6912.726205</td>
#       <td id="T_a0082_row4_col2" class="data row4 col2" >root_mean_squared_error</td>
#       <td id="T_a0082_row4_col3" class="data row4 col3" >52.984282</td>
#       <td id="T_a0082_row4_col4" class="data row4 col4" >7419.985626</td>
#       <td id="T_a0082_row4_col5" class="data row4 col5" >0.012855</td>
#       <td id="T_a0082_row4_col6" class="data row4 col6" >1.171855</td>
#       <td id="T_a0082_row4_col7" class="data row4 col7" >2</td>
#       <td id="T_a0082_row4_col8" class="data row4 col8" >True</td>
#       <td id="T_a0082_row4_col9" class="data row4 col9" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a0082_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a0082_row5_col0" class="data row5 col0" >NeuralNetFastAI_BAG_L2</td>
#       <td id="T_a0082_row5_col1" class="data row5 col1" >-6912.834287</td>
#       <td id="T_a0082_row5_col2" class="data row5 col2" >root_mean_squared_error</td>
#       <td id="T_a0082_row5_col3" class="data row5 col3" >121.473838</td>
#       <td id="T_a0082_row5_col4" class="data row5 col4" >8989.694853</td>
#       <td id="T_a0082_row5_col5" class="data row5 col5" >9.142348</td>
#       <td id="T_a0082_row5_col6" class="data row5 col6" >121.920617</td>
#       <td id="T_a0082_row5_col7" class="data row5 col7" >2</td>
#       <td id="T_a0082_row5_col8" class="data row5 col8" >True</td>
#       <td id="T_a0082_row5_col9" class="data row5 col9" >16</td>
#     </tr>
#     <tr>
#       <th id="T_a0082_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a0082_row6_col0" class="data row6 col0" >CatBoost_BAG_L1</td>
#       <td id="T_a0082_row6_col1" class="data row6 col1" >-6914.249908</td>
#       <td id="T_a0082_row6_col2" class="data row6 col2" >root_mean_squared_error</td>
#       <td id="T_a0082_row6_col3" class="data row6 col3" >7.016960</td>
#       <td id="T_a0082_row6_col4" class="data row6 col4" >5819.427714</td>
#       <td id="T_a0082_row6_col5" class="data row6 col5" >7.016960</td>
#       <td id="T_a0082_row6_col6" class="data row6 col6" >5819.427714</td>
#       <td id="T_a0082_row6_col7" class="data row6 col7" >1</td>
#       <td id="T_a0082_row6_col8" class="data row6 col8" >True</td>
#       <td id="T_a0082_row6_col9" class="data row6 col9" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a0082_level0_row7" class="row_heading level0 row7" >7</t

# %%
## -- RUN 2: Use original data as extra learning input --
# predictor.fit_pseudolabel(
#                 orig,
#                 use_ensemble = True,
#                 fit_ensemble = True,
#                 time_limit   = 3600*5,
#                 ag_args_fit  = {'num_cpus': os.cpu_count() - 1},
# )

# %%
## -- Get Summary -- 
# print(f"""
#     # {'█'*5}| Total models : {len(predictor.model_names())}
#     # {'█'*5}| Best model   : {predictor.model_best}
#         """)

# # -- Observe RUN 2 RESULTS --
# leaderboard = predictor.leaderboard(silent=True)
# display(leaderboard.style.background_gradient(subset=["score_val"], cmap="Spectral"))

# %%
## -- Create folder directory to save predictions --
SAVE_PATH = '/kaggle/working/AG_loan_predictions/'
# !mkdir {SAVE_PATH}

# %%
## -- Predictions for {SELECTED FEATURE} --
oof_ = predictor.predict_oof(train_data=train)
np.save(f"{SAVE_PATH}oof_AG_on_{TARGET}.npy", oof_)

preds_ = predictor.predict(test)
np.save(f"{SAVE_PATH}pred_AG_on_{TARGET}.npy", preds_)

oof_[:5], preds_[:5]
# Out:
# (0    14733.912109
#  1    15155.894531
#  2    14490.648438
#  3    14438.337891
#  4    14488.851562
#  Name: loan_amount, dtype: float32,
#  0    15614.290039
#  1    14826.189453
#  2    15503.588867
#  3    14277.865234
#  4    14791.062500
#  Name: loan_amount, dtype: float32)

# %%
predictor.plot_ensemble_model(filename='ensemble_model.png')
display(Image(f'{MODELS_PATH}ensemble_model.png'))

# %%
# !zip -r /kaggle/working/AG_accident_models /kaggle/working/AG_accident_models.zip
# !zip -r {FOLDER}{NAME_EXT}.zip /kaggle/working/{FOLDER}{NAME_EXT}

# %%
## -- Extract model scores --
result_ = dict(zip(leaderboard['model'], leaderboard['score_val']))
result_df = pd.DataFrame.from_dict(result_, orient='index').sort_values(0)

max_score = result_df.max().item()
min_score = result_df.min().item()

## -- PLOT MODELS & SCORES --
plt.figure(figsize=(18, 15))
plt.stem(
    result_df.index,
    result_df[0],
    orientation = 'horizontal',
    bottom = min_score - 0.0055,
    markerfmt = 'C3o'
)
plt.xlim(min_score - 0.006, max_score + 0.005)
plt.xlabel('Score')
plt.title('-- Scores of Models --', fontsize=15)

for i, value in enumerate(result_df[0]):
    plt.text(value+1e-3, i, f'{abs(value):.5f}', ha='left', va='center', fontdict=dict(size=12))

plt.grid(True, axis='x')
plt.tight_layout()
plt.show()

# %%
# predictor.model_names()

# %%
# ## -- Permutation Feature Importances --
# feat_imp = predictor.feature_importance(
#                         data = X_test,
#                         # time_limit = 3600,
#                         # model = 'LightGBM_BAG_L1',
#                         # features = None,
#                         # feature_stage = 'transformed',
#                         # subsample_size = 5000,
#                         # num_shuffle_sets = 10,
#                         # include_confidence_band = True,
#                         confidence_level = 0.95,
#                         # silent = False
# ) 

# feat_imp.style.background_gradient(subset=["importance"], cmap="Spectral")

# %%
# plt.figure(figsize=(18, 35))
# sns.barplot(data=feat_imp, y=feat_imp.index, x=feat_imp.importance)
# plt.tick_params(axis='y', which='major', labelcolor='r')
# plt.title("Top Features by Permutation")
# plt.tight_layout()
# plt.show()

# %%
## -- OPTIONAL: Remove stored files --
# !rm -r {MODELS_PATH}

# %%
print(f"""
{'-'*48}
{'█'*5} | - AUTOGLUON NOTEBOOK COMPLETE! - | {'█'*5}
{'-'*48}
""")
# Out:
# ------------------------------------------------
# █████ | - AUTOGLUON NOTEBOOK COMPLETE! - | █████
# ------------------------------------------------
