# %%
# %%capture cap
# !pip install -qq ipywidgets
# !pip install -qq autogluon scikit-learn==1.5.2 
# !apt-get install -qq -y graphviz graphviz-dev && pip install -q pydot
# !pip install -qq pygraphviz
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 12.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 82.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.9/454.9 kB 20.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.3/487.3 kB 19.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.7/189.7 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.8/285.8 kB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.5/280.5 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 51.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 31.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 19.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 MB 23.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.4/354.4 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 34.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.5/963.5 kB 37.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 105.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 22.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 68.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 72.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 90.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 23.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 2.9 MB/s eta 0:00:00
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Building wheel for seqeval (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# Selecting previously unselected package libgtk2.0-common.
# (Reading database ... 128639 files and directories currently installed.)
# Preparing to unpack .../0-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../1-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../2-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../3-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libxdot4:amd64.
# Preparing to unpack .../4-libxdot4_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgvc6-plugins-gtk.
# Preparing to unpack .../5-libgvc6-plugins-gtk_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgraphviz-dev:amd64.
# Preparing to unpack .../6-libgraphviz-dev_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../7-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.0/106.0 kB 2.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for pygraphviz (pyproject.toml) ... done

# %%
import torch
import os
import pydot

import random
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
from time import time, sleep
from itertools import combinations

from IPython.display import display, Image
import matplotlib.pyplot as plt
import seaborn as sns

import warnings

warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')

## -- Set Global Seed --
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

pd.set_option('display.max_columns', 500)
plt.style.use("ggplot")

## -- Ansi color codes --
COLOR = '\033[32m'
RESET = '\033[0m'

print("Packages import succesful!")
# Out:
# Packages import succesful!

# %%
### Load Data ###
PATH = "/kaggle/input/playground-series-s5e11/"
submit = pd.read_csv(PATH+"sample_submission.csv")

list_of_targets = [
    'debt_to_income_ratio',
    'credit_score',
    'interest_rate',
    'employment_status',
    'annual_income',
    'loan_amount',
    'education_level',
    'grade_subgrade',
    'loan_purpose',
    'marital_status',
    'gender',
]

TARGET = list_of_targets[3]

train = pd.read_csv(PATH+"train.csv").drop(['id', "loan_paid_back"], axis=1)
test = pd.read_csv(PATH+"test.csv").drop(['id', TARGET], axis=1)

# ## -- Convert target to float for regression --
# train[TARGET] = train[TARGET].astype(np.float32)

NUMS = test.select_dtypes(include='number').columns.tolist()
CATS = test.select_dtypes(exclude='number').columns.tolist()
BASE = NUMS + CATS

for (name, df) in dict(Train=train, Test=test).items():
    print(f"{name} shape: {df.shape}")

print(f"\nTotal Numerical: {len(NUMS)}")
print(f"Total Categorical: {len(CATS)}")
print(f"Total base features: {len(BASE)}")
# Out:
# Train shape: (593994, 11)
# Test shape: (254569, 10)
#
# Total Numerical: 5
# Total Categorical: 5
# Total base features: 10

# %%
# !rm -r /kaggle/working/AG_loan_models

# %%
from autogluon.tabular import TabularPredictor

# %%
MODELS_PATH = "./AG_loan_models/"

predictor = TabularPredictor(
                label = TARGET,
         # problem_type = "regression",
          eval_metric = "roc_auc_ovo_macro",
                 path = MODELS_PATH,
    ).fit(
                   train_data = train,
                      presets = "best",
                num_bag_folds = 6,
             # dynamic_stacking = False,
             # num_stack_levels = 1,
                   time_limit = 3600*5,
                   # auto_stack = False,
                 # num_bag_sets = 2,
                  # ag_args_fit = {'num_cpus': os.cpu_count()},
)
# Out:
# Preset alias specified: 'best' maps to 'best_quality'.
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.11.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Sat Sep 27 10:16:09 UTC 2025
# CPU Count:          4
# Memory Avail:       29.96 GB / 31.35 GB (95.6%)
# Disk Space Avail:   19.50 GB / 19.52 GB (99.9%)
# ===================================================
# Presets specified: ['best']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=6, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 4500s of the 18000s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-11-29 11:55:30,551	INFO worker.py:1843 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho"
# (_dystack pid=427) Running DyStack sub-fit ...
# (_dystack pid=427) Beginning AutoGluon training ... Time limit = 4493s
# (_dystack pid=427) AutoGluon will save models to "/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho"
# (_dystack pid=427) Train Data Rows:    527994
# (_dystack pid=427) Train Data Columns: 10
# (_dystack pid=427) Label Column:       employment_status
# (_dystack pid=427) Problem Type:       multiclass
# (_dystack pid=427) Preprocessing data ...
# (_dystack pid=427) Train Data Class Count: 5
# (_dystack pid=427) Using Feature Generators to preprocess the data ...
# (_dystack pid=427) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=427) 	Available Memory:                    30115.08 MB
# (_dystack pid=427) 	Train Data (Original)  Memory Usage: 181.56 MB (0.6% of available memory)
# (_dystack pid=427) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=427) 	Stage 1 Generators:
# (_dystack pid=427) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=427) 	Stage 2 Generators:
# (_dystack pid=427) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=427) 	Stage 3 Generators:
# (_dystack pid=427) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=427) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=427) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=427) 	Stage 4 Generators:
# (_dystack pid=427) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=427) 	Stage 5 Generators:
# (_dystack pid=427) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=427) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=427) 		('float', [])  : 4 | ['annual_income', 'debt_to_income_ratio', 'loan_amount', 'interest_rate']
# (_dystack pid=427) 		('int', [])    : 1 | ['credit_score']
# (_dystack pid=427) 		('object', []) : 5 | ['gender', 'marital_status', 'education_level', 'loan_purpose', 'grade_subgrade']
# (_dystack pid=427) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=427) 		('category', []) : 5 | ['gender', 'marital_status', 'education_level', 'loan_purpose', 'grade_subgrade']
# (_dystack pid=427) 		('float', [])    : 4 | ['annual_income', 'debt_to_income_ratio', 'loan_amount', 'interest_rate']
# (_dystack pid=427) 		('int', [])      : 1 | ['credit_score']
# (_dystack pid=427) 	2.4s = Fit runtime
# (_dystack pid=427) 	10 features in original data used to generate 10 features in processed data.
# (_dystack pid=427) 	Train Data (Processed) Memory Usage: 22.66 MB (0.1% of available memory)
# (_dystack pid=427) Data preprocessing and feature engineering runtime = 3.35s ...
# (_dystack pid=427) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc_ovo'
# (_dystack pid=427) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=427) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=427) Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=427) User-specified model hyperparameters to be fit:
# (_dystack pid=427) {
# (_dystack pid=427) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=427) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=427) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=427) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=427) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=427) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=427) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=427) }
# (_dystack pid=427) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=427) Fitting 108 L1 models, fit_strategy="sequential" ...
# (_dystack pid=427) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2992.51s of the 4489.88s of remaining time.
# (_dystack pid=427) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.00%)
# (_ray_fit pid=706) Metric roc_auc_ovo is not supported by this model - using log_loss instead
# (_ray_fit pid=1010) Metric roc_auc_ovo is not supported by this model - using log_loss instead [repeated 4x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_dystack pid=427) 	0.6052	 = Validation score   (roc_auc_ovo)
# (_dystack pid=427) 	1072.62s	 = Training   runtime
# (_dystack pid=427) 	8.69s	 = Validation runtime
# (_dystack pid=427) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1909.51s of the 3406.88s of remaining time.
# (_ray_fit pid=1001) Metric roc_auc_ovo is not supported by this model - using log_loss instead
# (_dystack pid=427) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.72%)
# (_dystack pid=427) 	0.6058	 = Validation score   (roc_auc_ovo)
# (_dystack pid=427) 	336.19s	 = Training   runtime
# (_dystack pid=427) 	87.68s	 = Validation runtime
# (_dystack pid=427) Fitting model: LightGBM_BAG_L1 ... Training model for up to 1557.62s of the 3054.98s of remaining time.
# (_dystack pid=427) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.72%)
# (_dystack pid=427) 	0.617	 = Validation score   (roc_auc_ovo)
# (_dystack pid=427) 	329.76s	 = Training   runtime
# (_dystack pid=427) 	78.24s	 = Validation runtime
# (_dystack pid=427) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 1212.37s of the 2709.74s of remaining time.
# (_dystack pid=427) 	0.5961	 = Validation score   (roc_auc_ovo)
# (_dystack pid=427) 	209.11s	 = Training   runtime
# (_dystack pid=427) 	27.6s	 = Validation runtime
# (_dystack pid=427) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 969.98s of the 2467.35s of remaining time.
# (_dystack pid=427) 	0.5925	 = Validation score   (roc_auc_ovo)
# (_dystack pid=427) 	292.78s	 = Training   runtime
# (_dystack pid=427) 	31.36s	 = Validation runtime
# (_dystack pid=427) Fitting model: CatBoost_BAG_L1 ... Training model for up to 638.75s of the 2136.12s of remaining time.
# (_dystack pid=427) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.04%)
# (_ray_fit pid=2178) 	Ran out of time, early stopping on iteration 27.
# (_ray_fit pid=2176) 	Ran out of time, early stopping on iteration 39.
# (_ray_fit pid=2179) 	Ran out of time, early stopping on iteration 28.
# (_ray_fit pid=2378) 	Ran out of time, early stopping on iteration 59. [repeated 2x across cluster]
# (_ray_fit pid=2424) 	Ran out of time, early stopping on iteration 66.
# (_dystack pid=427) 	0.5619	 = Validation score   (roc_auc_ovo)
# (_dystack pid=427) 	499.48s	 = Training   runtime
# (_dystack pid=427) 	0.43s	 = Validation runtime
# (_dystack pid=427) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 133.59s of the 1630.96s of remaining time.
# (_dystack pid=427) 	Not enough time to generate out-of-fold predictions for model. Estimated time required was 118.31s compared to 103.17s of available time.
# (_dystack pid=427) 	Time limit exceeded... Skipping ExtraTreesGini_BAG_L1.
# (_dystack pid=427) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 62.77s of the 1560.14s of remaining time.
# (_dystack pid=427) 	Warning: Reducing model 'n_estimators' from 300 -> 196 due to low time. Expected time usage reduced from 95.4s -> 62.6s...
# (_dystack pid=427) 	Not enough time to generate out-of-fold predictions for model. Estimated time required was 85.83s compared to 24.05s of available time.
# (_dystack pid=427) 	Time limit exceeded... Skipping ExtraTreesEntr_BAG_L1.
# (_dystack pid=427) Fitting model: XGBoost_BAG_L1 ... Training model for up to 4.97s of the 1502.34s of remaining time.
# (_dystack pid=427) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.96%)
# (_dystack pid=427) 	0.5928	 = Validation score   (roc_auc_ovo)
# (_dystack pid=427) 	26.63s	 = Training   runtime
# (_dystack pid=427) 	2.41s	 = Validation runtime
# (_dystack pid=427) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 1469.80s of remaining time.
# (_dystack pid=427) 	Ensemble Weights: {'LightGBM_BAG_L1': 0.76, 'NeuralNetFastAI_BAG_L1': 0.12, 'RandomForestGini_BAG_L1': 0.08, 'RandomForestEntr_BAG_L1': 0.04}
# (_dystack pid=427) 	0.6177	 = Validation score   (roc_auc_ovo)
# (_dystack pid=427) 	247.32s	 = Training   runtime
# (_dystack pid=427) 	1.23s	 = Validation runtime
# (_dystack pid=427) Fitting 108 L2 models, fit_strategy="sequential" ...
# (_dystack pid=427) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1221.11s of the 1220.69s of remaining time.
# (_dystack pid=427) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=3.81%)
# (_ray_fit pid=3055) Metric roc_auc_ovo is not supported by this model - using log_loss instead
# (_ray_fit pid=3304) Metric roc_auc_ovo is not supported by this model - using log_loss instead [repeated 4x across cluster]
# (_dystack pid=427) 	0.6214	 = Validation score   (roc_auc_ovo)
# (_dystack pid=427) 	889.22s	 = Training   runtime
# (_dystack pid=427) 	16.62s	 = Validation runtime
# (_dystack pid=427) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 322.78s of the 322.35s of remaining time.
# (_ray_fit pid=3342) Metric roc_auc_ovo is not supported by this model - using log_loss instead
# (_dystack pid=427) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.61%)
# (_ray_fit pid=3575) 	Ran out of time, early stopping on iteration 85. Best iteration is:
# (_ray_fit pid=3575) 	[84]	valid_set's multi_logloss: 0.807416	valid_set's roc_auc_ovo: 0.618832
# (_dystack pid=427) 	0.6203	 = Validation score   (roc_auc_ovo)
# (_dystack pid=427) 	264.15s	 = Training   runtime
# (_dystack pid=427) 	32.18s	 = Validation runtime
# (_dystack pid=427) Fitting model: LightGBM_BAG_L2 ... Training model for up to 46.94s of the 46.51s of remaining time.
# (_ray_fit pid=3574) 	Ran out of time, early stopping on iteration 85. Best iteration is: [repeated 3x across cluster]
# (_ray_fit pid=3574) 	[84]	valid_set's multi_logloss: 0.806875	valid_set's roc_auc_ovo: 0.61931 [repeated 3x across cluster]
# (_dystack pid=427) 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=2.61%)
# (_ray_fit pid=3946) 	Ran out of time, early stopping on iteration 7. Best iteration is:
# (_ray_fit pid=3946) 	[7]	valid_set's multi_logloss: 0.821518	valid_set's roc_auc_ovo: 0.594008
# (_ray_fit pid=3947) 	Ran out of time, early stopping on iteration 7. Best iteration is:
# (_ray_fit pid=3947) 	[7]	valid_set's multi_logloss: 0.821555	valid_set's roc_auc_ovo: 0.596006
# (_ray_fit pid=4094) 	Ran out of time, early stopping on iteration 14. Best iteration is: [repeated 3x across cluster]
# (_ray_fit pid=4094) 	[14]	valid_set's multi_logloss: 0.814047	valid_set's roc_auc_ovo: 0.605666 [repeated 3x across cluster]
# (_dystack pid=427) 	0.5973	 = Validation score   (roc_auc_ovo)
# (_dystack pid=427) 	47.41s	 = Training   runtime
# (_dystack pid=427) 	2.51s	 = Validation runtime
# (_dystack pid=427) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the -9.59s of remaining time.
# (_dystack pid=427) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L2': 0.476, 'LightGBMXT_BAG_L2': 0.238, 'XGBoost_BAG_L1': 0.143, 'NeuralNetFastAI_BAG_L1': 0.048, 'LightGBM_BAG_L1': 0.048, 'RandomForestGini_BAG_L1': 0.048}
# (_dystack pid=427) 	0.6227	 = Validation score   (roc_auc_ovo)
# (_dystack pid=427) 	332.36s	 = Training   runtime
# (_dystack pid=427) 	1.23s	 = Validation runtime
# (_dystack pid=427) AutoGluon training complete, total runtime = 4836.64s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 372.4 rows/s (87999 batch size)
# (_ray_fit pid=4101) 	Ran out of time, early stopping on iteration 14. Best iteration is:
# (_ray_fit pid=4101) 	[14]	valid_set's multi_logloss: 0.81399	valid_set's roc_auc_ovo: 0.606017
# (_dystack pid=427) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AG_loan_models/ds_sub_fit/sub_fit_ho")
# (_dystack pid=427) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val  eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0    NeuralNetFastAI_BAG_L2       0.625163   0.621439  roc_auc_ovo       77.064297     253.031846  3655.795932                 6.239997               16.619975         889.220064            2       True          9
# 1       WeightedEnsemble_L3       0.624406   0.622737  roc_auc_ovo       87.203297     286.437498  4252.300975                 0.021448                1.229357         332.358941            3       True         12
# 2         LightGBMXT_BAG_L2       0.621843   0.620259  roc_auc_ovo       80.941852     268.588166  3030.721970                10.117552               32.176296         264.146102            2       True         10
# 3       WeightedEnsemble_L2       0.618386   0.617715  roc_auc_ovo       39.583753     147.130359  2151.591423                 0.014804                1.232498         247.318508            2       True          8
# 4           LightGBM_BAG_L1       0.618013   0.617025  roc_auc_ovo       23.748533      78.243417   329.758275                23.748533               78.243417         329.758275            1       True          3
# 5    NeuralNetFastAI_BAG_L1       0.606497   0.605247  roc_auc_ovo        5.925583       8.693198  1072.622778                 5.925583                8.693198        1072.622778            1       True          1
# 6         LightGBMXT_BAG_L1       0.605855   0.605798  roc_auc_ovo       28.821274      87.675205   336.188117                28.821274               87.675205         336.188117            1       True          2
# 7           CatBoost_BAG_L1       0.603851   0.561862  roc_auc_ovo        0.525508       0.433305   499.484082                 0.525508                0.433305         499.484082            1       True          6
# 8           LightGBM_BAG_L2       0.602567   0.597273  roc_auc_ovo       71.632342     238.926128  2813.985098                 0.808042                2.514258          47.409230            2       True         11
# 9   RandomForestGini_BAG_L1       0.602505   0.596121  roc_auc_ovo        5.925766      27.604331   209.111377                 5.925766               27.604331         209.111377            1       True          4
# 10  RandomForestEntr_BAG_L1       0.599489   0.592490  roc_auc_ovo        3.969066      31.356915   292.780485                 3.969066               31.356915         292.780485            1       True          5
# 11           XGBoost_BAG_L1       0.598411   0.592783  roc_auc_ovo        1.908570       2.405500    26.630753                 1.908570                2.405500          26.630753            1       True          7
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	4940s	 = DyStack   runtime |	13060s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 13060s
# AutoGluon will save models to "/kaggle/working/AG_loan_models"
# Train Data Rows:    593994
# Train Data Columns: 10
# Label Column:       employment_status
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 5
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    30260.62 MB
# 	Train Data (Original)  Memory Usage: 204.29 MB (0.7% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 4 | ['annual_income', 'debt_to_income_ratio', 'loan_amount', 'interest_rate']
# 		('int', [])    : 1 | ['credit_score']
# 		('object', []) : 5 | ['gender', 'marital_status', 'education_level', 'loan_purpose', 'grade_subgrade']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 5 | ['gender', 'marital_status', 'education_level', 'loan_purpose', 'grade_subgrade']
# 		('float', [])    : 4 | ['annual_income', 'debt_to_income_ratio', 'loan_amount', 'interest_rate']
# 		('int', [])      : 1 | ['credit_score']
# 	2.8s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 25.49 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 3.86s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc_ovo'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 108 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 8701.88s of the 13056.06s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.94%)
# 	0.6056	 = Validation score   (roc_auc_ovo)
# 	1248.44s	 = Training   runtime
# 	10.12s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 7445.53s of the 11799.72s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.67%)
# 	0.6062	 = Validation score   (roc_auc_ovo)
# 	360.26s	 = Training   runtime
# 	85.31s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 7065.89s of the 11420.07s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.67%)
# 	0.6168	 = Validation score   (roc_auc_ovo)
# 	374.73s	 = Training   runtime
# 	90.38s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 6671.63s of the 11025.81s of remaining time.
# 	0.5967	 = Validation score   (roc_auc_ovo)
# 	283.02s	 = Training   runtime
# 	29.15s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 6353.68s of the 10707.87s of remaining time.
# 	0.5945	 = Validation score   (roc_auc_ovo)
# 	344.68s	 = Training   runtime
# 	44.65s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 5955.37s of the 10309.55s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.98%)
# 	0.6145	 = Validation score   (roc_auc_ovo)
# 	4747.07s	 = Training   runtime
# 	3.74s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 1199.29s of the 5553.48s of remaining time.
# 	0.5955	 = Validation score   (roc_auc_ovo)
# 	107.59s	 = Training   runtime
# 	29.89s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 1055.97s of the 5410.16s of remaining time.
# 	0.5943	 = Validation score   (roc_auc_ovo)
# 	128.84s	 = Training   runtime
# 	31.58s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 889.65s of the 5243.84s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.88%)
# 	0.5644	 = Validation score   (roc_auc_ovo)
# 	415.47s	 = Training   runtime
# 	3.22s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 467.35s of the 4821.53s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.53%)
# 	0.6024	 = Validation score   (roc_auc_ovo)
# 	360.1s	 = Training   runtime
# 	7.91s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 100.03s of the 4454.22s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.88%)
# 	0.6041	 = Validation score   (roc_auc_ovo)
# 	95.57s	 = Training   runtime
# 	20.15s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 870.19s of the 4346.44s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L1': 0.5, 'CatBoost_BAG_L1': 0.458, 'RandomForestEntr_BAG_L1': 0.042}
# 	0.619	 = Validation score   (roc_auc_ovo)
# 	459.03s	 = Training   runtime
# 	1.42s	 = Validation runtime
# Fitting 108 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 3885.81s of the 3884.07s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=5.72%)
# 	0.6216	 = Validation score   (roc_auc_ovo)
# 	1585.03s	 = Training   runtime
# 	16.66s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 2288.22s of the 2286.49s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=3.88%)
# 	0.6204	 = Validation score   (roc_auc_ovo)
# 	481.93s	 = Training   runtime
# 	40.7s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1790.07s of the 1788.34s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=3.87%)
# 	0.62	 = Validation score   (roc_auc_ovo)
# 	397.62s	 = Training   runtime
# 	25.3s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 1379.35s of the 1377.61s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 235 due to low time. Expected time usage reduced from 1754.1s -> 1376.0s...
# 	0.6	 = Validation score   (roc_auc_ovo)
# 	1322.9s	 = Training   runtime
# 	45.1s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 388.58s of the -0.53s of remaining time.
# Warning: Ensemble Selection ran out of time, early stopping at iteration 17. This may mean that the time_limit specified is very small for this problem.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L2': 0.438, 'CatBoost_BAG_L1': 0.25, 'LightGBM_BAG_L2': 0.188, 'LightGBMXT_BAG_L2': 0.125}
# 	0.6238	 = Validation score   (roc_auc_ovo)
# 	411.62s	 = Training   runtime
# 	1.4s	 = Validation runtime
# AutoGluon training complete, total runtime = 13473.78s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 303.4 rows/s (98999 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AG_loan_models")

# %%
## -- Get Summary -- 
print(f"-> Total models : {len(predictor.model_names())}")
print(f"-> Best model   : {predictor.model_best}") 

## -- Observe RUN 1 RESULTS -- 
leaderboard = predictor.leaderboard(silent=True)
leaderboard.style.background_gradient(subset=["score_val"], cmap="Spectral")
# Out:
# -> Total models : 17
# -> Best model   : WeightedEnsemble_L3
# <style type="text/css">
# #T_9fb14_row0_col1 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_9fb14_row1_col1 {
#   background-color: #4e63ac;
#   color: #f1f1f1;
# }
# #T_9fb14_row2_col1 {
#   background-color: #466eb1;
#   color: #f1f1f1;
# }
# #T_9fb14_row3_col1 {
#   background-color: #4273b3;
#   color: #f1f1f1;
# }
# #T_9fb14_row4_col1 {
#   background-color: #3b7cb7;
#   color: #f1f1f1;
# }
# #T_9fb14_row5_col1 {
#   background-color: #3b92b9;
#   color: #f1f1f1;
# }
# #T_9fb14_row6_col1 {
#   background-color: #50a9af;
#   color: #f1f1f1;
# }
# #T_9fb14_row7_col1 {
#   background-color: #a7dba4;
#   color: #000000;
# }
# #T_9fb14_row8_col1 {
#   background-color: #aedea3;
#   color: #000000;
# }
# #T_9fb14_row9_col1 {
#   background-color: #bce4a0;
#   color: #000000;
# }
# #T_9fb14_row10_col1 {
#   background-color: #cfec9d;
#   color: #000000;
# }
# #T_9fb14_row11_col1 {
#   background-color: #e6f598;
#   color: #000000;
# }
# #T_9fb14_row12_col1 {
#   background-color: #f4faad;
#   color: #000000;
# }
# #T_9fb14_row13_col1 {
#   background-color: #f9fcb5;
#   color: #000000;
# }
# #T_9fb14_row14_col1 {
#   background-color: #fefebd;
#   color: #000000;
# }
# #T_9fb14_row15_col1 {
#   background-color: #ffffbe;
#   color: #000000;
# }
# #T_9fb14_row16_col1 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9fb14">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9fb14_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_9fb14_level0_col1" class="col_heading level0 col1" >score_val</th>
#       <th id="T_9fb14_level0_col2" class="col_heading level0 col2" >eval_metric</th>
#       <th id="T_9fb14_level0_col3" class="col_heading level0 col3" >pred_time_val</th>
#       <th id="T_9fb14_level0_col4" class="col_heading level0 col4" >fit_time</th>
#       <th id="T_9fb14_level0_col5" class="col_heading level0 col5" >pred_time_val_marginal</th>
#       <th id="T_9fb14_level0_col6" class="col_heading level0 col6" >fit_time_marginal</th>
#       <th id="T_9fb14_level0_col7" class="col_heading level0 col7" >stack_level</th>
#       <th id="T_9fb14_level0_col8" class="col_heading level0 col8" >can_infer</th>
#       <th id="T_9fb14_level0_col9" class="col_heading level0 col9" >fit_order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fb14_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9fb14_row0_col0" class="data row0 col0" >WeightedEnsemble_L3</td>
#       <td id="T_9fb14_row0_col1" class="data row0 col1" >0.623828</td>
#       <td id="T_9fb14_row0_col2" class="data row0 col2" >roc_auc_ovo</td>
#       <td id="T_9fb14_row0_col3" class="data row0 col3" >440.178465</td>
#       <td id="T_9fb14_row0_col4" class="data row0 col4" >11341.967770</td>
#       <td id="T_9fb14_row0_col5" class="data row0 col5" >1.402042</td>
#       <td id="T_9fb14_row0_col6" class="data row0 col6" >411.616456</td>
#       <td id="T_9fb14_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_9fb14_row0_col8" class="data row0 col8" >True</td>
#       <td id="T_9fb14_row0_col9" class="data row0 col9" >17</td>
#     </tr>
#     <tr>
#       <th id="T_9fb14_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9fb14_row1_col0" class="data row1 col0" >NeuralNetFastAI_BAG_L2</td>
#       <td id="T_9fb14_row1_col1" class="data row1 col1" >0.621577</td>
#       <td id="T_9fb14_row1_col2" class="data row1 col2" >roc_auc_ovo</td>
#       <td id="T_9fb14_row1_col3" class="data row1 col3" >372.770194</td>
#       <td id="T_9fb14_row1_col4" class="data row1 col4" >10050.806549</td>
#       <td id="T_9fb14_row1_col5" class="data row1 col5" >16.657806</td>
#       <td id="T_9fb14_row1_col6" class="data row1 col6" >1585.027580</td>
#       <td id="T_9fb14_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_9fb14_row1_col8" class="data row1 col8" >True</td>
#       <td id="T_9fb14_row1_col9" class="data row1 col9" >13</td>
#     </tr>
#     <tr>
#       <th id="T_9fb14_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9fb14_row2_col0" class="data row2 col0" >LightGBMXT_BAG_L2</td>
#       <td id="T_9fb14_row2_col1" class="data row2 col1" >0.620426</td>
#       <td id="T_9fb14_row2_col2" class="data row2 col2" >roc_auc_ovo</td>
#       <td id="T_9fb14_row2_col3" class="data row2 col3" >396.817254</td>
#       <td id="T_9fb14_row2_col4" class="data row2 col4" >8947.707582</td>
#       <td id="T_9fb14_row2_col5" class="data row2 col5" >40.704866</td>
#       <td id="T_9fb14_row2_col6" class="data row2 col6" >481.928612</td>
#       <td id="T_9fb14_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_9fb14_row2_col8" class="data row2 col8" >True</td>
#       <td id="T_9fb14_row2_col9" class="data row2 col9" >14</td>
#     </tr>
#     <tr>
#       <th id="T_9fb14_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9fb14_row3_col0" class="data row3 col0" >LightGBM_BAG_L2</td>
#       <td id="T_9fb14_row3_col1" class="data row3 col1" >0.620044</td>
#       <td id="T_9fb14_row3_col2" class="data row3 col2" >roc_auc_ovo</td>
#       <td id="T_9fb14_row3_col3" class="data row3 col3" >381.413751</td>
#       <td id="T_9fb14_row3_col4" class="data row3 col4" >8863.395122</td>
#       <td id="T_9fb14_row3_col5" class="data row3 col5" >25.301363</td>
#       <td id="T_9fb14_row3_col6" class="data row3 col6" >397.616153</td>
#       <td id="T_9fb14_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_9fb14_row3_col8" class="data row3 col8" >True</td>
#       <td id="T_9fb14_row3_col9" class="data row3 col9" >15</td>
#     </tr>
#     <tr>
#       <th id="T_9fb14_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9fb14_row4_col0" class="data row4 col0" >WeightedEnsemble_L2</td>
#       <td id="T_9fb14_row4_col1" class="data row4 col1" >0.618970</td>
#       <td id="T_9fb14_row4_col2" class="data row4 col2" >roc_auc_ovo</td>
#       <td id="T_9fb14_row4_col3" class="data row4 col3" >140.203682</td>
#       <td id="T_9fb14_row4_col4" class="data row4 col4" >5925.519684</td>
#       <td id="T_9fb14_row4_col5" class="data row4 col5" >1.423566</td>
#       <td id="T_9fb14_row4_col6" class="data row4 col6" >459.034797</td>
#       <td id="T_9fb14_row4_col7" class="data row4 col7" >2</td>
#       <td id="T_9fb14_row4_col8" class="data row4 col8" >True</td>
#       <td id="T_9fb14_row4_col9" class="data row4 col9" >12</td>
#     </tr>
#     <tr>
#       <th id="T_9fb14_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9fb14_row5_col0" class="data row5 col0" >LightGBM_BAG_L1</td>
#       <td id="T_9fb14_row5_col1" class="data row5 col1" >0.616821</td>
#       <td id="T_9fb14_row5_col2" class="data row5 col2" >roc_auc_ovo</td>
#       <td id="T_9fb14_row5_col3" class="data row5 col3" >90.383565</td>
#       <td id="T_9fb14_row5_col4" class="data row5 col4" >374.733164</td>
#       <td id="T_9fb14_row5_col5" class="data row5 col5" >90.383565</td>
#       <td id="T_9fb14_row5_col6" class="data row5 col6" >374.733164</td>
#       <td id="T_9fb14_row5_col7" class="data row5 col7" >1</td>
#       <td id="T_9fb14_row5_col8" class="data row5 col8" >True</td>
#       <td id="T_9fb14_row5_col9" class="data row5 col9" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9fb14_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9fb14_row6_col0" class="data row6 col0" >CatBoost_BAG_L1</td>
#       <td id="T_9fb14_row6_col1" class="data row6 col1" >0.614469</td>
#       <td id="T_9fb14_row6_col2" class="data row6 col2" >roc_auc_ovo</td>
#       <td id="T_9fb14_row6_col3" class="data row6 col3" >3.742165</td>
#       <td id="T_9fb14_row6_col4" class="data row6 col4" >4747.071664</td>
#       <td id="T_9fb14_row6_col5" class="data row6 col5" >3.742165</td>
#       <td id="T_9fb14_row6_col6" class="data row6 col6" >4747.071664</td>
#       <td id="T_9fb14_row6_col7" class="data row6 col7" >1</td>
#       <td id="T_9fb14_row6_col8" class="data row6 col8" >True</td>
#       <td id="T_9fb14_row6_col9" class="data row6 col9" >6</td>
#     </tr>
#     <tr>
#       <th id="T_9fb14_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9fb14_row7_col0" class="data row7 col0" >LightGBMXT_BA

# %%
## -- RUN 2: Use original data as extra learning input --
# predictor.fit_pseudolabel(
#                 orig,
#                 use_ensemble = True,
#                 fit_ensemble = True,
#                 time_limit   = 3600*5,
#                 ag_args_fit  = {'num_cpus': os.cpu_count() - 1},
# )

# %%
## -- Get Summary -- 
# print(f"""
#     # {'█'*5}| Total models : {len(predictor.model_names())}
#     # {'█'*5}| Best model   : {predictor.model_best}
#         """)

# # -- Observe RUN 2 RESULTS --
# leaderboard = predictor.leaderboard(silent=True)
# display(leaderboard.style.background_gradient(subset=["score_val"], cmap="Spectral"))

# %%
## -- Create folder directory to save predictions --
SAVE_PATH = '/kaggle/working/AG_loan_predictions/'
# !mkdir {SAVE_PATH}

# %%
## -- Predictions for {SELECTED FEATURE} --
oof_ = predictor.predict_proba_oof(train_data=train, as_multiclass=False)
np.save(f"{SAVE_PATH}oof_AG_on_{TARGET}.npy", oof_)

preds_ = predictor.predict_proba(data=test, as_multiclass=False)
np.save(f"{SAVE_PATH}pred_AG_on_{TARGET}.npy", preds_)

oof_[:5], preds_[:5]
# Out:
# (   Employed   Retired  Self-employed   Student  Unemployed
#  0  0.815611  0.037176       0.089033  0.011013    0.047167
#  1  0.628666  0.015543       0.070327  0.043257    0.242207
#  2  0.788733  0.028424       0.073504  0.017073    0.092266
#  3  0.780602  0.023180       0.082281  0.013722    0.100216
#  4  0.802116  0.034394       0.101245  0.010449    0.051796,
#     Employed   Retired  Self-employed   Student  Unemployed
#  0  0.790220  0.029342       0.090585  0.013969    0.075883
#  1  0.805470  0.037481       0.093759  0.012702    0.050588
#  2  0.652391  0.014260       0.067066  0.060308    0.205976
#  3  0.810869  0.023364       0.098732  0.013024    0.054011
#  4  0.825282  0.033380       0.088729  0.011379    0.041231)

# %%
predictor.plot_ensemble_model(filename='ensemble_model.png')
display(Image(f'{MODELS_PATH}ensemble_model.png'))

# %%
# !zip -r /kaggle/working/AG_accident_models /kaggle/working/AG_accident_models.zip
# !zip -r {FOLDER}{NAME_EXT}.zip /kaggle/working/{FOLDER}{NAME_EXT}

# %%
## -- Extract model scores --
result_ = dict(zip(leaderboard['model'], leaderboard['score_val']))
result_df = pd.DataFrame.from_dict(result_, orient='index').sort_values(0)

max_score = result_df.max().item()
min_score = result_df.min().item()

## -- PLOT MODELS & SCORES --
plt.figure(figsize=(18, 15))
plt.stem(
    result_df.index,
    result_df[0],
    orientation = 'horizontal',
    bottom = min_score - 0.0055,
    markerfmt = 'C3o'
)
plt.xlim(min_score - 0.006, max_score + 0.005)
plt.xlabel('Score')
plt.title('-- Scores of Models --', fontsize=15)

for i, value in enumerate(result_df[0]):
    plt.text(value+1e-3, i, f'{abs(value):.5f}', ha='left', va='center', fontdict=dict(size=12))

plt.grid(True, axis='x')
plt.tight_layout()
plt.show()

# %%
# predictor.model_names()

# %%
# ## -- Permutation Feature Importances --
# feat_imp = predictor.feature_importance(
#                         data = X_test,
#                         # time_limit = 3600,
#                         # model = 'LightGBM_BAG_L1',
#                         # features = None,
#                         # feature_stage = 'transformed',
#                         # subsample_size = 5000,
#                         # num_shuffle_sets = 10,
#                         # include_confidence_band = True,
#                         confidence_level = 0.95,
#                         # silent = False
# ) 

# feat_imp.style.background_gradient(subset=["importance"], cmap="Spectral")

# %%
# plt.figure(figsize=(18, 35))
# sns.barplot(data=feat_imp, y=feat_imp.index, x=feat_imp.importance)
# plt.tick_params(axis='y', which='major', labelcolor='r')
# plt.title("Top Features by Permutation")
# plt.tight_layout()
# plt.show()

# %%
## -- OPTIONAL: Remove stored files --
# !rm -r {MODELS_PATH}

# %%
print(f"""
{'-'*48}
{'█'*5} | - AUTOGLUON NOTEBOOK COMPLETE! - | {'█'*5}
{'-'*48}
""")
# Out:
# ------------------------------------------------
# █████ | - AUTOGLUON NOTEBOOK COMPLETE! - | █████
# ------------------------------------------------
