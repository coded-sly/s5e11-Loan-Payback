# %%
## -- Set Device-Agnostic code --
import torch
print(f"ℹ️ Cuda available: {torch.cuda.is_available()}")

# import cuml.accel
# cuml.accel.install()

# %load_ext cudf.pandas
from cuml.preprocessing import TargetEncoder as cuTE
# Out:
# ℹ️ Cuda available: True

# %%
## -- IMPORT LIBRARIES --
import sys, os, gc
from scipy.special import logit

## -- DATA MANIPUALATION --
import numpy as np, pandas as pd, random

## -- VISUALISATION --
from IPython.display import display, Image
import matplotlib.pyplot as plt
import seaborn as sns
import shap

## -- FUNCTIONAL TOOLS --
from time import time, sleep, perf_counter
from itertools import combinations, product
from tqdm.notebook import tqdm

## -- MACHINE LEARNING --
import sklearn
import xgboost as xgb

from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.metrics import (
                roc_auc_score,
                RocCurveDisplay,
                ConfusionMatrixDisplay,
                classification_report
)

import warnings

# %%
print(f"sklearn  version: {sklearn.__version__}")
print(f"sxgboost version: {xgb.__version__}")
# Out:
# sklearn  version: 1.2.2
# sxgboost version: 2.0.3

# %%
## -- Global Settings --
# sklearn.set_config(transform_output="pandas")
warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')

# pd.options.mode.copy_on_write = True
pd.set_option('display.max_columns', 1000)
# plt.style.use("ggplot")
sns.set_style("darkgrid")

## -- Set Global Seed --
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

COLOR = '\033[32m'
RESET = '\033[0m'

# %%
### Load Data ###
PATH = "/kaggle/input/playground-series-s5e11/"
submit = pd.read_csv(PATH+"sample_submission.csv")
train = pd.read_csv(PATH+"train.csv").drop(['id'], axis=1)
test = pd.read_csv(PATH+"test.csv").drop(['id'], axis=1)

TARGET = "loan_paid_back"
NUMS = test.select_dtypes(include='number').columns.tolist()
CATS = test.select_dtypes(exclude='number').columns.tolist()
BASE = NUMS + CATS

ORIG_PATH = "/kaggle/input/loan-prediction-dataset-2025/"
orig = pd.read_csv(ORIG_PATH+"loan_dataset_20000.csv")[BASE+[TARGET]]

for (name, df) in dict(Train=train, Test=test, Original=orig).items():
    print(f"{name} shape: {df.shape}")

print(f"\nTotal Numerical: {len(NUMS)}")
print(f"Total Categorical: {len(CATS)}")
print(f"Total base features: {len(BASE)}")
# Out:
# Train shape: (593994, 12)
# Test shape: (254569, 11)
# Original shape: (20000, 12)
#
# Total Numerical: 5
# Total Categorical: 6
# Total base features: 11

# %%
# ### Load Data ###
# submit = pd.read_csv("sample_submission.csv")
# train = pd.read_csv("train.csv",index_col='id') #.drop('id', axis=1)
# test = pd.read_csv("test.csv", index_col='id') #.drop('id', axis=1)

# TARGET = "loan_paid_back"
# NUMS = test.select_dtypes(include='number').columns.tolist()
# CATS = test.select_dtypes(exclude='number').columns.tolist()
# BASE = NUMS + CATS

# orig = pd.read_csv("loan_dataset_20000.csv")[BASE+[TARGET]]

# for (name, df) in dict(Train=train, Test=test, Original=orig).items():
#     print(f"{name} shape: {df.shape}")

# print(f"\nTotal Numerical: {len(NUMS)}")
# print(f"Total Categorical: {len(CATS)}")
# print(f"Total base features: {len(BASE)}")

# %%
# display(test.head())
train.info()
# Out:
# <class 'cudf.core.dataframe.DataFrame'>
# RangeIndex: 593994 entries, 0 to 593993
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   annual_income         593994 non-null  float64
#  1   debt_to_income_ratio  593994 non-null  float64
#  2   credit_score          593994 non-null  int64
#  3   loan_amount           593994 non-null  float64
#  4   interest_rate         593994 non-null  float64
#  5   gender                593994 non-null  object
#  6   marital_status        593994 non-null  object
#  7   education_level       593994 non-null  object
#  8   employment_status     593994 non-null  object
#  9   loan_purpose          593994 non-null  object
#  10  grade_subgrade        593994 non-null  object
#  11  loan_paid_back        593994 non-null  float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 65.8+ MB

# %%
train.head()
# Out:
#    annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 0       29367.99                 0.084           736      2528.42
# 1       22108.02                 0.166           636      4593.10
# 2       49566.20                 0.097           694     17005.15
# 3       46858.25                 0.065           533      4682.48
# 4       25496.70                 0.053           665     12184.43
#
#    interest_rate  gender marital_status education_level employment_status  \
# 0          13.67  Female         Single     High School     Self-employed
# 1          12.92    Male        Married        Master's          Employed
# 2           9.76    Male         Single     High School          Employed
# 3          16.10  Female         Single     High School          Employed
# 4          10.21    Male        Married     High School          Employed
#
#          loan_purpose grade_subgrade  loan_paid_back
# 0               Other             C3             1.0
# 1  Debt consolidation             D3             0.0
# 2  Debt consolidation             C5             1.0
# 3  Debt consolidation             F1             1.0
# 4               Other             D1             1.0

# %%
train.describe().T
# Out:
#                          count          mean           std       min  \
# annual_income         593994.0  48212.202976  26711.942078  6002.430
# debt_to_income_ratio  593994.0      0.120696      0.068573     0.011
# credit_score          593994.0    680.916009     55.424956   395.000
# loan_amount           593994.0  15020.297629   6926.530568   500.090
# interest_rate         593994.0     12.356345      2.008959     3.200
# loan_paid_back        593994.0      0.798820      0.400883     0.000
#
#                             25%        50%        75%         max
# annual_income         27934.400  46557.680  60981.320  393381.740
# debt_to_income_ratio      0.072      0.096      0.156       0.627
# credit_score            646.000    682.000    719.000     849.000
# loan_amount           10279.620  15000.220  18858.580   48959.950
# interest_rate            10.990     12.370     13.680      20.990
# loan_paid_back            1.000      1.000      1.000       1.000

# %%
test.describe().T
# Out:
#                          count          mean           std       min  \
# annual_income         254569.0  48233.080193  26719.658580  6011.770
# debt_to_income_ratio  254569.0      0.120583      0.068582     0.011
# credit_score          254569.0    681.037691     55.624118   395.000
# loan_amount           254569.0  15016.753484   6922.165182   500.050
# interest_rate         254569.0     12.352323      2.017602     3.200
#
#                             25%        50%        75%         max
# annual_income         27950.300  46528.980  61149.440  380653.940
# debt_to_income_ratio      0.072      0.096      0.156       0.627
# credit_score            646.000    683.000    719.000     849.000
# loan_amount           10248.580  15000.220  18831.460   48959.260
# interest_rate            10.980     12.370     13.690      21.290

# %%
train.nunique(dropna=False).sort_values(ascending=False)
# Out:
# annual_income           119728
# loan_amount             111570
# interest_rate             1454
# debt_to_income_ratio       526
# credit_score               399
# grade_subgrade              30
# loan_purpose                 8
# education_level              5
# employment_status            5
# marital_status               4
# gender                       3
# loan_paid_back               2
# dtype: int64

# %% [markdown]
# # * FEATURE ENGINEERING

# %% [markdown]
# ## - APPEND BASE_MARGIN

# %%
# ## -- AutoGluon Probabilities --
# orig_margin = pd.read_csv("/kaggle/input/ps5e11-autogluon-original/origY_extreme.csv")
# orig_margin = orig_margin.rename(columns={'origY_extreme': 'y'})
# orig = pd.concat([orig, orig_margin], axis=1)

# train_margin = pd.read_csv("/kaggle/input/ps5e11-autogluon-original/trainY_extreme.csv")
# train_margin = train_margin.rename(columns={'trainY_extreme': 'y'})
# train = pd.concat([train, train_margin], axis=1)

# test_margin = pd.read_csv("/kaggle/input/ps5e11-autogluon-original/testY_extreme.csv")
# test_margin = test_margin.rename(columns={'testY_extreme': 'y'})
# test = pd.concat([test, test_margin], axis=1)

# ## -- Convert probas to logits --
# epsilon = 1e-6
# orig['y'] = logit(np.clip(orig['y'], epsilon, 1 - epsilon)) 
# train['y'] = logit(np.clip(train['y'], epsilon, 1 - epsilon)) 
# test['y'] = logit(np.clip(test['y'], epsilon, 1 - epsilon)) 

# train.head()

# %%
## -- Define categories for OHE --
CAT_COLS = [c for c in BASE if train[c].dtype=='object' or train[c].nunique() <= 0.01*len(train)]
print(f"ℹ️ Features for TE: {len(CAT_COLS)} -> {CAT_COLS}")
# Out:
# ℹ️ Features for TE: 9 -> ['debt_to_income_ratio', 'credit_score', 'interest_rate', 'gender', 'marital_status', 'education_level', 'employment_status', 'loan_purpose', 'grade_subgrade']

# %%
## -- Factorize using combined data --
for c in [i for i in CATS if train[i].dtype == 'object']:
    combined = pd.concat([train[c], test[c], orig[c]], axis=0)
    combined = combined.factorize()[0]
    train[c] = combined[:len(train)].astype("int8")
    test[c]  = combined[len(train):len(train)+len(test)].astype("int8")
    orig[c]  = combined[-len(orig):].astype("int8")

print('Label encoding complete!!')
# Out:
# Label encoding complete!!

# %%
# ROUND = []
# round_levels = {'1s': 0, '10s': -1, '100s': -2, '1000s': -3}

# for col in tqdm(['annual_income', 'loan_amount']):
#     for suffix, level in round_levels.items():
#         new_col = f'{col}_r{suffix}'
#         ROUND.append(new_col)
        
#         for df in [train, test, orig]:
#             df[new_col] = df[col].round(level).astype(int)

# print(f'{len(ROUND)} ROUND Features created.')
# train[ROUND].nunique()

# %% [markdown]
# ## - DIGITIZE | ROUND + INTERACTION

# %%
ROUND = []
for col in tqdm(['annual_income', 'loan_amount']):
    for r in [-3, -2, -1, 0]:
        n = f"{col}_r{r}"
        train[n] = train[col].round(r).astype(int)
        test[n] = test[col].round(r).astype(int)
        orig[n] = test[col].round(r).astype(int)
        ROUND.append(n)

print(f'{len(ROUND)} ROUND Features created.')
print(train[ROUND].nunique())

DIGITS = []
for col in tqdm(['debt_to_income_ratio']):
    for d in range(1, 4):
        n = f'{col}_d{d}'
        train[n] = ((train[col] * 10**d) % 10).fillna(-1).astype(int)
        test[n]  = ((test[col]  * 10**d) % 10).fillna(-1).astype(int)
        orig[n]  = ((orig[col]  * 10**d) % 10).fillna(-1).astype(int)

        ## -- Drop constant features --
        if train[n].nunique() < 2:
            train.drop([n], axis=1, inplace=True)
            test.drop([n],  axis=1, inplace=True)
            orig.drop([n],  axis=1, inplace=True)
        else:
            DIGITS.append(n)

for col in tqdm(['interest_rate']):
    for d in range(1, 3):
        n = f'{col}_d{d}'
        train[n] = ((train[col] * 10**d) % 10).fillna(-1).astype(int)
        test[n]  = ((test[col]  * 10**d) % 10).fillna(-1).astype(int)
        orig[n]  = ((orig[col]  * 10**d) % 10).fillna(-1).astype(int)

        ## -- Drop constant features --
        if train[n].nunique() < 2:
            train.drop([n], axis=1, inplace=True)
            test.drop([n],  axis=1, inplace=True)
            orig.drop([n],  axis=1, inplace=True)
        else:
            DIGITS.append(n)

print(f'{len(DIGITS)} Features DIGITS extracted.')
print(train[DIGITS].nunique())

INTER = []
for col1, col2 in tqdm(list(combinations(CAT_COLS+DIGITS, 2)), desc="Pairwise"):
    new_col = f"{col1}-|-{col2}"
    train[new_col] = train[col1].astype(str) + '_' + train[col2].astype(str)
    test[new_col] = test[col1].astype(str) + '_' + test[col2].astype(str)
    INTER.append(new_col)

print(f"Ineraction Features: {len(INTER)}")
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# 8 ROUND Features created.
# annual_income_r-3      270
# annual_income_r-2     1721
# annual_income_r-1     9706
# annual_income_r0     35523
# loan_amount_r-3         49
# loan_amount_r-2        426
# loan_amount_r-1       3558
# loan_amount_r0       21644
# dtype: int64
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 5 Features DIGITS extracted.
# debt_to_income_ratio_d1     7
# debt_to_income_ratio_d2    10
# debt_to_income_ratio_d3    10
# interest_rate_d1           10
# interest_rate_d2           10
# dtype: int64
# Pairwise:   0%|          | 0/91 [00:00<?, ?it/s]
# Ineraction Features: 91

# %% [markdown]
# ## - BINNING | ROUND + INTERACTION

# %%
# BINS = []
# b = 6
# for c in tqdm(['annual_income', 'loan_amount'], desc='Binning'):
#     n = f"{c}_bin{b}"
#     train[n], edges = pd.cut(train[c], bins=b, duplicates='drop', retbins=True, labels=False)
#     test[n] = pd.cut(test[c], bins=edges, include_lowest=True, labels=False)
#     test[n].fillna(-1, inplace=True)
#     BINS.append(n)
    
# print(f"Total Binned Features: {len(BINS)}")

# for col1, col2 in tqdm(list(combinations(DIGITS+BINS, 2)), desc="Pairwise"):
#     new_col = f"TE_{col1}-|-{col2}"
#     train[new_col] = train[col1].astype(str) + '_' + train[col2].astype(str)
#     test[new_col] = test[col1].astype(str) + '_' + test[col2].astype(str)
#     INTER.append(new_col)
# print(f"Ineraction Features: {len(INTER)}")

# %%
# BINS = []
# for c in tqdm(['loan_amount'], desc='Binning'):
#     b = [0, 5000, 10000, 20000, 30000, 40000, np.inf]
#     n = f"{c}_BIN"
#     train[n], edges = pd.cut(train[c], bins=b, duplicates='drop', retbins=True, labels=False)
#     test[n] = pd.cut(test[c], bins=edges, include_lowest=True, labels=False)
#     test[n].fillna(-1, inplace=True)
#     BINS.append(n)

# for c in tqdm(['annual_income'], desc='Binning'):
#     b = [0, 40000, 75000, 100000, 150000, 250000, 300000, np.inf]
#     n = f"{c}_BIN"
#     train[n], edges = pd.cut(train[c], bins=b, duplicates='drop', retbins=True, labels=False)
#     test[n] = pd.cut(test[c], bins=edges, include_lowest=True, labels=False)
#     test[n].fillna(-1, inplace=True)
#     BINS.append(n)

# print(f"Total Binned Features: {len(BINS)}")

# print("Train null:", train.isna().sum().sum())
# print("Test null:", test.isna().sum().sum())

# %% [markdown]
# ## - USE ORIGINAL AS COLUMNS

# %%
ORIG = []

if 'y' in orig.columns:
    BASE.append('y')

for col in tqdm(BASE): # +ROUND
    # MEAN
    mean_map = orig.groupby(col)[TARGET].mean()
    mean_col = f"OTE_{col}_mean"
    mean_map.name = mean_col
    
    train = train.merge(mean_map, on=col, how='left')
    test = test.merge(mean_map, on=col, how='left')
    ORIG.append(mean_col)

    # COUNT
    count_col = f"OTE_{col}_count"
    count_map = orig.groupby(col).size().reset_index(name=count_col)
    
    train = train.merge(count_map, on=col, how='left')
    test = test.merge(count_map, on=col, how='left')
    ORIG.append(count_col)

print(len(ORIG), 'Orig Features Created!!')
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
# 22 Orig Features Created!!

# %%
train.head()
# Out:
#    annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 0       29367.99                 0.084           736      2528.42
# 1       22108.02                 0.166           636      4593.10
# 2       49566.20                 0.097           694     17005.15
# 3       46858.25                 0.065           533      4682.48
# 4       25496.70                 0.053           665     12184.43
#
#    interest_rate  gender  marital_status  education_level  employment_status  \
# 0          13.67       0               0                0                  0
# 1          12.92       1               1                1                  1
# 2           9.76       1               0                0                  1
# 3          16.10       0               0                0                  1
# 4          10.21       1               1                0                  1
#
#    loan_purpose  grade_subgrade  loan_paid_back  annual_income_r-3  \
# 0             0               0             1.0              29000
# 1             1               1             0.0              22000
# 2             1               2             1.0              50000
# 3             1               3             1.0              47000
# 4             0               4             1.0              25000
#
#    annual_income_r-2  annual_income_r-1  annual_income_r0  loan_amount_r-3  \
# 0              29400              29370             29368             3000
# 1              22100              22110             22108             5000
# 2              49600              49570             49566            17000
# 3              46900              46860             46858             5000
# 4              25500              25500             25497            12000
#
#    loan_amount_r-2  loan_amount_r-1  loan_amount_r0  debt_to_income_ratio_d1  \
# 0             2500             2530            2528                        0
# 1             4600             4590            4593                        1
# 2            17000            17010           17005                        0
# 3             4700             4680            4682                        0
# 4            12200            12180           12184                        0
#
#    debt_to_income_ratio_d2  debt_to_income_ratio_d3  interest_rate_d1  \
# 0                        8                        4                 6
# 1                        6                        6                 9
# 2                        9                        7                 7
# 3                        6                        5                 1
# 4                        5                        3                 2
#
#    interest_rate_d2 debt_to_income_ratio-|-credit_score  \
# 0                 7                           0.084_736
# 1                 2                           0.166_636
# 2                 6                           0.097_694
# 3                 0                           0.065_533
# 4                 0                           0.053_665
#
#   debt_to_income_ratio-|-interest_rate debt_to_income_ratio-|-gender  \
# 0                          0.084_13.67                       0.084_0
# 1                          0.166_12.92                       0.166_1
# 2                           0.097_9.76                       0.097_1
# 3                           0.065_16.1                       0.065_0
# 4                          0.053_10.21                       0.053_1
#
#   debt_to_income_ratio-|-marital_status  \
# 0                               0.084_0
# 1                               0.166_1
# 2                               0.097_0
# 3                               0.065_0
# 4                               0.053_1
#
#   debt_to_income_ratio-|-education_level  \
# 0                                0.084_0
# 1                                0.166_1
# 2                                0.097_0
# 3                                0.065_0
# 4                                0.053_0
#
#   debt_to_income_ratio-|-employment_status  \
# 0                                  0.084_0
# 1                                  0.166_1
# 2                                  0.097_1
# 3                                  0.065_1
# 4                                  0.053_1
#
#   debt_to_income_ratio-|-loan_purpose debt_to_income_ratio-|-grade_subgrade  \
# 0                             0.084_0                               0.084_0
# 1                             0.166_1                               0.166_1
# 2                             0.097_1                               0.097_2
# 3                             0.065_1                               0.065_3
# 4                             0.053_0                               0.053_4
#
#   debt_to_income_ratio-|-debt_to_income_ratio_d1  \
# 0                                        0.084_0
# 1                                        0.166_1
# 2                                        0.097_0
# 3                                        0.065_0
# 4                                        0.053_0
#
#   debt_to_income_ratio-|-debt_to_income_ratio_d2  \
# 0                                        0.084_8
# 1                                        0.166_6
# 2                                        0.097_9
# 3                                        0.065_6
# 4                                        0.053_5
#
#   debt_to_income_ratio-|-debt_to_income_ratio_d3  \
# 0                                        0.084_4
# 1                                        0.166_6
# 2                                        0.097_7
# 3                                        0.065_5
# 4                                        0.053_3
#
#   debt_to_income_ratio-|-interest_rate_d1  \
# 0                                 0.084_6
# 1                                 0.166_9
# 2                                 0.097_7
# 3                                 0.065_1
# 4                                 0.053_2
#
#   debt_to_income_ratio-|-interest_rate_d2 credit_score-|-interest_rate  \
# 0                                 0.084_7                    736_13.67
# 1                                 0.166_2                    636_12.92
# 2                                 0.097_6                     694_9.76
# 3                                 0.065_0                     533_16.1
# 4                                 0.053_0                    665_10.21
#
#   credit_score-|-gender credit_score-|-marital_status  \
# 0                 736_0                         736_0
# 1                 636_1                         636_1
# 2                 694_1                         694_0
# 3                 533_0                         533_0
# 4                 665_1                         665_1
#
#   credit_score-|-education_level credit_score-|-employment_status  \
# 0                          736_0                            736_0
# 1                          636_1                            636_1
# 2                          694_0                            694_1
# 3                          533_0                            533_1
# 4                          665_0                            665_1
#
#   credit_score-|-loan_purpose credit_score-|-grade_subgrade  \
# 0                       736_0                         736_0
# 1                       636_1                         636_1
# 2                       694_1                         694_2
# 3                       533_1                         533_3
# 4                       665_0                         665_4
#
#   credit_score-|-debt_to_income_ratio_d1  \
# 0                                  736_0
# 1                                  636_1
# 2                                  694_0
# 3                                  533_0
# 4                                  665_0
#
#   credit_score-|-debt_to_income_ratio_d2  \
# 0                                  736_8
# 1                                  636_6
# 2                                  694_9
# 3                                  533_6
# 4                                  665_5
#
#   credit_score-|-debt_to_income_ratio_d3 credit_score-|-interest_rate_d1  \
# 0                                  736_4                           736_6
# 1                                  636_6                           636_9
# 2                                  694_7                           694_7
# 3                                  533_5                           533_1
# 4                                  665_3                           665_2
#
#   credit_score-|-interest_rate_d2 interest_rate-|-gender  \
# 0                           736_7                13.67_0
# 1                           636_2                12.92_1
# 2                           694_6                 9.76_1
# 3                           533_0                 16.1_0
# 4                           665_0                10.21_1
#
#   interest_rate-|-marital_status interest_rate-|-education_level  \
# 0                        13.67_0                         13.67_0
# 1                        12.92_1                         12.92_1
# 2                         9.76_0                          9.76_0
# 3                         16.1_0                          16.1_0
# 4                        10.21_1                         10.21_0
#
#   interest_rate-|-employment_status interest_rate-|-loan_purpose  \
# 0                           13.67_0                      13.67_0
# 1                           12.92_1                      12.92_1
# 2                            9.76_1                       9.76_1
# 3                            16.1_1                       16.1_1
# 4                           10.21_1                      10.21_0
#
#   interest_rate-|-grade_subgrade interest_rate-|-debt_to_income_ratio_d1  \
# 0                        13.67_0                                 13.67_0
# 1                        12.92_1                                 12.92_1
# 2                         9.76_2                                  9.76_0
# 3                         16.1_3                                  16.1_0
# 4                        10.21_4                                 10.21_0
#
#   interest_rate-|-debt_to_income_ratio_d2  \
# 0                                 13.67_8
# 1                                 12.92_6
# 2                                  9.76_9
# 3                                  16.1_6
# 4                                 10.21_5
#
#   interest_rate-|-debt_to_income_ratio_d3 interest_rate-|-interest_rate_d1  \
# 0                                 13.67_4                          13.67_6
# 1                                 12.92_6                          12.92_9
# 2                                  9.76_7                           9.76_7
# 3                                  16.1_5                           16.1_1
# 4                                 10.21_3                          10.21_2
#
#   interest_rate-|-interest_rate_d2 gender-|-marital_status  \
# 0                          13.67_7                     0_0
# 1                          12.92_2                     1_1
# 2                           9.76_6                     1_0
# 3                           16.1_0                     0_0
# 4                          10.21_0                     1_1
#
#   gender-|-education_level gender-|-employment_status gender-|-loan_purpose  \
# 0                      0_0                        0_0                   0_0
# 1                      1_1                        1_1                   1_1
# 2                      1_0                        1_1                   1_1
# 3                      0_0                        0_1                   0_1
# 4                      1_0                        1_1                   1_0
#
#   gender-|-grade_subgrade gender-|-debt_to_income_ratio_d1  \
# 0                     0_0                              0_0
# 1                     1_1                              1_1
# 2                     1_2                              1_0
# 3                     0_3                              0_0
# 4                     1_4                              1_0
#
#   gender-|-debt_to_income_ratio_d2 gender-|-debt_to_income_ratio_d3  \
# 0                              0_8                              0_4
# 1                              1_6                              1_6
# 2                              1_9                              1_7
# 3                              0_6                              0_5
# 4                              1_5                              1_3
#
#   gender-|-interest_rate_d1 gender-|-interest_rate_d2  \
# 0                       0_6                       0_7
# 1                       1_9                       1_2
# 2                       1_7                       1_6
# 3                       0_1                       0_0
# 4                       1_2                       1_0
#
#   marital_status-|-education_level marital_status-|-employment_status  \
# 0                              0_0                                0_0
# 1                              1_1                                1_1
# 2                              0_0                                0_1
# 3                              0_0                                0_1
# 4                              1_0                                1_1
#
#   marital_status-|-loan_purpose marital_status-|-grade_subgrade  \
# 0                           0_0                             0_0
# 1                           1_1                             1_1
# 2                           0_1                             0_2
# 3                           0_1                             0_3
# 4                           1_0                             1_4
#
#   marital_status-|-debt_to_income_ratio_d1  \
# 0                                      0_0
# 1                                      1_1
# 2                                      0_0
# 3                                      0_0
# 4                                      1_0
#
#   marital_status-|-debt_to_income_ratio_d2  \
# 0                                      0_8
# 1                                      1_6
# 2                                      0_9
# 3                                      0_6
# 4                                      1_5
#
#   marital_status-|-debt_to_income_ratio_d3 marital_status-|-interest_rate_d1  \
# 0                                      0_4                               0_6
# 1                                      1_6                               1_9
# 2                                      0_7                               0_7
# 3                                      0_5                               0_1
# 4                                      1_3                               1_2
#
#   marital_status-|-interest_rate_d2 education_level-|-employment_status  \
# 0                               0_7                                 0_0
# 1                               1_2                                 1_1
# 2                               0_6                                 0_1
# 3                               0_0                                 0_1
# 4                               1_0                                 0_1
#
#   education_level-|-loan_purpose education_level-|-grade_subgrade  \
# 0                            0_0                              0_0
# 1                            1_1                              1_1
# 2                            0_1                              0_2
# 3                            0_1                              0_3
# 4                            0_0                              0_4
#
#   education_level-|-debt_to_income_ratio_d1  \
# 0                                       0_0
# 1                                       1_1
# 2                                       0_0
# 3                                       0_0
# 4                                       0_0
#
#   education_level-|-debt_to_income_ratio_d2  \
# 0                                       0_8
# 1                                       1_6
# 2                                       0_9
# 3                                       0_6
# 4                                       0_5
#
#   education_level-|-debt_to_income_ratio_d3  \
# 0                                       0_4
# 1                                       1_6
# 2                                       0_7
# 3                                       0_5
# 4                                       0_3
#
#   education_level-|-interest_rate_d1 education_level-|-interest_rate_d2  \
# 0                                0_6                                0_7
# 1                                1_9                                1_2
# 2                                0_7                                0_6
# 3                                0_1                                0_0
# 4                                0_2                                0_0
#
#   employment_status-|-loan_purpose employment_status-|-grade_subgrade  \
# 0                              0_0                                0_0
# 1                              1_1                                1_1
# 2                              1_1                                1_2
# 3                              1_1                                1_3
# 4                              1_0                                1_4
#
#   employment_status-|-debt_to_income_ratio_d1  \
# 0                                         0_0
# 1                                         1_1
# 2                                         1_0
# 3                                         1_0
# 4                                         1_0
#
#   employment_status-|-debt_to_income_ratio_d2  \
# 0                                         0_8
# 1                                         1_6
# 2                                         1_9
# 3                                         1_6
# 4                                         1_5
#
#   employment_status-|-debt_to_income_ratio_d3  \
# 0                                         0_4
# 1                                         1_6
# 2                                         1_7
# 3                                         1_5
# 4                                         1_3
#
#   employment_status-|-interest_rate_d1 employment_status-|-interest_rate_d2  \
# 0                                  0_6                                  0_7
# 1                                  1_9                                  1_2
# 2                                  1_7                                  1_6
# 3                                  1_1                                  1_0
# 4                                  1_2                                  1_0
#
#   loan_purpose-|-grade_subgrade loan_purpose-|-debt_to_income_ratio_d1  \
# 0                           0_0                                    0_0
# 1                           1_1                                    1_1
# 2                           1_2                                    1_0
# 3                           1_3                                    1_0
# 4                           0_4                                    0_0
#
#   loan_purpose-|-debt_to_income_ratio_d2  \
# 0                                    0_8
# 1                                    1_6
# 2                                    1_9
# 3                                    1_6
# 4                                    0_5
#
#   loan_purpose-|-debt_to_income_ratio_d3 loan_purpose-|-interest_rate_d1  \
# 0                                    0_4                             0_6
# 1                                    1_6                             1_9
# 2                                    1_7                             1_7
# 3                                    1_5                             1_1
# 4                                    0_3                             0_2
#
#   loan_purpose-|-interest_rate_d2 grade_subgrade-|-debt_to_income_ratio_d1  \
# 0                             0_7                                      0_0
# 1                             1_2                                      1_1
# 2                             1_6                                      2_0
# 3                             1_0                                      3_0
# 4                             0_0                                      4_0
#
#   grade_subgrade-|-debt_to_income_ratio_d2  \
# 0                                      0_8
# 1                                      1_6
# 2                                      2_9
# 3                                      3_6
# 4                                      4_5
#
#   grade_subgrade-|-debt_to_income_ratio_d3 grade_subgrade-|-interest_rate_d1  \
# 0                                      0_4                               0_6
# 1                                      1_6                               1_9
# 2                                      2_7                               2_7
# 3                                      3_5                               3_1
# 4                                      4_3                               4_2
#
#   grade_subgrade-|-interest_rate_d2  \
# 0                               0_7
# 1                               1_2
# 2                               2_6
# 3                               3_0
# 4                               4_0
#
#   debt_to_income_ratio_d1-|-debt_to_income_ratio_d2  \
# 0                                               0_8
# 1                                               1_6
# 2                                               0_9
# 3                                               0_6
# 4                                               0_5
#
#   debt_to_income_ratio_d1-|-debt_to_income_ratio_d3  \
# 0                                               0_4
# 1                                               1_6
# 2                                               0_7
# 3                                               0_5
# 4                                               0_3
#
#   debt_to_income_ratio_d1-|-interest_rate_d1  \
# 0                                        0_6
# 1                                        1_9
# 2                                        0_7
# 3                                        0_1
# 4                                        0_2
#
#   debt_to_income_ratio_d1-|-interest_rate_d2  \
# 0                                        0_7
# 1                                        1_2
# 2                                        0_6
# 3                                        0_0
# 4                                        0_0
#
#   debt_to_income_ratio_d2-|-debt_to_income_ratio_d3  \
# 0                                               8_4
# 1                                               6_6
# 2                                               9_7
# 3                                               6_5
# 4                                               5_3
#
#   debt_to_income_ratio_d2-|-interest_rate_d1  \
# 0                                        8_6
# 1                                        6_9
# 2                                        9_7
# 3                                        6_1
# 4                                        5_2
#
#   debt_to_income_ratio_d2-|-interest_rate_d2  \
# 0                                        8_7
# 1                                        6_2
# 2                                        9_6
# 3                                        6_0
# 4                                        5_0
#
#   debt_to_income_ratio_d3-|-interest_rate_d1  \
# 0                                        4_6
# 1                                        6_9
# 2                                        7_7
# 3                                        5_1
# 4                                        3_2
#
#   debt_to_income_ratio_d3-|-interest_rate_d2  \
# 0                                        4_7
# 1                                        6_2
# 2                                        7_6
# 3                                        5_0
# 4                                        3_0
#
#   interest_rate_d1-|-interest_rate_d2 OTE_annual_income_mean  \
# 0                                 6_7                    0.0
# 1                                 9_2                    1.0
# 2                                 7_6                   <NA>
# 3                                 1_0                   <NA>
# 4                                 2_0                    1.0
#
#   OTE_annual_income_count  OTE_debt_to_income_ratio_mean  \
# 0                       1                       0.884615
# 1                       1                       0.765432
# 2                    <NA>                       0.923077
# 3                    <NA>                       0.925373
# 4                       1                       0.943662
#
#    OTE_debt_to_income_ratio_count  OTE_credit_score_mean  \
# 0                              78               0.862069
# 1                              81               0.649485
# 2                              91               0.825243
# 3                              67               0.846154
# 4                              71               0.843750
#
#    OTE_credit_score_count  OTE_loan_amount_mean  OTE_loan_amount_count  \
# 0                      87                   1.0                      1
# 1                      97                   1.0                      1
# 2                     103                   1.0                      1
# 3                      13                   1.0                      1
# 4                      96                   0.0                      1
#
#    OTE_interest_rate_mean  OTE_interest_rate_count  OTE_gender_mean  \
# 0                0.800000                       30         0.802472
# 1                0.560000                       25         0.797504
# 2                0.869565                       23         0.797504
# 3                0.600000                       10         0.802472
# 4                0.740741                       27         0.797504
#
#    OTE_gender_count  OTE_marital_status_mean  OTE_marital_status_count  \
# 0             10034                 0.799579                      9031
# 1              9536                 0.800312                      8974
# 2              9536                 0.799579                      9031
# 3             10034                 0.799579                      9031
# 4              9536                 0.800312                      8974
#
#    OTE_education_level_mean  OTE_education_level_count  \
# 0                  0.808076                       5919
# 1                  0.797798                       3724
# 2                  0.808076                       5919
# 3                  0.808076                       5919
# 4                  0.808076                       5919
#
#    OTE_employment_status_mean  OTE_employment_status_count  \
# 0                    0.885734                         2923
# 1                    0.886984                        13007
# 2                    0.886984                        13007
# 3                    0.886984                        13007
# 4                    0.886984                        13007
#
#    OTE_loan_purpose_mean  OTE_loan_purpose_count  OTE_grade_subgrade_mean  \
# 0               0.802745                    2550                 0.821004
# 1               0.799399                    7981                 0.727749
# 2               0.799399                    7981                 0.831224
# 3               0.799399                    7981                 0.653722
# 4               0.802745                    2550                 0.757576
#
#    OTE_grade_subgrade_count
# 0                      1514
# 1                      1146
# 2                      1422
# 3                       309
# 4                      1155

# %%
train.info()
# Out:
# <class 'cudf.core.dataframe.DataFrame'>
# RangeIndex: 593994 entries, 0 to 593993
# Columns: 138 entries, annual_income to OTE_grade_subgrade_count
# dtypes: float64(16), int64(25), int8(6), object(91)
# memory usage: 624.5+ MB

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class TargetEncoder(BaseEstimator, TransformerMixin):
    """
    Target Encoder that supports multiple aggregation functions,
    internal cross-validation for leakage prevention, and smoothing.

    Parameters
    ----------
    cols_to_encode : list of str
        List of column names to be target encoded.

    aggs : list of str, default=['mean']
        List of aggregation functions to apply. Any function accepted by
        pandas' `.agg()` method is supported, such as:
        'mean', 'std', 'var', 'min', 'max', 'skew', 'nunique', 
        'count', 'sum', 'median'.
        Smoothing is applied only to the 'mean' aggregation.

    cv : int, default=5
        Number of folds for cross-validation in fit_transform.

    smooth : float or 'auto', default='auto'
        The smoothing parameter `m`. A larger value puts more weight on the 
        global mean. If 'auto', an empirical Bayes estimate is used.
        
    drop_original : bool, default=False
        If True, the original columns to be encoded are dropped.
    """
    def __init__(self, cols_to_encode, aggs=['mean'], cv=5, smooth='auto', drop_original=False):
        self.cols_to_encode = cols_to_encode
        self.aggs = aggs
        self.cv = cv
        self.smooth = smooth
        self.drop_original = drop_original
        self.mappings_ = {}
        self.global_stats_ = {}

    def fit(self, X, y):
        """
        Learn mappings from the entire dataset.
        These mappings are used for the transform method on validation/test data.
        """
        temp_df = X.copy()
        temp_df['target'] = y

        # Learn global statistics for each aggregation
        for agg_func in self.aggs:
            self.global_stats_[agg_func] = y.agg(agg_func)

        # Learn category-specific mappings
        for col in self.cols_to_encode:
            self.mappings_[col] = {}
            for agg_func in self.aggs:
                mapping = temp_df.groupby(col)['target'].agg(agg_func)
                self.mappings_[col][agg_func] = mapping
        
        return self

    def transform(self, X):
        """
        Apply learned mappings to the data.
        Unseen categories are filled with global statistics.
        """
        X_transformed = X.copy()
        for col in self.cols_to_encode:
            for agg_func in self.aggs:
                new_col_name = f'TE_{col}_{agg_func}'
                map_series = self.mappings_[col][agg_func]
                X_transformed[new_col_name] = X[col].map(map_series)
                X_transformed[new_col_name].fillna(self.global_stats_[agg_func], inplace=True)
        
        if self.drop_original:
            X_transformed.drop(columns=self.cols_to_encode, inplace=True)
            
        return X_transformed

    def fit_transform(self, X, y):
        """
        Fit and transform the data using internal cross-validation to prevent leakage.
        """
        # First, fit on the entire dataset to get global mappings for transform method
        self.fit(X, y)

        # Initialize an empty DataFrame to store encoded features
        encoded_features = pd.DataFrame(index=X.index)
        
        kf = KFold(n_splits=self.cv, shuffle=True, random_state=42)

        for train_idx, val_idx in kf.split(X, y):
            X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
            X_val = X.iloc[val_idx]
            
            temp_df_train = X_train.copy()
            temp_df_train['target'] = y_train

            for col in self.cols_to_encode:
                # --- Calculate mappings only on the training part of the fold ---
                for agg_func in self.aggs:
                    new_col_name = f'TE_{col}_{agg_func}'
                    
                    # Calculate global stat for this fold
                    fold_global_stat = y_train.agg(agg_func)
                    
                    # Calculate category stats for this fold
                    mapping = temp_df_train.groupby(col)['target'].agg(agg_func)

                    # --- Apply smoothing only for 'mean' aggregation ---
                    if agg_func == 'mean':
                        counts = temp_df_train.groupby(col)['target'].count()
                        
                        m = self.smooth
                        if self.smooth == 'auto':
                            # Empirical Bayes smoothing
                            variance_between = mapping.var()
                            avg_variance_within = temp_df_train.groupby(col)['target'].var().mean()
                            if variance_between > 0:
                                m = avg_variance_within / variance_between
                            else:
                                m = 0  # No smoothing if no variance between groups
                        
                        # Apply smoothing formula
                        smoothed_mapping = (counts * mapping + m * fold_global_stat) / (counts + m)
                        encoded_values = X_val[col].map(smoothed_mapping)
                    else:
                        encoded_values = X_val[col].map(mapping)
                    
                    # Store encoded values for the validation fold
                    encoded_features.loc[X_val.index, new_col_name] = encoded_values.fillna(fold_global_stat)

        # Merge with original DataFrame
        X_transformed = X.copy()
        for col in encoded_features.columns:
            X_transformed[col] = encoded_features[col]
            
        if self.drop_original:
            X_transformed.drop(columns=self.cols_to_encode, inplace=True)
            
        return X_transformed

# %% [markdown]
# # * ML TRAINING

# %% [markdown]
# 1. Using data trained on competition, we only use `base_margin` during `fit()`

# %%
FEATURES = [c for c in train.columns if c != TARGET]
print('Total Features', len(FEATURES))
# Out:
# Total Features 137

# %%
## -- Define Training Parameters --
if torch.cuda.is_available():
    print(f"ℹ️ Device GPU: {torch.cuda.get_device_name(0)}")
    print(f"ℹ️ No. of CPU: {os.cpu_count()} cores")
else:
    print(f"ℹ️ Device: CPU {os.cpu_count()} cores")

X = train[FEATURES]
y = train[TARGET]

FOLDS = 6
kf = StratifiedKFold(n_splits=FOLDS, shuffle=True, random_state=SEED)
## -----------------------------------------------------------------
oof_preds  = np.zeros(len(X))
test_preds = np.zeros(len(test))
fold_scores = []
models = []

params = dict(
    objective= 'binary:logistic',
    eval_metric= 'auc',
    max_depth= 6,
    learning_rate= 0.005,
    n_estimators= 20_000,
    subsample= 0.8,
    colsample_bytree= 0.3,
    colsample_bylevel= 0.5,
    reg_lambda= 1.5,
    enable_categorical= True,
    early_stopping_rounds= 300,
    random_state= SEED,
    n_jobs= -1,
    device= 'cuda' if torch.cuda.is_available() else 'cpu',
)

tik = time()
for fold, (train_idx, val_idx) in enumerate(kf.split(X, y)):
    print('|', '-'*20)
    print(f"Fold {fold+1}/{FOLDS}")
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
    X_test = test[FEATURES].copy()
    
    # ## -> Opt1. -> Using CUSTOM
    # TE = TargetEncoder(cols_to_encode=INTER,cv=5,smooth=1.0,aggs=['mean'],drop_original=True)
    # X_train = TE.fit_transform(X_train, y_train)
    # X_val   = TE.transform(X_val)
    # X_test  = TE.transform(X_test)

    # TE = TargetEncoder(cols_to_encode=ROUND,cv=5,smooth=1.0,aggs=['mean'],drop_original=False)
    # X_train = TE.fit_transform(X_train, y_train)
    # X_val   = TE.transform(X_val)
    # X_test  = TE.transform(X_test)
    
    ## -> Opt2. -> Using RAPIDS ->
    for c in INTER:
        TE = cuTE(n_folds=5, smooth=1.0, stat='mean', seed=SEED)
        X_train[c] = TE.fit_transform(X_train[c], y_train)
        X_val[c] = TE.transform(X_val[c])
        X_test[c] = TE.transform(X_test[c])

    for c in ROUND:
        TE = cuTE(n_folds=5, smooth=1.0, stat='mean', seed=SEED)
        new_col = f"TE_{c}"
        X_train[new_col] = TE.fit_transform(X_train[c], y_train)
        X_val[new_col] = TE.transform(X_val[c])
        X_test[new_col] = TE.transform(X_test[c])

    # BINS = []
    # b = 6
    # for c in tqdm(['annual_income', 'loan_amount'], desc='Binning'):
    #     n = f"{c}_bin{b}"
    #     X_train[n], edges = pd.cut(X_train[c], bins=b, duplicates='drop', retbins=True, labels=False)
    #     X_val[n] = pd.cut(X_val[c], bins=edges, include_lowest=True, labels=False)
    #     X_test[n] = pd.cut(X_test[c], bins=edges, include_lowest=True, labels=False)
    #     X_val[n].fillna(-1, inplace=True)
    #     X_test[n].fillna(-1, inplace=True)
    #     BINS.append(n)

    for c in CATS + DIGITS: #+BINS
        X_train[c] = X_train[c].astype('category')
        X_val[c]   = pd.Categorical(X_val[c], categories= X_train[c].cat.categories)
        X_test[c]  = pd.Categorical(X_test[c], categories=X_train[c].cat.categories)

    model = xgb.XGBClassifier(**params)
    model.fit(
        X_train, y_train,
        eval_set= [(X_val, y_val)],
        base_margin= X_train['y'] if 'y' in X_train.columns else None, ## <-
        verbose= 400
    )

    y_pred = model.predict_proba(
        X_val,
        base_margin= X_val['y'] if 'y' in X_val.columns else None ## <-
    )[:, 1]
    oof_preds[val_idx] = y_pred

    predictions = model.predict_proba(
        X_test,
        base_margin= X_test['y'] if 'y' in X_test.columns else None ## <-
    )[:, 1]
    test_preds += predictions / FOLDS

    score = roc_auc_score(y_val, y_pred)
    fold_scores.append(score)
    models.append(model)

    print(f"{COLOR}\tAUC: {score:.5f}{RESET}")
    # sleep(1); gc.collect(); sleep(2)

tok = time()
tiktok = (tok-tik) / 60
print('-'*20)
print(f"\tTraining Time: {tiktok:.2f} mins")
# Out:
# ℹ️ Device GPU: Tesla T4
# ℹ️ No. of CPU: 4 cores
# | --------------------
# Fold 1/6
# [0]	validation_0-auc:0.91574
# [400]	validation_0-auc:0.92439
# [800]	validation_0-auc:0.92639
# [1200]	validation_0-auc:0.92741
# [1600]	validation_0-auc:0.92778
# [2000]	validation_0-auc:0.92794
# [2400]	validation_0-auc:0.92803
# [2800]	validation_0-auc:0.92809
# [3200]	validation_0-auc:0.92811
# [3600]	validation_0-auc:0.92813
# [4000]	validation_0-auc:0.92815
# [4400]	validation_0-auc:0.92816
# [4800]	validation_0-auc:0.92817
# [5200]	validation_0-auc:0.92816
# [5233]	validation_0-auc:0.92816
# 	AUC: 0.92817
# | --------------------
# Fold 2/6
# [0]	validation_0-auc:0.91585
# [400]	validation_0-auc:0.92464
# [800]	validation_0-auc:0.92649
# [1200]	validation_0-auc:0.92751
# [1600]	validation_0-auc:0.92792
# [2000]	validation_0-auc:0.92813
# [2400]	validation_0-auc:0.92824
# [2800]	validation_0-auc:0.92828
# [3200]	validation_0-auc:0.92832
# [3600]	validation_0-auc:0.92835
# [4000]	validation_0-auc:0.92837
# [4400]	validation_0-auc:0.92839
# [4800]	validation_0-auc:0.92839
# [5200]	validation_0-auc:0.92840
# [5600]	validation_0-auc:0.92840
# [5647]	validation_0-auc:0.92840
# 	AUC: 0.92841
# | --------------------
# Fold 3/6
# [0]	validation_0-auc:0.91365
# [400]	validation_0-auc:0.92238
# [800]	validation_0-auc:0.92433
# [1200]	validation_0-auc:0.92537
# [1600]	validation_0-auc:0.92577
# [2000]	validation_0-auc:0.92593
# [2400]	validation_0-auc:0.92600
# [2800]	validation_0-auc:0.92604
# [3200]	validation_0-auc:0.92605
# [3560]	validation_0-auc:0.92603
# 	AUC: 0.92605
# | --------------------
# Fold 4/6
# [0]	validation_0-auc:0.91534
# [400]	validation_0-auc:0.92395
# [800]	validation_0-auc:0.92571
# [1200]	validation_0-auc:0.92657
# [1600]	validation_0-auc:0.92690
# [2000]	validation_0-auc:0.92703
# [2400]	validation_0-auc:0.92710
# [2800]	validation_0-auc:0.92715
# [3200]	validation_0-auc:0.92718
# [3600]	validation_0-auc:0.92722
# [4000]	validation_0-auc:0.92723
# [4400]	validation_0-auc:0.92723
# [4604]	validation_0-auc:0.92723
# 	AUC: 0.92723
# | --------------------
# Fold 5/6
# [0]	validation_0-auc:0.91679
# [400]	validation_0-auc:0.92463
# [800]	validation_0-auc:0.92638
# [1200]	validation_0-auc:0.92726
# [1600]	validation_0-auc:0.92760
# [2000]	validation_0-auc:0.92776
# [2400]	validation_0-auc:0.92783
# [2800]	validation_0-auc:0.92785
# [3200]	validation_0-auc:0.92787
# [3600]	validation_0-auc:0.92787
# [3819]	validation_0-auc:0.92787
# 	AUC: 0.92788
# | --------------------
# Fold 6/6
# [0]	validation_0-auc:0.91547
# [400]	validation_0-auc:0.92387
# [800]	validation_0-auc:0.92563
# [1200]	validation_0-auc:0.92660
# [1600]	validation_0-auc:0.92704
# [2000]	validation_0-auc:0.92727
# [2400]	validation_0-auc:0.92739
# [2800]	validation_0-auc:0.92749
# [3200]	validation_0-auc:0.92753
# [3600]	validation_0-auc:0.92758
# [4000]	validation_0-auc:0.92759
# [4400]	validation_0-auc:0.92762
# [4800]	validation_0-auc:0.92763
# [5158]	validation_0-auc:0.92762
# 	AUC: 0.92763
# --------------------
# 	Training Time: 22.47 mins

# %%
## -- After all folds -- 
print(f"|{'-'*52}") 
overall_AUC = roc_auc_score(y, oof_preds) 
print(f"| Overall AUC: {overall_AUC:.5f}") 
print(f"| Average AUC: {np.mean(fold_scores):.5f} ± {np.std(fold_scores):.5f}") 

print(f"|{'-'*52}") 
pred_labels = (oof_preds >= 0.5).astype(int) 
print(classification_report(y, pred_labels))
# Out:
# |----------------------------------------------------
# | Overall AUC: 0.92756
# | Average AUC: 0.92756 ± 0.00077
# |----------------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.65      0.74    119500
#          1.0       0.92      0.98      0.95    474494
#
#     accuracy                           0.91    593994
#    macro avg       0.89      0.81      0.84    593994
# weighted avg       0.91      0.91      0.90    593994

# %%
_, axs = plt.subplots(1, 3, figsize=(18, 5))
## -- ROC curve --
RocCurveDisplay.from_predictions(y, oof_preds, name='Logistic', ax=axs[0])
axs[0].set_title(f"AUC: {overall_AUC:.6f}")

## -- Confusion matrix (threshold = 0.5) --
ConfusionMatrixDisplay.from_predictions(y, pred_labels, cmap='Blues', colorbar=False, ax=axs[1])
axs[1].set_title(f"Confusion Matrix")
axs[1].grid(False)

## -- Distribution plot --
sns.histplot(oof_preds, bins=50, ax=axs[2])
axs[2].set_title(f"Distribution plot")
axs[2].set_xlabel(f"predicted probabilities")

## -- Plot feature importances --
_, axs = plt.subplots(1, 2, figsize=(18, 12))
xgb.plot_importance(models[0], importance_type='gain', max_num_features=30, height=0.5, ax=axs[0])
axs[0].set_title('Gain: Average gain of splits which use the feature')

xgb.plot_importance(models[0], importance_type='weight', max_num_features=30, height=0.5, ax=axs[1])
axs[1].set_title('Weight: Number of times a feature appears in a tree')

plt.tight_layout()
plt.show()

# %%
s = str(overall_AUC).split('.')[1][:5]
np.save(f"oof_XGB_{s}.npy", oof_preds)
np.save(f"pred_XGB_{s}.npy", test_preds)
print(f"✅ oof & prediction files saved!")

submit[TARGET] = test_preds
submit.to_csv(f"submit_XGB_{s}.csv", index=False)

print(f"✅ submit_XGB_{s}.csv file saved!")
# Out:
# ✅ oof & prediction files saved!
# ✅ submit_XGB_92755.csv file saved!
